# %% [markdown]
# ### 导入数据

# %%
import torch
import pandas as pd
import numpy as np
# 新数据
# 读取所有数据
paths = [
    # '../data/processed_data_900_1.csv', '../data/processed_data_900_2.csv', '../data/processed_data_900_3.csv',
    # '../data/processed_data_1050_1.csv', '../data/processed_data_1050_2.csv', '../data/processed_data_1050_3.csv',
    # '../data/processed_data_1200_1.csv', '../data/processed_data_1200_2.csv', '../data/processed_data_1200_3.csv',
    # '../data/processed_data_1350_1.csv', '../data/processed_data_1350_2.csv', '../data/processed_data_1350_3.csv',
    # '../data/processed_data_1500_1.csv', '../data/processed_data_1500_2.csv', '../data/processed_data_1500_3.csv',
    # '../data/processed_data_1650_1.csv', '../data/processed_data_1650_2.csv', '../data/processed_data_1650_3.csv',
    # '../data/new/processed_data_1500_1.csv', '../data/new/processed_data_1500_2.csv', '../data/new/processed_data_1500_3.csv',
    # '../data/new/processed_data_1500_4.csv', '../data/new/processed_data_1500_5.csv', '../data/new/processed_data_1500_6.csv'
    '../data/clean/clean_processed_data_1500_1.csv', '../data/clean/clean_processed_data_1500_2.csv', '../data/clean/clean_processed_data_1500_3.csv',
    '../data/clean/clean_processed_data_1500_4.csv', '../data/clean/clean_processed_data_1500_5.csv', '../data/clean/clean_processed_data_1500_6.csv'
]

# 读取并拼接数据
# all_data = pd.concat([pd.read_csv(path) for path in paths], ignore_index=True)
# all_data = np.array(all_data)
# all_data.shape

# %%
all_data = []
for path in paths:
    data = pd.read_csv(path)
    data = np.array(data)
    all_data.append(data)
all_data = np.concatenate(all_data, axis=0)

# %%
all_data.shape
# Out:
# (2652, 1)

# %%
# 
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
from torch.utils.data import TensorDataset, DataLoader
from tqdm import tqdm
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from torch.optim.lr_scheduler import ReduceLROnPlateau
from sklearn.preprocessing import MinMaxScaler
from copy import deepcopy
import pandas as pd
# 设定随机种子以保证结果可复现
torch.manual_seed(0)
np.random.seed(0)

# 设定设备
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
all_data
# Out:
# array([['(Mo3O9,91);(Mo3O9S2,13);(MoO2,5);(MoOS,11);(MoO2,13);(MoO,40);(MoOS2,3);(MoO,1);(MoOS2,14);(MoS,2);(MoOS2,1);(MoS,1);(MoOS2,2);(MoS,1);(MoOS2,4);(MoS,1);(MoOS2,2);(MoS,1);(MoOS2,8);(MoS,1);(MoOS2,12);(MoS,1);(MoOS2,4);(MoS,2);(MoOS2,15);(MoS,1);(MoOS2,8);(MoS,1);(MoOS2,4);(MoS,2);(MoOS2,6);(MoS,1);(MoOS2,2);(MoS,1);(MoOS2,13);(MoS,3);(MoO2S,1);(MoOS,76);(MoOS3,2);(MoOS,7);(MoOS3,7);(MoOS,49);(MoOS3,19);(MoS2,101);(Mo2S7,3);(MoS3,1);(Mo2S7,57);(Mo2S5,1);(Mo2S7,118);(MoO,25);(MoOS,16);(MoS,9);(MoS2,52);(MoO,6);(MoOS2,4);(MoS,1);(MoOS2,9);(MoS,156);(MoS3,9);(MoS,1);(MoS3,57);(MoS,1);(MoS3,68);(MoOS4,1);(MoS3,52);(MoS5,27);(MoS3,187);(MoOS4,1);(MoS3,84);(MoS5,269);(MoOS6,3);(MoS5,1);(MoOS6,4);(MoS3,1);(MoS5,1);(MoOS6,10);(MoS5,1);(MoOS6,1);(MoS5,1);(MoOS6,2);(MoS5,1);(MoOS6,3);(MoS5,158);(MoS6,4);(MoS4,1);(MoS6,759);(MoOS7,1);(MoS6,743);(MoS8,38);(MoS6,539);(MoOS7,1);(MoS6,2);(MoOS7,15);(MoS6,2);(MoOS7,6);(MoS6,1);(MoOS7,101);(MoS6,3);(MoOS7,123);(MoS6,321);(MoS8,208);(MoS10,1);(MoS8,522);(MoS7,16);(MoO2S7,1);(MoS7,153);(MoS9,136);(MoO2S6,660);(MoS7,152);(MoS5,284);(Mo2S10,74);(MoS5,42);(MoO2S5,131);(MoS5,7);(MoO2S5,5);(MoS5,24);(MoO2S5,74);(MoO4S6,16);(MoO2S6,50);(MoS6,8);(MoO2S6,56);(MoS6,4);(MoO2S6,13);(MoS6,6);(MoO2S6,5);(MoS6,47);(MoO2S6,6);(MoS6,2);(Mo2S10,15);(MoO2S5,25);(MoS5,24);(MoO2S5,14);(MoS5,1);(MoO2S5,29);(MoS5,1);(MoO2S5,34);(MoS5,2);(MoO2S5,12);(MoS5,2);(MoO2S5,5);(MoS5,13);(MoO2S5,40);(MoS5,22);(MoO2S5,3);(MoS5,10);(MoO2S5,32);(MoS5,10);(MoO2S5,11);(MoS5,2);(MoO2S5,1);(MoS5,1);(MoO2S5,34);(MoS5,17);(MoO2S5,17);(MoS5,37);(MoO2S5,78);(MoS5,13);(MoO2S5,33);(MoS5,28);(MoO2S5,2);(MoS5,8);(MoO2S5,11);(MoS5,3);(MoO2S5,10);(MoS5,16);(MoO2S5,33);(MoS5,33);(MoO2S5,16);(MoS5,30);(MoO2S5,9);(MoS5,6);(MoO2S5,57);(MoS5,9);(MoO2S5,10);(MoS5,59);(MoO2S5,18);(MoS5,2);(MoO2S5,116);(MoS5,22);(MoO2S5,125);(MoS5,6);(MoO2S5,2);(MoS5,13);(MoO2S5,4);(MoS5,4);(MoO2S5,130);(MoS5,56);(MoO2S5,49);(MoS5,4);(MoO2S5,146);(MoS5,8);(MoO2S5,75);(MoS5,1);(MoO2S5,11);(MoS5,9);(MoO2S5,23);(MoS5,19);(MoO2S5,13);(MoS5,5);(MoO2S5,52);(MoS5,11);(MoO2S5,2);(MoS5,1);(MoO2S5,154);(MoS5,20);(MoO2S5,4);(MoS5,1);(MoO2S5,57);(MoS5,7);(MoO2S5,77);(MoS5,1);(MoO2S5,167);(MoS5,47);(MoO2S5,238);(MoS5,7);(MoO2S5,92);(MoS5,33);(MoO2S5,79);(MoS5,19);(MoO2S5,61);(MoS5,9);(MoO2S5,119);(MoS5,17);(MoO2S5,23);(MoS5,4);(MoO2S5,259);(MoS5,3);(MoO2S5,5);(MoS5,56);(MoO2S5,33);(MoS5,3);(MoO2S5,33);(MoS5,11);(MoO2S5,153);(MoS5,72);(MoO2S5,30);(MoS5,6);(MoO2S5,11);(MoS5,6);(MoO2S5,65);(MoS5,13);(MoO2S5,500);(MoO2S4,225);(MoO2S5,803);(MoO2S8,96);(MoO3S8,722);(MoS7,570);(MoOS8,12);(MoS7,2752);(MoOS8,1);(MoS7,246);(MoOS8,2);(MoS7,2);(MoOS8,8);(MoS7,1);(MoOS8,5);(MoS7,1);(MoOS8,2);(MoS7,1);(MoOS8,2);(MoS7,1);(MoOS8,1);(MoS7,1);(MoOS8,6);(MoS7,2);(MoOS8,6);(MoS7,2);(MoOS8,5);(MoS7,1);(MoOS8,4);(MoS7,2);(MoOS8,4);(MoS7,1);(MoOS8,2);(MoS7,1);(MoOS8,8);(MoS7,1);(MoOS8,2);(MoS7,1);(MoOS8,1);(MoS7,1);(MoOS8,4);(MoS7,2);(MoOS8,4);(MoS7,1);(MoOS8,3);(MoS7,1);(MoOS8,4);(MoS7,2);(MoOS8,1);(MoS7,2);(MoOS8,17);(MoS7,1);(MoOS8,1);(MoS7,2);(MoOS8,4);(MoS7,2);(MoOS8,2);(MoS7,1);(MoOS8,65);(MoS7,182);(MoOS8,5);(MoS7,1);(MoOS8,2);(MoS7,1);(MoOS8,1);(MoS7,1);(MoOS8,35);(MoS7,3);(MoOS8,2);(MoS7,1);(MoOS8,1);(MoS7,2);(MoOS8,3);(MoS7,1);(MoOS8,2);(MoS7,5);(MoOS8,4);(MoS7,1);(MoOS8,4);(MoS7,1);(MoOS8,4);(MoS7,1497);(MoOS8,6);(MoS7,2);(MoOS8,5);(MoS7,1);(MoOS8,4);(MoS7,2);(MoOS8,3);(MoS7,2);(MoOS8,5);(MoS7,753);(MoOS8,2);(MoS7,1);(MoOS8,17);(MoS7,1);(MoOS8,6);(MoS7,2);(MoOS8,4);(MoS7,1);(MoOS8,6);(MoS7,1);(MoOS8,2);(MoS7,1);(MoOS8,1);(MoS7,1);(MoOS8,8);(MoS7,1);(MoOS8,8);(MoS7,1);(MoOS8,128);(MoS7,1);(MoOS8,2);(MoS7,1);(MoOS8,6);(MoS7,3);(MoOS8,1);(MoS7,2);(MoOS8,14);(MoS7,1);(MoOS8,1);(MoS7,1);(MoOS8,52);(MoS7,3);(MoOS8,3);(MoS7,1);(MoOS8,3);(MoS7,1);(MoOS8,3);(MoS7,2);(MoOS8,2);(MoS7,1);(MoOS8,12);(MoS7,1);(MoOS8,6);(MoS7,1);(MoOS8,9);(MoS7,2);(MoOS8,1);(MoS7,1);(MoOS8,2);(MoS7,2);(MoOS8,5);(MoS7,1);(MoOS8,2);(MoS7,1);(MoOS8,2);(MoS7,1);(MoOS8,4);(MoS7,1);(MoOS8,1);(MoS7,1);(MoOS8,5);(MoS7,3);(M ...
#        ['(Mo3O9,91);(Mo3O9S2,13);(Mo2O4,5);(MoO2,5);(MoO,101);(MoO2,1);(MoO,72);(MoO2S,3);(MoS,1);(MoOS,12);(MoOS3,1);(MoS2,135);(MoOS2,2);(MoS,43);(MoOS,15);(MoOS3,1);(MoOS,1);(MoOS3,8);(MoOS,1);(MoOS3,1);(MoOS,30);(MoO2S,1);(MoOS,11);(MoOS2,64);(MoO2S3,1);(MoS2,1);(MoO2S3,3);(MoOS2,1);(MoO2S3,5);(MoOS2,1);(MoO2S3,3);(MoOS2,1);(MoO2S3,2);(MoOS2,1);(MoO2S3,2);(MoOS2,1);(MoO2S3,9);(MoOS2,1);(MoO2S3,2);(MoS,1);(MoOS2,1);(MoO2S3,2);(MoOS2,17);(MoS,1);(MoOS2,19);(MoS,1);(MoOS2,9);(MoS,1);(MoOS2,9);(MoS,1);(MoOS2,23);(MoS,1);(MoOS2,7);(MoS,1);(MoOS2,15);(MoS,1);(MoOS2,13);(MoS,1);(MoOS2,17);(MoS,1);(MoOS2,11);(MoS,1);(MoOS2,38);(MoS,1);(MoOS2,4);(MoS,1);(MoOS2,91);(MoOS4,1);(MoS3,180);(MoS5,236);(MoOS6,14);(MoS5,1);(MoOS6,9);(MoS3,1);(MoS5,3);(MoOS6,5);(MoS5,1);(MoOS6,7);(MoS5,1);(MoOS6,2);(MoS5,1);(MoOS6,1);(MoS5,1);(MoOS6,7);(MoS5,1);(MoOS6,2);(MoS5,1);(MoOS6,13);(MoS5,1);(MoOS6,6);(MoS5,1);(MoOS6,2);(MoS5,2);(MoOS6,12);(MoS5,1);(MoOS6,26);(MoS7,1);(MoS5,1);(MoOS6,1);(MoOS4,1);(MoOS6,6);(MoS5,1);(MoOS6,2);(MoS5,1);(MoOS6,1);(MoS5,1);(MoOS6,6);(MoS5,1);(MoOS6,2);(MoS5,1);(MoOS6,1);(MoS5,1);(MoOS6,3);(MoS5,1);(MoOS6,10);(MoS5,1);(MoOS6,34);(MoS5,1);(MoOS6,3);(MoS5,1);(MoOS6,5);(MoS5,1);(MoOS6,11);(MoS5,1);(MoOS6,3);(MoS5,1);(MoOS6,21);(MoO2S7,1);(MoOS6,3);(MoS5,1);(MoOS6,22);(MoS5,1);(MoOS6,12);(MoS5,2);(MoOS6,22);(MoS5,1);(MoOS6,11);(MoS5,1);(MoOS6,4);(MoS5,1);(MoOS6,1);(MoS5,1);(MoOS6,5);(MoS5,1);(MoOS6,78);(MoS5,1);(MoOS6,8);(MoS5,1);(MoOS6,36);(MoS5,1);(MoOS6,137);(MoS5,1);(MoOS6,82);(MoS5,1);(MoOS6,86);(MoS5,1);(MoOS6,56);(MoS5,2);(MoOS6,2);(MoS5,1);(MoOS6,4);(MoS5,1);(MoOS6,146);(MoS5,1);(MoOS6,528);(MoS5,1);(MoOS6,34);(MoS5,1);(MoOS6,39);(MoS5,1);(MoOS6,171);(MoS5,1);(MoOS6,12);(MoS5,1);(MoOS6,71);(MoS5,1);(MoOS6,25);(MoS5,1);(MoOS6,178);(MoS5,1);(MoOS6,29);(MoS7,1);(MoOS8,24);(MoS7,1);(MoOS8,1);(MoS7,870);(MoS10,4);(MoS7,105);(MoOS8,1);(MoS7,648);(MoOS8,5);(MoS7,1);(MoOS8,66);(MoS7,1);(MoOS8,2);(MoS7,2);(MoOS8,3);(MoS7,1);(MoOS8,1);(MoS7,1);(MoOS8,1);(MoS7,1);(MoOS8,3);(MoS7,1);(MoOS8,1);(MoS7,1);(MoOS8,1);(MoS7,1);(MoOS8,1);(MoS7,1);(MoOS8,4);(MoS7,2);(MoOS8,2);(MoS7,1);(MoOS8,2);(MoS7,2);(MoOS8,2);(MoS7,1);(MoOS8,1);(MoS7,1);(MoOS8,4);(MoS7,5);(MoOS8,2);(MoS7,1);(MoOS8,5);(MoS7,1);(MoOS8,13);(MoS7,1);(MoOS8,18);(MoS7,434);(MoS9,357);(MoS6,454);(MoOS7,3);(MoS6,1);(MoOS7,4);(MoS6,1);(MoOS7,3);(MoS6,1);(MoOS7,135);(MoS6,1);(MoOS7,38);(MoS6,1);(MoOS7,3);(MoS6,1);(MoOS7,269);(MoS6,1);(MoOS7,136);(MoS6,426);(MoS8,41);(MoOS9,9);(MoS8,1046);(MoS7,1230);(MoOS8,1);(MoS7,3);(MoOS8,2);(MoS7,2385);(MoOS8,4);(MoS7,2);(MoOS8,12);(MoS7,1);(MoOS8,2);(MoS7,1);(MoOS8,2);(MoS7,1);(MoOS8,12);(MoS7,1);(MoOS8,1);(MoS7,1);(MoOS8,3);(MoS7,2);(MoOS8,3);(MoS7,1);(MoOS8,2);(MoS7,1);(MoOS8,14);(MoS7,1);(MoOS8,4);(MoS7,1);(MoOS8,3);(MoS7,2);(MoOS8,4);(MoS7,2);(MoOS8,6);(MoS7,1);(MoOS8,1);(MoS7,1);(MoOS8,3);(MoS7,1);(MoOS8,2);(MoS7,2);(MoOS8,2);(MoS7,1);(MoOS8,2);(MoS7,2);(MoOS8,4);(MoS7,1);(MoOS8,1);(MoS7,1);(MoOS8,1);(MoS7,2);(MoOS8,1);(MoS7,1);(MoOS8,350);(MoS7,1);(MoOS8,1);(MoS7,1);(MoOS8,4);(MoS7,1);(MoOS8,1);(MoS7,2);(MoOS8,4);(MoS7,1);(MoOS8,356);(MoS7,1);(MoOS8,2);(MoS7,1);(MoOS8,7);(MoS7,1);(MoOS8,2);(MoS7,3);(MoOS8,1);(MoS7,1);(MoOS8,3);(MoS7,1);(MoOS8,1);(MoS7,2);(MoOS8,124);(MoS7,1);(MoOS8,1);(MoS7,1);(MoOS8,2);(MoS7,1);(MoOS8,2);(MoS7,1);(MoOS8,2);(MoS7,2);(MoOS8,3);(MoS7,1);(MoOS8,3);(MoS7,2);(MoOS8,7);(MoS7,2);(MoOS8,6);(MoS7,3);(MoOS8,1);(MoS7,1);(MoOS8,1);(MoS7,1);(MoOS8,1);(MoS7,1);(MoOS8,7);(MoS7,1);(MoOS8,5);(MoS7,1);(MoOS8,52);(MoS7,2);(MoOS8,2);(MoS7,1);(MoOS8,4);(MoS7,1);(MoOS8,2);(MoS7,1);(MoOS8,2);(MoS7,3);(MoOS8,7);(MoS7,1);(MoOS8,297);(MoOS6,1653);(MoO2S7,2);(MoOS6,1);(MoO2S7,2);(MoOS6,1);(MoO2S7,1);(MoOS6,1);(MoO2S7,2);(MoOS6,1);(MoO2S7,1);(MoOS6,2);(MoO2S7,3);(MoOS6,1);(MoO2S7,1);(MoOS6,1);(MoO2S7,3);(MoOS6,1);(MoO2S7,2);(MoOS6,1);(MoO2S7,1);(MoOS6,1);(MoO2S7,10);(MoOS6,1);(MoO2S7,4);(MoOS6,2);(MoO2S7,17);(MoOS6,1);(MoO2S7,2);(MoOS6,1);(MoO2S7,2);(MoOS6,2);(MoO2S7,36);(MoOS6,1);(MoO2S7,18);(MoOS6,1);(MoO2S7,9);(MoOS6,1);(Mo ...
#        ['(Mo3O9,61);(Mo3O9S2,16);(MoO3,3);(MoO2,1);(MoO3,2);(MoO2,15);(MoO,1);(MoO2,4);(MoO,2);(MoO2,2);(MoO,1);(MoO2,3);(MoO,1);(MoO2,3);(MoO,1);(MoO2,20);(MoO,1);(MoO2,9);(MoO,1);(MoO2,9);(MoO,1);(MoO2,170);(MoO2S2,3);(MoOS,213);(MoO2S2,7);(Mo,1);(MoO2S2,1);(MoOS,9);(Mo,1);(MoOS,5);(Mo,1);(MoOS,14);(MoOS3,7);(MoS2,1);(MoOS,1);(MoOS3,8);(MoS2,1);(MoOS3,1);(MoS2,49);(MoS4,74);(MoS6,4);(MoS4,60);(Mo2S5,1);(MoS,5);(MoOS,23);(MoS4,1);(Mo2S5,4);(MoS3,6);(MoOS2,4);(MoOS,2);(MoOS2,270);(MoOS4,4);(MoS3,136);(MoS5,14);(MoS3,1);(MoS5,8);(MoS3,1);(MoS5,18);(MoS3,1);(MoS5,553);(MoS7,4);(MoS5,198);(MoOS6,24);(MoS5,1);(MoOS6,12);(MoS5,1);(MoOS6,10);(MoS5,1);(MoOS6,3);(MoS5,2);(MoOS6,1);(MoS5,1);(MoOS6,15);(MoS5,1);(MoOS6,6);(MoS5,1);(MoOS6,31);(MoS5,1);(MoOS6,53);(MoS5,1);(MoOS6,1);(MoS5,1);(MoOS6,11);(MoS5,2);(MoOS6,3);(MoS5,1);(MoOS6,4);(MoS5,1);(MoOS6,1);(MoS5,2);(MoOS6,20);(MoS5,1);(MoOS6,18);(MoS5,1);(MoOS6,5);(MoS5,1);(MoOS6,5);(MoS5,1);(MoOS6,1);(MoS5,1);(MoOS6,18);(MoS5,1);(MoOS6,24);(MoS5,3);(MoOS6,7);(MoS5,1);(MoOS6,3);(MoS5,2);(MoOS6,1);(MoS5,1);(MoOS6,21);(MoS5,1);(MoOS6,3);(MoS5,1);(MoOS6,11);(MoS5,1);(MoOS6,22);(MoS5,1);(MoOS6,43);(MoS5,1);(MoOS6,19);(MoS5,1);(MoOS6,81);(MoS5,1);(MoOS6,27);(MoS5,1);(MoOS6,38);(MoO2S7,1);(MoOS6,65);(MoS5,1);(MoOS6,4);(MoS5,1);(MoOS6,11);(MoS5,1);(MoOS6,377);(MoO2S7,30);(MoOS6,84);(MoO2S7,1);(MoOS6,314);(MoO2S6,33);(MoS5,22);(MoO2S7,6);(MoS6,2231);(MoS9,1);(MoS6,232);(MoOS7,4);(MoS6,997);(MoOS7,1);(MoS6,810);(MoOS7,1);(MoS6,88);(MoOS7,92);(MoS6,2);(MoOS7,17);(MoS6,1);(MoOS7,69);(MoS6,1);(MoOS7,2);(MoS6,1);(MoOS7,1);(MoS6,186);(MoOS7,23);(MoS6,2);(MoOS7,3);(MoS6,1);(MoOS7,2);(MoS6,1);(MoOS7,1);(MoS6,1);(MoOS7,2);(MoS6,1);(MoOS7,5);(MoS6,1);(MoOS7,5);(MoS6,1);(MoOS7,3);(MoS6,1);(MoOS7,4);(MoS6,1);(MoOS7,3);(MoS6,1);(MoOS7,1);(MoS6,1);(MoOS7,1);(MoS6,2);(MoOS7,7);(MoS6,1);(MoOS7,7);(MoS6,1);(MoOS7,2);(MoS6,1);(MoOS7,3);(MoS6,1);(MoOS7,2);(MoS6,4);(MoOS7,3);(MoS6,1);(MoOS7,2);(MoS6,2);(MoOS7,1);(MoS6,2);(MoOS7,1);(MoS6,1258);(MoOS7,2);(MoS6,2);(MoOS7,4);(MoS6,1);(MoOS7,48);(MoS6,1);(MoOS7,36);(MoO2S8,1);(MoOS7,1);(MoO2S8,3);(MoOS7,88);(MoS6,1);(MoOS7,1);(MoS6,1);(MoOS7,122);(MoS6,1);(MoOS7,2);(MoOS9,1);(MoS8,1);(MoOS6,1005);(MoS5,1);(MoOS6,1066);(MoS5,1);(MoOS6,2006);(MoS5,1);(MoOS6,296);(MoS5,1);(MoOS6,21);(MoS5,1);(MoOS6,12);(MoS5,1);(MoOS6,116);(MoS5,1);(MoOS6,24);(MoS5,1);(MoOS6,12);(MoS5,2);(MoOS6,36);(MoS5,1);(MoOS6,2);(MoS5,1);(MoOS6,1);(MoS5,1);(MoOS6,168);(MoS5,1);(MoOS6,490);(MoS5,1);(MoOS6,3);(MoS5,1);(MoOS6,6);(MoS5,1);(MoOS6,3);(MoS5,1);(MoOS6,8);(MoS5,1);(MoOS6,30);(MoS5,1);(MoOS6,25);(MoS5,1);(MoOS6,144);(MoS5,1);(MoOS6,31);(MoS5,1);(MoOS6,135);(MoS5,1);(MoOS6,216);(MoS5,1);(MoOS6,279);(MoS5,1);(MoOS6,32);(MoS5,1);(MoOS6,311);(MoS5,1);(MoOS6,12);(MoS5,1);(MoOS6,339);(MoS5,1);(MoOS6,1559);(MoO2S7,1);(MoOS6,325);(MoS5,1);(MoOS6,25);(MoS5,1);(MoOS6,1);(MoS5,1);(MoOS6,45);(MoS5,1);(MoOS6,2);(MoS5,1);(MoOS6,71);(MoS5,1);(MoOS6,4);(MoS5,1);(MoOS6,116);(MoS5,2);(MoOS6,432);(MoS5,1);(MoOS6,65);(MoS5,1);(MoOS6,103);(MoS5,1);(MoOS6,10);(MoS5,1);(MoOS6,24);(MoS5,1);(MoOS6,11);(MoS5,1);(MoOS6,105);(MoS5,1);(MoOS6,26);(MoS5,1);(MoOS6,144);(MoS5,1);(MoOS6,416);(MoS5,1);(MoOS6,21);(MoS5,1);(MoOS6,59);(MoS5,1);(MoOS6,200);(MoS5,1);(MoOS6,4);(MoS5,1);(MoOS6,16);(MoS5,1);(MoOS6,57);(MoS5,1);(MoOS6,2);(MoS5,1);(MoOS6,9);(MoS5,1);(MoOS6,65);(MoS5,1);(MoOS6,84);(MoS5,1);(MoOS6,12);(MoS5,1);(MoOS6,22);(MoS5,1);(MoOS6,10);(MoS5,1);(MoOS6,10);(MoS5,1);(MoOS6,4);(MoS5,1);(MoOS6,102);(MoS5,1);(MoOS6,961);(MoS5,1);(MoOS6,22);(MoS5,1);(MoOS6,11);(MoS5,1);(MoOS6,966);(MoS5,1);(MoOS6,1);(MoS5,1);(MoOS6,98);(MoS5,1);(MoOS6,84);(MoS5,1);(MoOS6,236);(MoS5,1);(MoOS6,35);(MoS5,1);(MoOS6,12);(MoO2S7,1);(MoOS6,2465);(MoS5,1);(MoOS6,1584);(MoS5,1);(MoOS6,9);(MoS5,1);(MoOS6,14);(MoS5,1);(MoOS6,14);(MoS5,1);(MoOS6,4);(MoS5,1);(MoOS6,6);(MoS5,1);(MoOS6,25);(MoS5,1);(MoOS6,77);(MoS5,1);(MoOS6,2);(MoS5,1);(MoOS6,16);(MoS5,2);(MoOS6,1);(MoS5,1);(MoOS6,19);(MoOS8,1);(MoOS6,21);(MoS5,1);(MoOS6,15);(MoS5,1);(MoOS6,15);(MoS5,1);(M ...
#        ['(Mo3O9,61);(Mo3O9S2,16);(Mo2O4,4);(MoO2,15);(MoO,1);(MoO2,2);(MoO,3);(MoO2,2);(MoO,1);(MoO2,3);(MoO,1);(MoO2,4);(MoO,2);(MoO2,2);(MoO3,9);(MoO2,6);(MoO3,5);(MoO2,32);(MoO,1);(MoO2,3);(MoO,1);(MoO2,1);(MoO,1);(MoO2,1);(MoO,1);(MoO2,1);(MoO,1);(MoO2,5);(MoO,1);(MoO2,4);(MoO2S2,1);(MoO2,13);(MoO,1);(MoO2,1);(MoO,2);(MoO2,5);(MoO,1);(MoO2,1);(MoO2S2,1);(MoOS,458);(MoOS3,1);(MoS2,174);(Mo2OS7,55);(MoS4,46);(Mo2S8,6);(MoS4,1);(Mo2S8,8);(MoS4,49);(MoS3,105);(MoOS6,3);(MoOS5,1);(MoOS6,1);(MoOS4,2);(MoOS5,31);(MoS4,1);(MoOS5,8);(MoS4,163);(MoS6,5);(MoS4,1);(MoS6,171);(MoS7,3);(MoS6,1183);(MoO2S6,46);(MoS6,29);(MoO2S6,29);(MoS6,205);(MoO2S5,9);(MoS5,9);(MoO2S5,29);(MoS5,2);(MoO2S5,48);(MoS5,1812);(MoO2S5,28);(MoS5,168);(MoO2S5,465);(Mo2OS8,18);(MoS4,1);(Mo2OS8,2);(MoOS4,1);(Mo2OS8,12);(MoOS4,1);(Mo2OS8,10);(MoOS3,1);(Mo2OS8,1);(Mo2S7,1);(Mo2OS8,1);(Mo2S7,1);(Mo2OS8,28);(Mo2S7,1);(Mo2OS8,1);(Mo2S7,1089);(MoS6,340);(MoS4,149);(MoS6,1053);(MoOS7,1);(MoS6,1122);(MoOS7,1);(MoS6,328);(MoOS7,2);(MoS6,3);(MoOS7,1);(MoS6,1);(MoOS7,3);(MoS6,2);(MoOS7,4);(MoS6,1);(MoOS7,1);(MoS6,30);(MoOS7,1);(MoS6,257);(MoOS7,84);(MoS6,1);(MoOS7,22);(MoS6,1);(MoOS7,503);(MoS6,1);(MoOS7,142);(MoO2S8,1);(MoOS7,1);(MoO2S8,8);(MoOS7,1);(MoO2S8,4);(MoOS7,1);(MoO2S8,4);(MoOS7,1);(MoO2S8,6);(MoOS7,1194);(MoS6,1);(MoOS7,2);(MoS6,1);(MoOS7,295);(MoS6,1);(MoOS7,2);(MoS6,3);(MoOS7,5);(MoS6,3);(MoOS7,3);(MoS6,1575);(MoOS7,3);(MoS6,3);(MoOS7,1);(MoS6,277);(MoOS7,230);(MoS6,1);(MoOS7,46);(MoS6,1);(MoOS7,259);(MoS6,1);(MoOS7,195);(MoS6,1);(MoOS7,171);(MoS6,1);(MoOS7,8);(MoS6,1);(MoOS7,3);(MoS6,1);(MoOS7,3);(MoS6,1);(MoOS7,1);(MoS6,1424);(MoS8,316);(MoS6,1149);(MoOS7,1);(MoS6,2);(MoOS7,2);(MoS6,4030);(MoOS7,2);(MoS6,2);(MoOS7,3);(MoS6,1);(MoOS7,1);(MoS6,2);(MoOS7,1);(MoS6,1);(MoOS7,280);(MoS6,1);(MoOS7,13);(MoS6,1);(MoOS7,49);(MoS6,1);(MoOS7,16);(MoS6,1);(MoOS7,18);(MoS6,2);(MoOS7,5);(MoS6,1339);(MoOS7,1);(MoS6,1);(MoOS7,4);(MoS6,1);(MoOS7,2);(MoS6,2);(MoOS7,5);(MoS6,1);(MoOS7,1);(MoS6,1);(MoOS7,1);(MoS6,1);(MoOS7,1);(MoS6,2);(MoOS7,1);(MoS6,1);(MoOS7,1);(MoS6,2);(MoOS7,1);(MoS6,3);(MoOS7,1);(MoS6,1139);(MoOS7,46);(MoS6,1);(MoOS7,12);(MoS6,1);(MoOS7,34);(MoS6,1);(MoOS7,8);(MoS6,1);(MoOS7,50);(MoS6,1);(MoOS7,2);(MoS6,1);(MoOS7,2);(MoS6,475);(MoOS7,9);(MoS6,1);(MoOS7,7);(MoS6,1);(MoOS7,2);(MoS6,1);(MoOS7,1);(MoS6,1171);(MoOS7,1);(MoS6,1784);(MoOS7,1);(MoS6,1436)'],
#        ['(Mo3O9,61);(Mo3O9S2,16);(Mo2O4,4);(MoO2,164);(MoO2S2,6);(MoOS,53);(MoO2S3,1);(MoOS2,1);(MoO2S3,2);(MoOS2,64);(MoOS4,12);(MoS3,2);(MoOS4,2);(MoS3,2);(MoOS4,4);(MoS3,1);(MoOS4,6);(MoS3,1);(MoOS4,7);(MoS3,1);(MoOS4,17);(MoS3,1);(MoOS4,7);(MoS3,1);(MoOS4,13);(MoS3,1);(MoOS4,23);(MoS3,1);(MoOS4,37);(MoS3,1);(MoOS4,86);(MoS3,1);(MoOS4,49);(MoS3,1);(MoOS4,57);(MoOS6,11);(MoS5,1);(MoOS6,4);(MoS5,1);(MoOS6,8);(MoS5,1);(MoOS6,6);(MoS5,1);(MoOS6,3);(MoS5,1);(MoOS6,1);(MoS5,1);(MoOS6,2);(MoOS4,1);(MoS5,2);(MoOS6,5);(MoS5,1);(MoOS6,7);(MoS5,1);(MoOS6,2);(MoS5,1);(MoOS6,1);(MoS5,2);(MoOS6,9);(MoS5,1);(MoOS6,1);(MoS5,1);(MoOS6,4);(MoS5,1);(MoOS6,20);(MoS5,1);(MoOS6,49);(MoS5,1);(MoOS6,5);(MoS5,1);(MoOS6,1);(MoS5,2);(MoOS6,18);(MoS5,1);(MoOS6,3);(MoS5,1);(MoOS6,26);(MoS5,1);(MoOS6,3);(MoS5,1);(MoOS6,9);(MoS5,1);(MoOS6,7);(MoS5,1);(MoOS6,8);(MoS5,1);(MoOS6,147);(MoOS9,2);(MoOS6,276);(MoO2S7,3);(MoOS6,49);(MoS5,1);(MoOS6,2451);(MoO2S7,9);(MoOS6,1);(MoO2S7,4);(MoOS6,1);(MoO2S7,1492);(MoS6,1);(MoO2S7,334);(MoS6,1);(MoO2S7,926);(MoS6,1);(MoO2S7,92);(MoS6,1);(MoO2S7,715);(MoO3S8,1);(MoO2S7,1);(MoO3S8,1);(MoO2S7,1153);(MoO2S9,200);(MoO2S8,239);(MoS7,1);(MoO2S8,125);(MoS7,1);(MoO3S9,7);(MoO2S8,1);(MoO3S9,28);(MoO2S8,1);(MoO3S9,2);(MoS7,1);(MoO3S9,13);(MoO2S8,909);(MoS7,1);(MoO2S8,1443);(MoO3S9,2);(MoO2S8,1);(MoO3S9,6);(MoO2S8,1);(MoO3S9,3);(MoO2S8,1);(MoO3S9,3);(MoO2S8,1);(MoO3S9,6735);(MoS6,15);(MoO2S7,8);(MoS6,3);(MoO2S7,15);(MoS6,40);(MoO2S7,7);(MoS6,308);(MoOS7,1);(MoS6,698);(MoO3S9,33);(MoS7,854);(MoOS8,1);(MoS7,1);(MoOS8,27);(MoS7,1);(MoOS8,2);(MoS7,1);(MoOS8,1);(MoS7,2);(MoOS8,28);(MoS7,1);(MoOS8,1);(MoS7,1);(MoOS8,8);(MoS7,1);(MoOS8,12);(MoS7,1);(MoOS8,2);(MoS7,2);(MoOS8,3);(MoS7,4192);(MoOS8,2);(MoS7,4);(MoOS8,2);(MoS7,1);(MoOS8,5);(MoS7,2031);(MoS9,3349)'],
#        ['(Mo3O9,86);(Mo3O9S2,24);(Mo2O4,3);(MoO,21);(MoOS2,22);(MoS,2);(MoOS2,2);(MoS,12);(MoOS2,14);(MoS,33);(MoS3,16);(MoS,1);(MoS3,3);(MoS2,1);(MoS3,12);(MoS2,1);(MoS3,39);(MoS5,2);(MoS3,1);(MoS5,1);(MoS3,379);(MoS5,502);(MoOS6,9);(MoS5,1);(MoOS6,5);(MoS5,1);(MoOS6,3);(MoS5,1);(MoOS6,13);(MoS5,1);(MoOS6,7);(MoS5,1);(MoOS6,5);(MoS5,1);(MoOS6,16);(MoS5,1);(MoOS6,17);(MoS5,1);(MoOS6,1);(MoS5,1);(MoOS6,1);(MoS5,1);(MoOS6,10);(MoS5,1);(MoOS6,22);(MoS5,1);(MoOS6,9);(MoS5,1);(MoOS6,31);(MoS5,1);(MoOS6,38);(MoS5,1);(MoOS6,21);(MoS5,1);(MoOS6,15);(MoS5,1);(MoOS6,3);(MoS5,1);(MoOS6,18);(MoS5,1);(MoOS6,49);(MoS5,1);(MoOS6,9);(MoS5,2);(MoOS6,6);(MoS5,1);(MoOS6,10);(MoS5,1);(MoOS6,2);(MoS5,1);(MoOS6,30);(MoS5,1);(MoOS6,14);(MoS5,1);(MoOS6,3);(MoS5,1);(MoOS6,28);(MoS5,1);(MoOS6,4);(MoS5,1);(MoOS6,12);(MoS5,1);(MoOS6,21);(MoS5,1);(MoOS6,16);(MoS5,1);(MoOS6,10);(MoS5,1);(MoOS6,9);(MoS5,1);(MoOS6,18);(MoS5,1);(MoOS6,57);(MoS5,1);(MoOS6,25);(MoS5,1);(MoOS6,3);(MoS5,1);(MoOS6,25);(MoS5,1);(MoOS6,3);(MoS5,1);(MoOS6,34);(MoS5,1);(MoOS6,23);(MoS5,1);(MoOS6,345);(MoOS9,3);(MoS8,1);(MoOS9,5);(MoOS6,1085);(MoOS8,2);(MoS7,1);(MoOS8,21);(MoS7,1);(MoOS8,3);(MoOS6,284);(MoS5,1);(MoOS6,66);(MoS5,1);(MoOS6,361);(MoS5,1);(MoOS6,83);(MoS5,1);(MoOS6,199);(MoS5,1);(MoOS6,8);(MoS5,1);(MoOS6,28);(MoS5,1);(MoOS6,9);(MoS5,1);(MoOS6,1);(MoS5,1);(MoOS6,4);(MoS5,1);(MoOS6,99);(MoS5,1);(MoOS6,23);(MoS5,1);(MoOS6,101);(MoS5,1);(MoOS6,17);(MoS5,1);(MoOS6,65);(MoS5,1);(MoOS6,49);(MoS5,1);(MoOS6,16);(MoS5,1);(MoOS6,31);(MoS5,1);(MoOS6,14);(MoOS8,1);(MoOS6,31);(MoS5,1);(MoOS6,28);(MoS5,1);(MoOS6,31);(MoS5,2);(MoOS6,15);(MoS5,1);(MoOS6,8);(MoS5,1);(MoOS6,148);(MoS5,1);(MoOS6,6);(MoS5,1);(MoOS6,7);(MoS5,1);(MoOS6,111);(MoO2S7,1);(MoOS6,25);(MoS5,1);(MoOS6,84);(MoS5,1);(MoOS6,188);(MoS5,1);(MoOS6,119);(MoS5,1);(MoOS6,22);(MoS7,1);(MoOS6,988);(MoS5,1);(MoOS6,113);(MoS5,1);(MoOS6,210);(MoS5,1);(MoOS6,7);(MoO2S7,1);(MoOS6,1);(MoO2S7,2);(MoOS6,25);(MoS5,1);(MoOS6,89);(MoS5,1);(MoOS6,6);(MoS5,1);(MoOS6,7);(MoS5,1);(MoOS6,5);(MoS5,1);(MoOS6,11);(MoS5,1);(MoOS6,78);(MoS5,1);(MoOS6,12);(MoS5,1);(MoOS6,2);(MoS5,1);(MoOS6,13);(MoS5,1);(MoOS6,2);(MoS5,1);(MoOS6,14);(MoS5,1);(MoOS6,61);(MoS5,1);(MoOS6,16);(MoS5,1);(MoOS6,3);(MoS5,1);(MoOS6,35);(MoS5,1);(MoOS6,11);(MoS5,1);(MoOS6,3);(MoS5,1);(MoOS6,96);(MoO2S7,1);(MoOS6,17);(MoS5,1);(MoOS6,210);(MoS5,1);(MoOS6,1110);(MoS5,1);(MoOS6,66);(MoS5,1);(MoOS6,33);(MoS5,1);(MoOS6,14);(MoS5,1);(MoOS6,35);(MoS5,1);(MoOS6,1);(MoS5,1);(MoOS6,17);(MoO2S7,1);(MoOS6,45);(MoS5,1);(MoOS6,2);(MoS5,1);(MoOS6,4);(MoS5,1);(MoOS6,70);(MoS5,1);(MoOS6,5);(MoS5,1);(MoOS6,3094);(MoS5,1);(MoOS6,83);(MoS5,1);(MoOS6,188);(MoS5,1);(MoOS6,111);(MoS5,1);(MoOS6,15);(MoS5,1);(MoOS6,71);(MoS5,1);(MoOS6,111);(MoS5,1);(MoOS6,384);(MoS5,1);(MoOS6,7);(MoS5,2);(MoOS6,26);(MoS5,1);(MoOS6,32);(MoS5,1);(MoOS6,111);(MoS5,1);(MoOS6,46);(MoO2S7,1);(MoS5,1);(MoOS6,32);(MoS5,1);(MoOS6,58);(MoS5,1);(MoOS6,231);(MoS5,1);(MoOS6,131);(MoS5,1);(MoOS6,31);(MoS5,1);(MoOS6,17);(MoS5,1);(MoOS6,1);(MoS5,1);(MoOS6,246);(MoS5,1);(MoOS6,60);(MoS5,1);(MoOS6,51);(MoS5,1);(MoOS6,107);(MoS5,1);(MoOS6,53);(MoS5,1);(MoOS6,15);(MoS5,1);(MoOS6,11);(MoS5,1);(MoOS6,15);(MoS5,1);(MoOS6,229);(MoS5,1);(MoOS6,16);(MoS5,1);(MoOS6,23);(MoS5,1);(MoOS6,126);(MoS5,1);(MoOS6,46);(MoS5,1);(MoOS6,172);(MoS5,1);(MoOS6,57);(MoS5,1);(MoOS6,78);(MoS5,1);(MoOS6,17);(MoS5,1);(MoOS6,73);(MoS5,1);(MoOS6,3);(MoS5,1);(MoOS6,4);(MoS5,1);(MoOS6,29);(MoS5,1);(MoOS6,52);(MoS5,1);(MoOS6,2);(MoS5,1);(MoOS6,2);(MoS5,1);(MoOS6,23);(MoS5,1);(MoOS6,19);(MoS5,1);(MoOS6,11);(MoS5,1);(MoOS6,18);(MoS5,1);(MoOS6,19);(MoS5,1);(MoOS6,1);(MoS5,1);(MoOS6,6);(MoS5,2);(MoOS6,9);(MoS5,1);(MoOS6,4);(MoS5,1);(MoOS6,34);(MoOS8,4);(MoOS6,207);(MoS5,1);(MoOS6,19);(MoS5,1);(MoOS6,107);(MoS5,1);(MoOS6,20);(MoS5,1);(MoOS6,52);(MoS5,1);(MoOS6,78);(MoS5,1);(MoOS6,173);(MoS5,1);(MoOS6,10);(MoS5,1);(MoOS6,45);(MoS5,1);(MoOS6,39);(MoS5,1);(MoOS6,70);(MoS5,1);(MoOS6,39);(MoS5,1);(MoOS6,36);(MoS5,1);(MoOS6,353);(MoOS8,4);(MoS7,1);(MoOS8,155);(MoS7,1);(MoOS8,2);(MoS ...
#        ['(Mo3O9,86);(Mo3O9S2,9);(MoO2,1);(Mo3O9S2,14);(Mo2O4,3);(MoO3,3);(MoO2,19);(MoO,1);(MoO2,8);(MoO,1);(MoO2,10);(MoO,1);(MoO2,1);(MoO,1);(MoO2,3);(MoO,4);(MoO2,1);(MoO,1);(MoO2,1);(MoO,1);(MoO2,2);(MoO,2);(MoO2,1);(MoO,1);(MoO2,2);(MoO,40);(MoOS2,13);(MoS,1);(MoOS2,1);(MoS,1);(MoOS2,2);(MoS,1);(MoOS2,4);(MoS,1);(MoOS2,103);(MoS,1);(MoOS2,1);(MoS,120);(Mo2S5,9);(MoS4,1);(Mo2S5,1);(MoS2,1);(Mo2S5,274);(MoS3,452);(MoS6,91);(MoS8,1);(MoS6,55);(MoS8,1);(MoS6,18);(MoS4,1);(MoS6,167);(MoOS9,14);(MoS8,26);(MoS6,589);(MoOS4,209);(MoS5,6);(Mo2OS8,2);(MoS5,3);(MoOS5,7);(MoS5,129);(MoS7,294);(MoS9,1);(MoS7,2171);(MoS6,18);(MoS8,604);(MoS6,2291);(MoOS7,67);(MoS6,1);(MoOS7,18);(MoS6,1);(MoOS7,3);(MoS6,1);(MoOS7,25);(MoS6,1272);(MoS7,377);(MoS8,388);(MoOS9,399);(MoS8,1);(MoOS9,4);(MoS8,1);(MoOS9,47);(MoS8,1);(MoOS9,255);(MoOS6,225);(MoS5,1);(MoOS6,222);(MoS5,1);(MoOS6,8);(MoS5,1);(MoOS6,147);(MoS5,1);(MoOS6,16);(MoS5,1);(MoOS6,52);(MoS5,1);(MoOS6,109);(MoS5,1);(MoOS6,17);(MoS5,1);(MoOS6,22);(MoS5,1);(MoOS6,3);(MoS5,1);(MoOS6,13);(MoS5,1);(MoOS6,7);(MoS5,1);(MoOS6,30);(MoS5,1);(MoOS6,1);(MoS5,1);(MoOS6,9);(MoS5,1);(MoOS6,58);(MoS5,1);(MoOS6,61);(MoS5,1);(MoOS6,54);(MoS5,1);(MoOS6,14);(MoS5,2);(MoOS6,30);(MoS5,1);(MoOS6,98);(MoS5,1);(MoOS6,3);(MoS5,1);(MoOS6,33);(MoS5,1);(MoOS6,1);(MoS5,1);(MoOS6,1);(MoS5,1);(MoOS6,54);(MoS5,1);(MoOS6,75);(MoS5,1);(MoOS6,67);(MoS5,1);(MoOS6,1);(MoS5,1);(MoOS6,116);(MoS5,1);(MoOS6,5);(MoS5,1);(MoOS6,249);(MoS5,1);(MoOS6,2);(MoS5,1);(MoOS6,10);(MoS5,1);(MoOS6,15);(MoS5,1);(MoOS6,150);(MoS5,1);(MoOS6,3);(MoS5,1);(MoOS6,24);(MoS5,1);(MoOS6,21);(MoS5,1);(MoOS6,33);(MoS5,1);(MoOS6,47);(MoS5,1);(MoOS6,687);(MoOS8,12);(MoOS6,239);(MoO2S7,3);(MoOS6,1);(MoS5,1);(MoO2S7,1);(MoOS6,1);(MoO2S7,1);(MoOS6,110);(MoS5,1);(MoOS6,253);(MoS5,1);(MoOS6,582);(MoS5,1);(MoOS6,4);(MoS5,1);(MoOS6,233);(MoS5,1);(MoOS6,4);(MoS5,1);(MoOS6,16);(MoS5,1);(MoOS6,42);(MoS5,1);(MoOS6,52);(MoS5,1);(MoOS6,54);(MoS5,1);(MoOS6,1);(MoS5,1);(MoOS6,64);(MoS5,1);(MoOS6,5);(MoS5,1);(MoOS6,22);(MoS5,1);(MoOS6,1);(MoS5,1);(MoOS6,3);(MoS5,1);(MoOS6,53);(MoS5,1);(MoOS6,5);(MoS5,1);(MoOS6,138);(MoS5,1);(MoOS6,6);(MoS5,1);(MoOS6,38);(MoS5,1);(MoOS6,175);(MoS5,1);(MoOS6,156);(MoS5,1);(MoOS6,235);(MoS5,1);(MoOS6,10);(MoS5,1);(MoOS6,127);(MoS5,1);(MoOS6,18);(MoS5,1);(MoOS6,14);(MoS5,1);(MoOS6,27);(MoS5,1);(MoOS6,98);(MoS5,1);(MoOS6,3);(MoS5,1);(MoOS6,6);(MoS5,1);(MoOS6,407);(MoS5,1);(MoOS6,11);(MoS5,1);(MoOS6,129);(MoS5,1);(MoOS6,15);(MoS5,1);(MoOS6,25);(MoS5,1);(MoOS6,20);(MoS5,1);(MoOS6,19);(MoS5,1);(MoOS6,255);(MoS5,2);(MoOS6,31);(MoS5,1);(MoOS6,33);(MoS5,1);(MoOS6,7);(MoS5,2);(MoOS6,1);(MoS5,1);(MoOS6,54);(MoS5,1);(MoOS6,1);(MoS5,1);(MoOS6,44);(MoS5,1);(MoOS6,21);(MoS5,1);(MoOS6,104);(MoS5,1);(MoOS6,7);(MoS5,1);(MoOS6,3);(MoS5,1);(MoOS6,1);(MoS5,1);(MoOS6,48);(MoS5,1);(MoOS6,21);(MoS5,1);(MoOS6,33);(MoS5,1);(MoOS6,20);(MoS5,1);(MoOS6,28);(MoS5,1);(MoOS6,51);(MoS5,1);(MoOS6,69);(MoS5,1);(MoOS6,11);(MoS5,1);(MoOS6,23);(MoS5,1);(MoOS6,9);(MoS5,1);(MoOS6,20);(MoS5,1);(MoOS6,19);(MoS5,1);(MoOS6,26);(MoS5,2);(MoOS6,15);(MoS5,1);(MoOS6,9);(MoS5,1);(MoOS6,41);(MoS5,1);(MoOS6,6);(MoS5,1);(MoOS6,70);(MoS5,1);(MoOS6,70);(MoS5,1);(MoOS6,37);(MoS5,1);(MoOS6,2);(MoS5,1);(MoOS6,4);(MoS5,1);(MoOS6,17);(MoS5,1);(MoOS6,6);(MoS5,1);(MoOS6,24);(MoS5,1);(MoOS6,2);(MoS5,1);(MoOS6,7);(MoS5,1);(MoOS6,1);(MoS5,1);(MoOS6,49);(MoS5,1);(MoOS6,19);(MoS5,1);(MoOS6,12);(MoS5,1);(MoOS6,22);(MoS5,1);(MoOS6,34);(MoS5,2);(MoOS6,16);(MoS5,1);(MoOS6,3);(MoS5,1);(MoOS6,34);(MoS5,1);(MoOS6,5);(MoS5,1);(MoOS6,7);(MoS5,2);(MoOS6,8);(MoS5,1);(MoOS6,19);(MoS5,1);(MoOS6,2);(MoS5,1);(MoOS6,7);(MoS5,1);(MoOS6,8);(MoS5,1);(MoOS6,15);(MoS5,1);(MoOS6,12);(MoS5,1);(MoOS6,9);(MoS5,1);(MoOS6,34);(MoS5,1);(MoOS6,10);(MoS5,1);(MoOS6,14);(MoS5,1);(MoOS6,3);(MoS5,2);(MoOS6,44);(MoS5,1);(MoOS6,1);(MoS5,2);(MoOS6,32);(MoS5,1);(MoOS6,3);(MoS5,1);(MoOS6,9);(MoS5,1);(MoOS6,2);(MoS5,1);(MoOS6,8);(MoS5,1);(MoOS6,19);(MoS5,1);(MoOS6,2);(MoS5,1);(MoOS6,36);(MoS5,1);(MoOS6,2);(MoS5,1);(MoOS6,1);(MoS5,1);(MoOS6,38);(Mo ...
#        ['(Mo3O9,86);(Mo3O9S2,14);(MoO2,25);(MoO,2);(MoO2,2);(MoO,1);(MoO2,2);(MoO,1);(MoO2,1);(MoO,1);(MoO2,3);(MoO,2);(MoO2,1);(MoO,1);(MoOS,4);(MoS,2);(MoOS,6);(MoS,1);(MoOS,3);(Mo,1);(MoOS,3);(MoS,1);(MoOS,7);(MoO,1);(MoOS,33);(MoS,1);(MoOS,3);(MoS,1);(MoOS,1);(Mo,1);(MoOS,6);(Mo,1);(MoOS,10);(Mo,1);(MoOS,301);(Mo,1);(MoOS,3);(Mo,1);(MoOS,44);(MoO,2);(MoOS,143);(MoO2S2,4);(MoOS,3);(MoO2S2,7);(MoO2,47);(MoO,1);(MoO2,39);(MoO,1);(MoO2,9);(MoO,1);(MoO2,2);(MoO,1);(MoO2,2);(MoO,1);(MoO2,34);(MoO,1);(MoO2,1);(MoO,1);(MoO2,1);(MoO,1);(MoO2,3);(MoO,1);(MoO2,8);(MoO,1);(MoO2,3);(MoO,1);(MoO2,1);(MoO,1);(MoO2,34);(MoO,1);(MoO2,3);(MoO,1);(MoO2,1);(MoO,1);(MoO2,1);(MoO,1);(MoO2,12);(MoO,1);(MoO2,2);(MoO,2);(MoO2,1);(MoO,380);(MoO2S,2);(MoOS,1);(MoO,231);(MoOS2,1);(MoS,90);(Mo2S5,34);(MoS3,1);(Mo2S5,13);(MoS3,415);(MoS5,527);(MoOS6,5);(MoS5,2);(MoOS6,3);(MoS5,2);(MoOS6,2);(MoS5,1);(MoOS6,2);(MoS5,1);(MoOS6,30);(MoS5,1);(MoOS6,4);(MoS5,2);(MoOS6,2);(MoS5,1);(MoOS6,7);(MoS5,1);(MoOS6,3);(MoS5,1);(MoOS6,5);(MoS5,1);(MoOS6,5);(MoS5,1);(MoOS6,7);(MoS5,543);(MoOS6,2);(MoS5,2);(MoOS6,6);(MoS5,1);(MoOS6,17);(MoS5,1);(MoOS6,12);(MoS5,1);(MoOS6,60);(MoS5,1);(MoOS6,17);(MoS5,1);(MoOS6,19);(MoS5,1);(MoOS6,12);(MoS5,1);(MoOS6,1);(MoS5,1);(MoOS6,18);(MoS5,1);(MoOS6,2);(MoS5,1);(MoOS6,3);(MoS5,1);(MoOS6,31);(MoS5,1);(MoOS6,20);(MoS5,1);(MoOS6,1);(MoS5,2);(MoOS6,13);(MoS5,1);(MoOS6,65);(MoS5,1);(MoOS6,18);(MoS5,1);(MoOS6,45);(MoS5,1);(MoOS6,26);(MoS5,1);(MoOS6,5);(MoS5,1);(MoOS6,6);(MoS5,1);(MoOS6,10);(MoS5,1);(MoOS6,14);(MoS5,1);(MoOS6,9);(MoS5,1);(MoOS6,4);(MoS5,1);(MoOS6,22);(MoS5,1);(MoOS6,5);(MoS5,1);(MoOS6,10);(MoS5,1);(MoOS6,16);(MoS5,1);(MoOS6,31);(MoS5,1);(MoOS6,3);(MoS5,1);(MoOS6,21);(MoS5,1);(MoOS6,27);(MoS5,1);(MoOS6,62);(MoS5,1);(MoOS6,53);(MoS5,1);(MoOS6,3);(MoS5,1);(MoOS6,49);(MoS5,1);(MoOS6,14);(MoS5,1);(MoOS6,6);(MoO2S7,7);(MoOS6,24);(MoS5,1);(MoOS6,6);(MoS5,1);(MoOS6,1);(MoS5,1);(MoOS6,11);(MoS5,1);(MoOS6,14);(MoS5,2);(MoOS6,75);(MoS5,1);(MoOS6,17);(MoS5,1);(MoOS6,37);(MoS5,1);(MoOS6,57);(MoS5,1);(MoOS6,7);(MoS5,1);(MoOS6,7);(MoS5,1);(MoOS6,7);(MoS5,1);(MoOS6,3);(MoS5,1);(MoOS6,7);(MoOS8,1);(MoOS6,52);(MoS5,1);(MoOS6,7);(MoS5,1);(MoOS6,69);(MoS5,2);(MoOS6,10);(MoS5,1);(MoOS6,46);(MoS5,1);(MoOS6,2);(MoS5,1);(MoOS6,9);(MoS5,1);(MoOS6,25);(MoS5,1);(MoOS6,4);(MoS5,1);(MoOS6,11);(MoS5,1);(MoOS6,10);(MoS5,1);(MoOS6,36);(MoS5,1);(MoOS6,3);(MoS5,2);(MoOS6,49);(MoS5,1);(MoOS6,33);(MoS5,1);(MoOS6,7);(MoS5,1);(MoOS6,36);(MoS5,2);(MoOS6,17);(MoS5,1);(MoOS6,4);(MoS5,1);(MoOS6,9);(MoS5,1);(MoOS6,1);(MoS5,1);(MoOS6,26);(MoS5,1);(MoOS6,35);(MoS5,1);(MoOS6,25);(MoS5,1);(MoOS6,17);(MoS5,1);(MoOS6,11);(MoS5,1);(MoOS6,128);(MoO2S7,2);(MoOS6,1);(MoO2S7,2);(MoOS6,1);(MoO2S7,5);(MoOS6,1);(MoO2S7,1);(MoOS6,1);(MoO2S7,5);(MoOS6,1006);(MoO2S7,4);(MoOS6,1);(MoO2S7,4);(MoOS6,1);(MoO2S7,1);(MoOS6,1);(MoO2S7,2);(MoOS6,1);(MoO2S7,3);(MoOS6,1);(MoO2S7,32);(MoOS6,3);(MoO2S7,13);(MoS6,1);(MoO2S7,20);(MoS6,1);(MoO2S7,11);(MoOS6,1);(MoO2S7,1);(MoOS6,476);(MoS5,1);(MoOS6,412);(MoS5,1);(MoOS6,14);(MoS5,1);(MoOS6,7);(MoS5,1);(MoOS6,734);(MoS5,1);(MoOS6,226);(MoO2S7,4);(MoOS6,1);(MoO2S7,5);(MoOS6,1);(MoO2S7,1);(MoOS6,1);(MoO2S7,1);(MoOS6,353);(MoO2S7,1);(MoOS6,41);(MoS5,1);(MoOS6,351);(MoS5,1);(MoOS6,10);(MoS5,1);(MoOS6,113);(MoS5,1);(MoOS6,62);(MoS5,1);(MoOS6,8);(MoS5,1);(MoOS6,78);(MoO2S7,4);(MoOS6,1);(MoO2S7,5);(MoOS6,2);(MoO2S7,2);(MoOS6,1);(MoO2S7,5);(MoOS6,4);(MoO2S7,1);(MoOS6,1);(MoO2S7,1);(MoOS6,3);(MoS5,1);(MoOS6,5);(MoS5,2);(MoOS6,58);(MoS5,1);(MoOS6,398);(MoS5,1);(MoOS6,4);(MoS5,1);(MoOS6,50);(MoS5,1);(MoOS6,122);(MoS5,1);(MoOS6,46);(MoO2S7,3);(MoOS6,76);(MoS5,1);(MoOS6,234);(MoS5,1);(MoOS6,26);(MoS5,1);(MoOS6,31);(MoO2S7,1);(MoOS6,1);(MoO2S7,2);(MoOS6,528);(MoS5,1);(MoOS6,1913);(MoO2S7,1);(MoOS6,899);(MoS5,1);(MoOS6,215);(MoS5,1);(MoOS6,48);(MoS5,1);(MoOS6,124);(MoS5,1);(MoOS6,21);(MoS5,1);(MoOS6,21);(MoS5,1);(MoOS6,24);(MoS5,1);(MoOS6,46);(MoS5,1);(MoOS6,1);(MoS5,1);(MoOS6,34);(MoS5,1);(MoOS6,7);(MoS5,1);(MoOS6,112);(MoS5,1);(MoOS6,14);(MoS5,1);(MoOS6,8);(MoS ...
#        ['(Mo3O9,306);(Mo3O9S2,12);(MoO2,6);(MoO3,2);(Mo2O4,1);(MoO2,14);(MoO,1);(MoO2,7);(MoO,1);(MoO2,1);(MoO,1);(MoO2,2);(MoO,1);(MoO2,5);(MoO,15);(MoOS2,2);(MoO,1);(MoOS2,21);(MoO,20);(MoS,18);(MoS3,6);(MoS,1);(MoS3,42);(MoS,1);(MoS3,2);(MoS,1);(MoS3,150);(Mo2S8,4);(MoS4,190);(MoOS2,55);(MoS,2);(MoOS2,1);(MoS,65);(MoS2,26);(MoS3,14);(Mo2S5,21);(MoS2,1);(Mo2S5,131);(Mo2S8,31);(MoS5,213);(Mo2S8,59);(Mo2S10,16);(MoS4,1);(Mo2S10,62);(MoS6,1);(Mo2S10,23);(MoS5,1);(Mo2S10,36);(MoS6,1);(Mo2S10,21);(MoS6,1);(Mo2S10,9);(MoS6,7);(MoS7,5);(MoS8,10);(MoS6,129);(MoOS7,4);(MoS6,1);(MoOS7,7);(MoS6,2);(MoOS7,4);(MoS6,1);(MoOS7,17);(MoS6,1);(MoOS7,3);(MoS6,1);(MoOS7,8);(MoS6,1);(MoOS7,4);(MoOS5,5);(MoOS7,1);(MoOS5,133);(MoS4,1);(MoOS5,25);(MoS4,1);(MoOS5,81);(MoS4,1);(MoOS5,156);(MoS5,2650);(MoS4,448);(MoO3S6,1154);(MoS6,94);(MoS5,501);(MoO3S6,7);(MoS5,757);(MoO3S8,1347);(MoS5,2007);(MoO3S8,95);(MoO3S9,1126);(MoS7,1137);(MoO3S8,3);(MoS7,510);(MoO3S8,22);(MoS7,235);(MoO3S8,5721);(MoS7,6896);(MoS6,844);(MoS7,297);(MoS6,1915)'],
#        ['(Mo3O9,306);(Mo3O9S2,18);(Mo2O4,1);(MoO2,16);(MoO2S2,2);(MoS,1);(MoO2S2,2);(MoS,1);(MoO2S2,6);(MoS,1);(MoO2S2,33);(MoOS,2);(MoO2S2,11);(MoOS,1);(MoO2S2,13);(MoS,1);(MoOS,1);(MoO2S2,19);(MoOS,5);(MoOS2,66);(MoOS4,3);(MoS3,53);(MoS5,3);(MoS3,74);(MoOS4,5);(MoS3,1);(MoOS4,11);(MoS3,1);(MoOS4,3);(MoS3,1);(MoOS4,10);(MoS3,1);(MoOS4,2);(MoS3,1);(MoOS4,7);(MoS3,1);(MoOS4,35);(MoS3,1);(MoOS4,4);(MoS3,1);(MoOS4,2);(MoS3,1);(MoOS4,14);(MoS3,1);(MoOS4,1);(MoS3,1);(MoOS4,4);(MoS3,2);(MoOS4,22);(MoS3,1);(MoOS4,19);(MoS3,1);(MoOS4,2);(MoS3,1);(MoOS4,1);(MoS3,1);(MoOS4,24);(MoS3,1);(MoOS4,25);(MoS3,1);(MoOS4,9);(MoS3,1);(MoOS4,9);(MoS3,1);(MoOS4,49);(MoS3,1);(MoOS4,37);(MoS3,1);(MoOS4,12);(MoS3,1);(MoOS4,181);(MoS3,1);(MoOS4,40);(MoO2S5,15);(MoOS4,1);(MoO2S5,5);(MoS4,1);(MoO2S5,13);(MoS4,1);(MoO2S5,4);(MoS4,1);(MoO2S5,16);(MoS4,1);(MoO2S5,13);(MoOS4,1);(MoO2S5,11);(MoOS4,1);(MoO2S5,5);(MoOS4,1);(MoO2S5,20);(MoS4,1);(MoO2S5,17);(MoOS4,1);(MoO2S5,1);(MoOS4,1);(MoO2S5,26);(MoOS4,1);(MoO2S5,5);(MoOS4,1);(MoO2S5,6);(MoS3,1);(MoO2S5,17);(MoS4,1);(MoO2S5,1);(MoS4,1);(MoO2S5,7);(MoS4,1);(MoO2S5,4);(MoS4,1);(MoO2S5,3);(MoS4,1);(MoO2S5,6);(MoS4,1);(MoO2S5,15);(MoS4,1);(MoO2S5,5);(MoS4,1);(MoO2S5,5);(MoS4,1);(MoO2S5,10);(MoOS4,1);(MoO2S5,1);(MoOS4,1);(MoO2S5,3);(MoOS4,1);(MoO2S5,21);(MoOS4,1);(MoO2S5,8);(MoOS4,1);(MoO2S5,35);(MoOS4,1);(MoO2S5,29);(MoOS4,1);(MoO2S5,1);(MoOS4,1);(MoO2S5,14);(MoOS4,1);(MoO2S5,13);(MoOS4,1);(MoO2S5,3);(MoOS4,1);(MoO2S5,3);(MoOS4,1);(MoO2S5,7);(MoOS4,1);(MoO2S5,10);(MoOS4,1);(MoO2S5,1);(MoOS4,1);(MoO2S5,1);(MoOS4,1);(MoO2S5,15);(MoOS4,1);(MoO2S5,5);(MoOS4,1);(MoO2S5,9);(MoOS4,1);(MoO2S5,10);(MoOS4,1);(MoO2S5,15);(MoOS4,2);(MoO2S5,29);(MoOS4,1);(MoO2S5,8);(MoOS4,1);(MoO2S5,19);(MoOS4,1);(MoO2S5,3);(MoOS4,2);(MoO2S5,21);(MoOS4,1);(MoO2S5,1);(MoOS4,1);(MoO2S5,2);(MoOS4,1);(MoO2S5,8);(MoOS4,2);(MoO2S5,17);(MoOS4,1);(MoO2S5,9);(MoOS4,1);(MoO2S5,17);(MoOS4,1);(MoO2S5,5);(MoS4,1);(MoO2S5,8);(MoS4,1);(MoO2S5,20);(MoS4,1);(MoO2S5,26);(MoS4,1);(MoO2S5,5);(MoS4,1);(MoO2S5,2);(MoS4,1);(MoO2S5,4);(MoS4,2);(MoO2S5,2);(MoS4,1);(MoO2S5,5);(MoS4,1);(MoO2S5,7);(MoS4,1);(MoO2S5,9);(MoS4,1);(MoO2S5,3);(MoO3S8,1);(MoO2S5,3);(MoS4,1);(MoO2S5,15);(MoO2S8,10);(MoS7,1);(MoO2S8,4);(MoS7,1);(MoO2S8,2);(MoO2S6,24);(MoS5,1);(MoO2S6,4);(MoS5,1);(MoO2S6,17);(MoS5,1);(MoO2S6,50);(Mo2OS9,27);(MoOS6,29);(Mo2OS9,6);(MoOS5,199);(MoS4,1);(MoOS5,21);(MoS4,1);(MoOS5,104);(MoS4,1);(MoOS5,119);(MoS4,1);(MoOS5,12);(MoS4,1);(MoOS5,48);(MoS4,1);(MoOS5,28);(MoS4,1);(MoOS5,50);(MoO2S6,2);(MoOS5,229);(MoS4,1);(MoOS5,9);(MoS4,1);(MoOS5,24);(MoS4,1);(MoOS5,43);(MoS4,1);(MoOS5,5);(MoS4,2);(MoOS5,8);(MoO2S6,8);(MoOS5,1);(MoO2S6,32);(MoS5,1);(MoO2S6,12);(MoS5,1);(MoO2S6,1);(MoO2S8,5);(MoS7,1);(MoO2S6,13);(MoS5,1);(MoO2S6,3);(MoS5,2);(MoO2S6,9);(MoS5,2);(MoO2S6,1);(MoS5,1);(MoO2S6,11);(MoOS5,1);(MoO2S6,4);(MoS5,1);(MoO2S6,30);(MoS5,1);(MoO2S6,29);(MoOS5,1);(MoO2S6,9);(MoOS5,1);(MoO2S6,5);(MoOS5,1);(MoO2S6,2);(MoS5,1);(MoO2S6,6);(MoS5,1);(MoO2S6,14);(MoOS5,1);(MoO3S7,1);(MoO2S6,26);(MoOS5,1);(MoO2S6,4);(MoS5,1);(MoO2S6,1);(MoS5,1);(MoO2S6,11);(MoS5,1);(MoO2S6,16);(MoS5,1);(MoO2S6,1);(MoS5,1);(MoO2S6,2);(MoS5,1);(MoO2S6,2);(MoS5,1);(MoO2S6,42);(MoS5,1);(MoO2S6,12);(MoS5,1);(MoO2S6,13);(MoS5,1);(MoO2S6,1);(MoS5,1);(MoO2S6,4);(MoS5,1);(MoO2S6,1);(MoS5,1);(MoO2S6,7);(MoS5,1);(MoO2S6,2);(MoS5,1);(MoO2S6,9);(MoO2S4,1);(MoO2S6,62);(MoS5,1);(MoO2S6,6);(MoS5,1);(MoO2S6,15);(MoS5,1);(MoO2S6,3);(MoS5,1);(MoO2S6,10);(MoS5,2);(MoO2S6,8);(MoS5,1);(MoO2S6,7);(MoS5,1);(MoO2S6,1);(MoS5,3);(MoO2S6,22);(MoS5,3);(MoO2S6,9);(MoS5,1);(MoO2S6,15);(MoS5,1);(MoO2S6,13);(MoS5,1);(MoO2S6,3);(MoS5,1);(MoO2S6,40);(MoS5,1);(MoO2S6,7);(MoS5,1);(MoO2S6,16);(MoS5,1);(MoO2S6,6);(MoS5,1);(MoO2S6,4);(MoS5,1);(MoO2S6,3);(MoS5,1);(MoO2S6,2);(MoS5,1);(MoO2S6,9);(MoS5,1);(MoO2S6,1);(MoS5,1);(MoO2S6,33);(MoS5,1);(MoO2S6,5);(MoS5,1);(MoO2S6,2);(MoS5,1);(MoO2S6,4);(MoS5,1);(MoO2S6,1);(MoS5,1);(MoO2S6,2);(MoS5,1);(MoO2S6,8);(MoS5,1);(MoO2S6,3);(MoS5,1);(MoO2S6,1);(MoS5,2);(MoO2S6,2);(MoS5,1);(MoO2S6,14);(MoS5,1 ...
#        ['(Mo3O9,306);(Mo3O9S2,15);(MoO2,3);(Mo2O4,1);(MoO2,1);(Mo2O4,1);(MoO3,2);(MoO2,1);(MoO3,1);(MoO2,132);(MoO,1);(MoO2,9);(MoO,1);(MoO2,1);(MoO,1);(MoO2,2);(MoO2S2,1);(MoO2,10);(MoO,44);(MoO2,36);(MoO,1);(MoO2,33);(MoO,1);(MoO2,3);(MoO,1);(MoO2,3);(MoOS,16);(MoOS3,9);(MoOS,1);(MoOS3,10);(MoS2,29);(MoS4,8);(MoS2,297);(MoOS3,5);(MoS2,2);(MoOS3,13);(MoS2,1);(MoOS3,2);(MoS2,1);(MoOS3,6);(MoS2,1);(MoOS3,5);(MoS2,1);(MoOS3,7);(MoS2,2);(MoOS3,65);(MoOS,52);(MoO2S2,1);(MoOS,85);(MoOS3,5);(MoOS,1);(MoOS3,17);(MoS2,84);(MoS4,10);(MoS2,1);(MoS4,3);(MoS2,1);(MoS4,6);(MoS2,1);(MoS4,29);(MoS6,2);(MoS4,175);(Mo2S10,43);(MoS5,1);(Mo2S10,112);(MoOS5,11);(MoS4,1);(MoOS5,4);(MoS4,1);(MoOS5,7);(MoS4,1);(MoOS5,7);(MoS4,1);(MoOS5,9);(MoS4,1);(MoOS5,20);(MoS4,1);(MoOS5,1);(MoS4,1);(MoOS5,1);(MoS4,1);(MoOS5,22);(MoS4,1);(MoOS5,26);(MoS4,1);(MoOS5,7);(MoS4,1);(MoOS5,15);(MoS4,2);(MoOS5,13);(MoS4,1);(MoOS5,20);(MoS4,2);(MoOS5,14);(MoS4,1);(MoOS5,2);(MoS4,1);(MoOS5,3);(MoS4,1);(MoOS5,8);(MoS4,1);(MoOS5,9);(MoS4,1);(MoOS5,18);(MoS4,1);(MoOS5,100);(MoS4,1);(MoOS5,31);(MoS4,1);(MoOS5,16);(MoS4,1);(MoOS5,28);(MoS4,1);(MoOS5,17);(MoS4,1);(MoOS5,11);(MoS4,1);(MoOS5,6);(MoS4,1);(MoOS5,5);(MoS4,1);(MoOS5,8);(MoS4,1);(MoOS5,21);(MoS4,1);(MoOS5,19);(MoS4,1);(MoOS5,6);(MoS4,1);(MoOS5,44);(MoS4,1);(MoOS5,43);(MoS4,1);(MoOS5,37);(MoS4,1);(MoOS5,6);(MoS4,1);(MoOS5,19);(MoS4,1);(MoOS5,26);(MoS4,2);(MoOS5,1);(MoS4,1);(MoOS5,33);(MoS4,1);(MoOS5,14);(MoOS7,3);(MoS6,1);(MoOS7,10);(MoS6,1);(MoOS7,1);(MoS6,1);(MoOS7,3);(MoS6,1);(MoOS7,6);(MoS6,1);(MoOS7,11);(MoOS5,1);(MoOS7,25);(MoS6,1);(MoOS7,7);(MoS6,60);(Mo2S10,11);(MoS5,1);(Mo2S10,100);(Mo2OS8,6);(Mo2S7,1);(Mo2OS8,5);(Mo2S7,1);(Mo2OS8,3);(Mo2S7,1);(Mo2OS8,11);(Mo2S7,1);(Mo2OS8,58);(Mo2S7,1);(Mo2OS8,12);(Mo2S7,1);(Mo2OS8,7);(MoOS5,6);(Mo2OS8,2);(Mo2S7,1);(Mo2OS8,7);(Mo2S7,1);(Mo2OS8,2);(Mo2S7,1);(Mo2OS8,7);(Mo2S7,1);(Mo2OS8,16);(Mo2S7,1);(Mo2OS8,1);(Mo2S7,2);(Mo2OS8,1);(Mo2S7,1);(Mo2OS8,14);(Mo2OS7,259);(MoOS4,1);(Mo2OS7,2);(MoS2,1);(Mo2OS7,2);(MoS4,1);(Mo2OS7,21);(MoS3,45);(MoS5,57);(Mo2S7,34);(Mo2S8,48);(Mo2S7,1);(Mo2S8,10);(MoS5,53);(Mo2S8,31);(MoS7,26);(MoS6,203);(MoOS7,1);(MoS6,2);(MoOS7,63);(MoS6,1);(MoOS7,16);(MoS6,1);(MoOS7,47);(MoS6,1);(MoOS7,6);(MoS6,1);(MoOS7,7);(MoS5,2);(MoOS6,26);(MoS5,1);(MoOS6,11);(MoS5,1);(MoOS6,1);(MoS5,1);(MoOS6,33);(MoS5,1);(MoOS6,45);(MoS5,1);(MoOS6,13);(MoS5,1);(MoOS6,1);(MoS5,1);(MoOS6,14);(MoS5,1);(MoOS6,4);(MoS5,1);(MoOS6,12);(MoS5,1);(MoOS6,4);(MoS5,1);(MoOS6,65);(MoS5,1);(MoOS6,39);(MoS5,1);(MoOS6,138);(MoS5,2);(MoOS6,111);(MoO2S7,2);(MoOS6,1);(MoO2S7,3);(MoOS6,119);(MoO2S7,1);(MoOS6,1);(MoO2S7,1);(MoOS6,1);(MoO2S7,3);(MoOS6,871);(MoO2S7,1);(MoOS6,5);(MoO2S7,1);(MoOS6,1);(MoO2S7,6);(MoOS6,1);(MoO2S7,4);(MoOS6,75);(MoO2S7,2);(MoOS6,967);(MoS5,1);(MoOS6,1);(MoS5,1);(MoOS6,17);(MoS5,1);(MoOS6,4);(MoS5,2);(MoOS6,5);(MoS5,1);(MoOS6,2);(MoS5,1);(MoOS6,152);(MoS5,1);(MoOS6,8);(MoS5,1);(MoOS6,5);(MoS5,1);(MoOS6,2);(MoS5,1);(MoOS6,27);(MoS5,1);(MoOS6,70);(MoS5,1);(MoOS6,276);(MoS5,1);(MoOS6,188);(MoS5,1);(MoOS6,884);(MoO2S7,1);(MoOS6,1020);(MoS5,1);(MoOS6,9);(MoS5,1);(MoOS6,59);(MoS5,1);(MoOS6,284);(MoS5,1);(MoOS6,250);(MoS5,1);(MoOS6,387);(MoS5,1);(MoOS6,240);(MoS5,1);(MoOS6,28);(MoS5,1);(MoOS6,1);(MoS5,1);(MoOS6,18);(MoS5,1);(MoOS6,1864);(MoS5,1);(MoOS6,234);(MoS5,1);(MoOS6,118);(MoS5,1);(MoOS6,60);(MoS5,1);(MoOS6,35);(MoS5,1);(MoOS6,90);(MoS5,1);(MoOS6,1);(MoS5,1);(MoOS6,9);(MoS5,1);(MoOS6,22);(MoS5,1);(MoOS6,57);(MoS5,1);(MoOS6,7);(MoS5,1);(MoOS6,12);(MoS5,1);(MoOS6,12);(MoS5,1);(MoOS6,62);(MoS5,1);(MoOS6,54);(MoS5,1);(MoOS6,49);(MoS5,1);(MoOS6,3);(MoS5,1);(MoOS6,23);(MoS5,1);(MoOS6,190);(MoS5,1);(MoOS6,204);(MoS5,1);(MoOS6,4);(MoS5,1);(MoOS6,1);(MoS5,1);(MoOS6,34);(MoS5,2);(MoOS6,117);(MoS5,1);(MoOS6,4);(MoO2S7,2);(MoOS6,1);(MoO2S7,6);(MoS5,1);(MoOS6,1);(MoO2S7,2);(MoOS6,1);(MoO2S7,250);(MoS6,1);(MoO2S7,278);(MoS6,1);(MoO2S7,190);(MoS6,1);(MoO2S7,1255);(MoS6,1);(MoO2S7,391);(MoO3S8,3);(MoO2S7,1);(MoO3S8,11);(MoO2S7,1);(MoO3S8,1);(MoO2S7,1);(MoO3S8,5);(MoO2S7,1);(MoO3S8,1);(MoO2 ...
#        ['(Mo3O9,77);(Mo3O9S2,9);(Mo2O4,1);(MoO,3);(MoS,17);(MoS3,15);(MoS,1);(MoS2,1);(MoOS3,1);(MoS2,240);(MoS4,3);(MoS2,1);(MoS4,52);(MoOS4,1);(MoS3,2);(MoS,1);(MoS3,3);(MoS,1);(MoS3,2);(MoS,1);(MoS3,8);(MoS,1);(MoS3,128);(MoOS4,6);(MoS3,1);(MoOS4,11);(MoS3,128);(Mo2S8,6);(MoS4,280);(MoS5,5);(Mo2S8,100);(MoS6,362);(MoS8,139);(MoS6,1075);(MoS9,1);(MoS6,1);(MoS9,1);(MoS6,1);(MoS9,1);(MoS6,1);(MoS9,216);(MoS7,20);(MoS9,4);(MoS7,3072);(MoS9,202);(MoS7,20);(MoS6,1013);(MoOS7,1);(MoS6,586);(MoO3S7,1152);(MoO3S9,30);(MoS6,1);(MoO3S9,46);(MoS5,1);(MoO3S9,406);(MoO3S7,1);(MoO3S9,611);(MoOS6,67);(MoO4S7,166);(MoS5,74);(MoO4S7,2318);(MoO4S6,5665);(MoS4,901);(MoO2S5,40);(MoOS5,272);(MoS5,5554);(MoOS5,58);(MoOS6,29);(MoOS5,2668);(MoO2S5,2118)'],
#        ['(Mo3O9,77);(Mo3O9S2,9);(Mo2O4,1);(MoO2,13);(MoO2S2,8);(MoOS,62);(MoOS3,2);(MoOS,22);(MoO2S,1);(MoO,64);(MoOS2,1);(MoO,1);(MoOS2,2);(MoS,271);(MoOS2,18);(MoS,6);(MoS3,5);(MoS,1);(MoS3,132);(MoOS4,12);(MoS3,1);(MoOS4,22);(MoS3,1);(MoOS4,1);(MoS3,70);(MoS2,3);(MoOS,28);(MoOS2,43);(MoO,20);(MoOS,12);(MoS,43);(Mo2S5,15);(MoS3,505);(Mo2S5,95);(MoS3,1);(Mo2S5,210);(MoS5,15);(Mo2S8,72);(MoS6,402);(MoS5,2);(Mo2S10,24);(MoS6,509);(MoO2S8,1);(MoS6,1794);(MoS8,6);(MoS7,20);(MoS9,22);(MoS6,5);(MoS8,105);(MoS10,2);(MoS8,365);(MoS10,3);(MoS8,1110);(MoS6,13);(MoOS6,14);(MoS5,1);(MoOS6,47);(MoS5,1);(MoOS6,7);(MoOS8,1);(MoOS6,49);(MoS5,1);(MoOS6,54);(MoS5,1);(MoOS6,22);(MoS5,1);(MoOS6,203);(MoS5,1);(MoOS6,149);(MoS5,1);(MoOS6,124);(MoS5,1);(MoOS6,57);(MoS5,1);(MoOS6,51);(MoS5,1);(MoOS6,36);(MoS5,1);(MoOS6,5);(MoS5,1);(MoOS6,4);(MoS5,1);(MoOS6,16);(MoS5,2);(MoOS6,79);(MoS5,1);(MoOS6,19);(MoS5,1);(MoOS6,16);(MoS5,1);(MoOS6,11);(MoS5,1);(MoOS6,13);(MoS5,1);(MoOS6,5);(MoS5,1);(MoOS6,22);(MoS5,1);(MoOS6,6);(MoS5,1);(MoOS6,112);(MoS5,1);(MoOS6,16);(MoS5,2);(MoOS6,30);(MoS5,1);(MoOS6,22);(MoS5,1);(MoOS6,9);(MoS5,1);(MoOS6,16);(MoS5,1);(MoOS6,19);(MoS5,2);(MoOS6,21);(MoS5,1);(MoOS6,5);(MoS5,1);(MoOS6,2);(MoS5,1);(MoOS6,14);(MoS5,1);(MoOS6,61);(MoS5,1);(MoOS6,25);(MoS5,1);(MoOS6,29);(MoS5,1);(MoOS6,6);(MoS5,1);(MoOS6,17);(MoS5,1);(MoOS6,80);(MoS5,1);(MoOS6,3);(MoS5,1);(MoOS6,10);(MoS5,2);(MoOS6,10);(MoS5,1);(MoOS6,29);(MoS5,1);(MoOS6,32);(MoS5,1);(MoOS6,1);(MoS5,1);(MoOS6,31);(MoS5,1);(MoOS6,66);(MoS5,1);(MoOS6,57);(MoS5,1);(MoOS6,56);(MoOS8,1);(MoOS6,4);(MoS5,1);(MoOS6,6);(MoS5,1);(MoOS6,36);(MoS5,1);(MoOS6,6);(MoS5,2);(MoOS6,71);(MoS5,1);(MoOS6,101);(MoS5,1);(MoOS6,16);(MoS5,1);(MoOS6,62);(MoS5,1);(MoOS6,17);(MoS5,1);(MoOS6,165);(MoS5,1);(MoOS6,83);(MoS5,1);(MoOS6,26);(MoS5,1);(MoOS6,90);(MoS5,1);(MoOS6,9);(MoS5,1);(MoOS6,41);(MoS5,1);(MoOS6,39);(MoS5,1);(MoOS6,50);(MoS5,1);(MoOS6,6);(MoS5,1);(MoOS6,25);(MoS5,1);(MoOS6,31);(MoS5,1);(MoOS6,54);(MoS5,1);(MoOS6,5);(MoS5,2);(MoOS6,120);(MoS5,1);(MoOS6,7);(MoS5,1);(MoOS6,149);(MoS5,1);(MoOS6,57);(MoS5,1);(MoOS6,1193);(MoS5,1);(MoOS6,112);(MoS5,1);(MoOS6,21);(MoS5,1);(MoOS6,7);(MoS5,1);(MoOS6,3);(MoS5,1);(MoOS6,129);(MoS5,1);(MoOS6,21);(MoS5,1);(MoOS6,14);(MoS5,1);(MoOS6,298);(MoS5,2);(MoOS6,21);(MoS5,1);(MoOS6,37);(MoS5,1);(MoOS6,31);(MoS5,1);(MoOS6,27);(MoS5,1);(MoOS6,77);(MoS5,1);(MoOS6,51);(MoS5,1);(MoOS6,113);(MoS5,1);(MoOS6,226);(MoS5,1);(MoOS6,16);(MoS5,1);(MoOS6,70);(MoO2S7,2);(MoOS6,69);(MoS5,1);(MoOS6,3);(MoS5,1);(MoOS6,16);(MoS5,1);(MoOS6,788);(MoS5,1);(MoOS6,69);(MoS5,1);(MoOS6,23);(MoS5,1);(MoOS6,3);(MoS5,1);(MoOS6,24);(MoS5,1);(MoOS6,21);(MoS5,1);(MoOS6,109);(MoS5,2);(MoOS6,146);(MoS5,1);(MoOS6,72);(MoS5,1);(MoOS6,10);(MoS5,1);(MoOS6,27);(MoS5,1);(MoOS6,32);(MoS5,1);(MoOS6,134);(MoS5,1);(MoOS6,4);(MoS5,2);(MoOS6,1);(MoS5,1);(MoOS6,5);(MoS5,1);(MoOS6,108);(MoS5,1);(MoOS6,78);(MoS5,1);(MoOS6,66);(MoS5,2);(MoOS6,23);(MoS5,1);(MoOS6,7);(MoS5,1);(MoOS6,7);(MoS5,1);(MoOS6,42);(MoS5,1);(MoOS6,47);(MoS5,1);(MoOS6,3);(MoS5,1);(MoOS6,1);(MoS5,1);(MoOS6,114);(MoS5,1);(MoOS6,189);(MoS5,1);(MoOS6,210);(MoO2S7,1);(MoOS6,78);(MoS5,1);(MoOS6,8);(MoS5,1);(MoOS6,70);(MoS5,1);(MoOS6,78);(MoS5,1);(MoOS6,4);(MoS5,1);(MoOS6,30);(MoS5,1);(MoOS6,425);(MoS5,1);(MoOS6,74);(MoS5,1);(MoOS6,10);(MoS5,1);(MoOS6,16);(MoS5,1);(MoOS6,54);(MoS5,1);(MoOS6,20);(MoS5,2);(MoOS6,7);(MoS5,1);(MoOS6,40);(MoS5,1);(MoOS6,6);(MoS5,1);(MoOS6,12);(MoS5,1);(MoOS6,16);(MoS5,1);(MoOS6,11);(MoS5,1);(MoOS6,128);(MoS5,1);(MoOS6,26);(MoS5,1);(MoOS6,8);(MoS5,1);(MoOS6,91);(MoS5,1);(MoOS6,22);(MoS5,1);(MoOS6,100);(MoS5,1);(MoOS6,20);(MoS5,1);(MoOS6,101);(MoS5,1);(MoOS6,10);(MoS5,1);(MoOS6,164);(MoS5,1);(MoOS6,47);(MoS5,1);(MoOS6,293);(MoS5,1);(MoOS6,38);(MoS5,1);(MoOS6,60);(MoS5,1);(MoOS6,44);(MoS5,1);(MoOS6,20);(MoS5,1);(MoOS6,33);(MoS5,1);(MoOS6,16);(MoS5,1);(MoOS6,57);(MoS5,1);(MoOS6,4);(MoS5,1);(MoOS6,2);(MoS5,2);(MoOS6,43);(MoS5,1);(MoOS6,55);(MoS5,1);(MoOS6,71);(MoS5,1);(MoOS6,1);(MoS5,1);(MoOS6,10);(MoS5,1);(MoOS6,676);(MoS5,1);(Mo ...
#        ['(Mo3O9,77);(Mo3O9S2,8);(MoO2,1);(MoO3,1);(MoO2,1);(MoO3,3);(MoO2,33);(MoO,1);(MoO2,2);(MoO,1);(MoO2,26);(MoO,1);(MoO2,8);(MoO,1);(MoOS2,2);(MoS,113);(MoS3,9);(MoS2,1);(MoS3,11);(MoS,1);(MoS3,34);(MoS2,132);(MoS3,4);(MoS,2);(MoS3,3);(MoS,1);(MoS3,20);(MoS,2);(MoS3,2);(MoS,1);(MoS3,18);(MoS,1);(MoS3,18);(MoS,1);(MoS3,138);(MoS5,589);(MoOS6,3);(MoS5,1);(MoOS6,1);(MoS5,1);(MoOS6,6);(MoOS4,1);(MoOS6,11);(MoS5,1);(MoOS6,1);(MoS5,1);(MoOS6,1);(MoS5,1);(MoOS6,9);(MoS5,1);(MoOS6,15);(MoS5,1);(MoOS6,16);(MoS5,1);(MoOS6,22);(MoS5,1);(MoOS6,3);(MoS5,1);(MoOS6,7);(MoS5,1);(MoOS6,4);(MoS5,1);(MoOS6,5);(MoS5,1);(MoOS6,4);(MoS5,1);(MoOS6,8);(MoS5,1);(MoOS6,10);(MoS5,2);(MoOS6,116);(MoO2S4,50);(MoS2,11);(MoOS4,6);(MoS3,1);(MoOS4,3);(MoS3,3);(MoOS4,4);(MoS3,1);(MoOS4,9);(MoS3,1);(MoOS4,16);(MoS3,1);(MoOS4,6);(MoS3,1);(MoOS4,9);(MoS3,1);(MoOS4,9);(MoS3,1);(MoOS4,3);(MoS3,1);(MoOS4,7);(MoOS2,1);(MoOS4,17);(MoS3,1);(MoOS4,9);(MoS3,1);(MoOS4,1);(MoS3,2);(MoOS4,64);(MoS3,1);(MoOS4,42);(MoS3,1);(MoOS4,25);(MoS3,1);(MoOS4,26);(MoS3,1);(MoOS4,1);(MoS3,1);(MoOS4,4);(MoS3,1);(MoOS4,3);(MoS3,1);(MoOS4,3);(MoS3,2);(MoOS4,20);(MoS3,1);(MoOS4,49);(MoS3,1);(MoOS4,13);(MoS3,1);(MoOS4,11);(MoS3,1);(MoOS4,9);(MoS3,1);(MoOS4,12);(MoS3,1);(MoOS4,4);(MoS3,3);(MoOS4,39);(MoS3,1);(MoOS4,14);(MoS3,1);(MoOS4,47);(MoS3,1);(MoOS4,13);(MoS3,1);(MoOS4,15);(MoS3,1);(MoOS4,88);(MoS3,1);(MoOS4,209);(MoS3,1);(MoOS4,180);(MoOS6,25);(MoS5,1);(MoOS6,1);(MoOS4,1);(MoOS6,25);(MoS5,1);(MoOS6,23);(MoS5,1);(MoOS6,2);(MoS5,1);(MoOS6,21);(MoS5,1);(MoOS6,6);(MoS5,1);(MoOS6,8);(MoS5,1);(MoOS6,7);(MoS5,1);(MoOS6,1);(MoS5,1);(MoOS6,3);(MoS5,1);(MoOS6,8);(MoS5,1);(MoOS6,10);(MoS5,1);(MoOS6,7);(MoS5,1);(MoOS6,6);(MoS5,2);(MoOS6,2);(MoS5,1);(MoOS6,4);(MoS5,1);(MoOS6,10);(MoS5,1);(MoOS6,17);(MoS5,1);(MoOS6,10);(MoS5,1);(MoOS6,3);(MoS5,1);(MoOS6,8);(MoS5,1);(MoOS6,13);(MoS5,1);(MoOS6,6);(MoS5,1);(MoOS6,3);(MoS5,1);(MoOS6,1);(MoS5,1);(MoOS6,28);(MoS5,2);(MoOS6,5);(MoS5,1);(MoOS6,18);(MoS5,1);(MoOS6,8);(MoS5,1);(MoOS6,14);(MoS5,2);(MoOS6,1);(MoS5,1);(MoOS6,2);(MoS5,1);(MoOS6,13);(MoS5,1);(MoOS6,3);(MoS5,1);(MoOS6,6);(MoS5,1);(MoOS6,1);(MoS5,1);(MoOS6,9);(MoS5,1);(MoOS6,2);(MoS5,1);(MoOS6,4);(MoS5,1);(MoOS6,1);(MoS5,1);(MoOS6,21);(MoS5,1);(MoOS6,11);(MoS5,1);(MoOS6,7);(MoS5,1);(MoOS6,3);(MoS5,1);(MoOS6,4);(MoS5,1);(MoOS6,5);(MoS5,1);(MoOS6,3);(MoS5,1);(MoOS6,7);(MoS5,1);(MoOS6,4);(MoS5,1);(MoOS6,4);(MoS5,1);(MoOS6,17);(MoS5,1);(MoOS6,15);(MoS5,1);(MoOS6,5);(MoS5,1);(MoOS6,13);(MoS5,1);(MoOS6,10);(MoS5,1);(MoOS6,7);(MoS5,1);(MoOS6,8);(MoS5,1);(MoOS6,2);(MoS5,1);(MoOS6,4);(MoS5,1);(MoOS6,24);(MoS5,1);(MoOS6,21);(MoS5,1);(MoOS6,10);(MoS5,2);(MoOS6,5);(MoO2S7,1);(MoOS6,23);(MoS5,1);(MoOS6,6);(MoS5,1);(MoOS6,2);(MoS5,1);(MoOS6,91);(MoS5,1);(MoOS6,43);(MoS5,1);(MoOS6,36);(MoS5,1);(MoOS6,23);(MoS5,1);(MoOS6,43);(MoS5,1);(MoOS6,18);(MoS5,1);(MoOS6,7);(MoS5,1);(MoOS6,41);(MoS5,1);(MoOS6,510);(MoS5,1);(MoOS6,26);(MoS5,1);(MoOS6,664);(MoS5,1);(MoOS6,2);(MoS5,1);(MoOS6,17);(MoS5,1);(MoOS6,18);(MoOS8,2);(MoS7,1);(MoOS8,32);(MoS7,1);(MoOS8,64);(MoOS6,151);(MoS5,1);(MoOS6,7);(MoS5,1);(MoOS6,52);(MoS5,2);(MoOS6,19);(MoS5,1);(MoOS6,11);(MoS5,1);(MoOS6,13);(MoS5,1);(MoOS6,3);(MoS5,1);(MoOS6,206);(MoS5,1);(MoOS6,112);(MoS5,1);(MoOS6,383);(MoS5,1);(MoOS6,355);(MoS5,1);(MoOS6,64);(MoS5,1);(MoOS6,95);(MoS5,1);(MoOS6,87);(MoS5,1);(MoOS6,41);(MoO2S7,1);(MoOS6,104);(MoS5,1);(MoOS6,43);(MoS5,1);(MoOS6,7);(MoS5,1);(MoOS6,8);(MoS5,1);(MoOS6,330);(MoS5,1);(MoOS6,1);(MoS5,1);(MoOS6,24);(MoS5,2);(MoOS6,25);(MoS5,1);(MoOS6,32);(MoS5,2);(MoOS6,11);(MoS5,1);(MoOS6,79);(MoS5,2);(MoOS6,8);(MoOS8,1);(MoOS6,89);(MoS5,1);(MoOS6,192);(MoS5,1);(MoOS6,148);(MoS5,1);(MoOS6,134);(MoS5,1);(MoOS6,46);(MoS5,1);(MoOS6,1);(MoS5,1);(MoOS6,1);(MoS5,1);(MoOS6,14);(MoS5,1);(MoOS6,4);(MoS5,1);(MoOS6,28);(MoS5,1);(MoOS6,32);(MoS5,1);(MoOS6,28);(MoS5,1);(MoOS6,32);(MoS5,1);(MoOS6,18);(MoS5,1);(MoOS6,25);(MoS5,1);(MoOS6,8);(MoS5,1);(MoOS6,11);(MoS5,1);(MoOS6,7);(MoS5,1);(MoOS6,10);(MoS5,3);(MoOS6,154);(MoS5,1);(MoOS6,10);(MoS5,1);(MoOS6,12);(MoS ...
# ...
#        ['(Mo3O9,178);(Mo3O9S2,1);(Mo3O9,1);(Mo3O9S2,17);(MoO3,1);(MoO2,2);(Mo2O4,2);(MoO3,1);(Mo2O4,2);(MoO2,32);(MoO,1);(MoO2,5);(MoO,2);(MoO2,10);(MoO,1);(MoO2,49);(MoO,1);(MoO2,4);(MoO,1);(MoO2,1);(MoO,1);(MoO2,57);(MoO,1);(MoO2,47);(MoO,1);(MoO2,1);(MoO,2);(MoO2,9);(MoO,2);(MoO2,3);(MoO,1);(MoO2,1);(MoO,1);(MoO2,1);(MoO,1);(MoO2,3);(MoO,136);(MoO2S,4);(MoOS2,1081);(MoOS4,9);(MoS3,1);(MoOS4,25);(MoS3,1);(MoOS4,33);(MoS3,1);(MoOS4,3);(MoS3,1);(MoOS4,4);(MoS3,1);(MoOS4,5);(MoS3,38);(MoS5,14);(MoS7,1);(MoS5,724);(MoOS6,2);(MoS5,1);(MoOS6,15);(MoS5,1);(MoOS6,3);(MoS5,1);(MoOS6,3);(MoS5,1);(MoOS6,55);(MoS5,1);(MoOS6,15);(MoS5,1);(MoOS6,14);(MoS5,1);(MoOS6,4);(MoS5,1);(MoOS6,10);(MoS5,1);(MoOS6,17);(MoS4,1);(MoOS6,4);(MoS5,1);(MoOS6,4);(MoS5,1);(MoOS6,11);(MoS5,1);(MoOS6,11);(MoS5,1);(MoOS6,9);(MoS5,1);(MoOS6,1);(MoS5,1);(MoOS6,1);(MoS5,1);(MoOS6,5);(MoS5,1);(MoOS6,7);(MoS5,1);(MoOS6,6);(MoS5,1);(MoOS6,66);(MoOS4,1);(MoOS6,2);(MoS5,1);(MoOS6,6);(MoS5,1);(MoOS6,5);(MoS5,1);(MoOS6,6);(MoS5,1);(MoOS6,15);(MoS5,1);(MoOS6,25);(MoS5,1);(MoOS6,2);(MoS5,1);(MoOS6,97);(MoS5,1);(MoOS6,64);(MoS5,1);(MoOS6,99);(MoS5,2);(MoOS6,79);(MoS5,1);(MoOS6,34);(MoS5,1);(MoOS6,10);(MoS5,1);(MoOS6,48);(MoS5,1);(MoOS6,170);(MoO2S7,6);(MoOS6,1);(MoO2S7,1);(MoOS6,1);(MoS5,2);(MoOS6,38);(MoS5,1);(MoOS6,244);(MoS5,1);(MoOS6,23);(MoS5,1);(MoOS6,26);(MoS5,1);(MoOS6,70);(MoS5,1);(MoOS6,128);(MoS5,1);(MoOS6,49);(MoS5,1);(MoOS6,886);(MoS5,1);(MoOS6,48);(MoS5,1);(MoOS6,4);(MoO2S7,2);(MoOS6,1);(MoO2S7,3);(MoOS6,1);(MoO2S7,5);(MoOS6,2);(MoO2S7,4);(MoOS6,1);(MoO2S7,2);(MoOS6,1);(MoO2S7,4);(MoOS6,1);(MoO2S7,1);(MoOS6,1);(MoO2S7,6);(MoOS6,2);(MoO2S7,2);(MoOS6,3);(MoO2S7,100);(MoS6,1);(MoO2S7,14);(MoS6,1);(MoO2S7,53);(MoS6,1);(MoO2S7,412);(MoS6,1);(MoO2S7,15);(MoS6,1);(MoO2S7,58);(Mo2OS9,27);(Mo2S8,1);(Mo2OS9,22);(MoOS4,1);(Mo2OS9,7);(Mo2S8,2);(Mo2OS9,4);(Mo2S8,1);(Mo2OS9,15);(Mo2S8,1);(Mo2OS9,11);(Mo2S8,1);(Mo2OS9,10);(Mo2S8,1);(Mo2OS9,11);(Mo2S8,2);(Mo2OS9,34);(Mo2S8,1);(Mo2OS9,2);(Mo2S8,1);(Mo2OS9,1);(Mo2S8,1);(Mo2OS9,1);(Mo2S8,1);(Mo2OS9,6);(Mo2S8,1);(Mo2OS9,1);(Mo2S8,1);(Mo2OS9,6);(Mo2S8,2);(Mo2OS9,7);(Mo2S8,1);(Mo2OS9,11);(Mo2S8,1);(Mo2OS9,37);(Mo2S8,1);(Mo2OS9,23);(MoOS4,1);(Mo2OS9,22);(Mo2OS8,18);(MoS4,2);(Mo2OS8,1);(MoOS5,1);(Mo2OS8,13);(Mo2S7,1);(Mo2OS8,1);(MoS3,115);(MoS2,70);(MoS5,327);(MoS4,178);(MoS5,12);(MoS6,988);(MoOS7,1);(MoS6,1);(MoOS7,1);(MoS6,1);(MoOS7,3);(MoS6,2);(MoOS7,2);(MoS6,689);(MoS7,77);(MoOS6,329);(MoOS5,12);(MoOS6,634);(MoS5,1);(MoOS6,10);(MoS5,1);(MoOS6,291);(MoS5,1);(MoOS6,121);(MoS5,1);(MoOS6,55);(MoS5,1);(MoOS6,211);(MoS5,1);(MoOS6,38);(MoS5,1);(MoOS6,4);(MoS5,2);(MoOS6,12);(MoS5,1);(MoOS6,28);(MoS5,1);(MoOS6,4);(MoS5,1);(MoOS6,455);(MoS5,1);(MoOS6,8);(MoS5,1);(MoOS6,1079);(MoS5,1);(MoOS6,112);(MoS5,1);(MoOS6,222);(MoOS7,464);(MoS6,1);(MoOS7,490);(MoS6,1);(MoOS7,13);(MoS6,1);(MoOS7,13);(MoS6,1);(MoOS7,283);(MoS6,1);(MoOS7,52);(MoS6,1);(MoOS7,83);(MoS6,1);(MoOS7,133);(MoS6,1);(MoOS7,164);(MoOS9,1);(MoOS6,24);(MoS5,1);(MoOS6,1);(MoS5,1);(MoOS6,23);(MoS5,1);(MoOS6,12);(MoS5,1);(MoOS6,30);(MoS5,1);(MoOS6,83);(MoS5,1);(MoOS6,5);(MoS5,1);(MoOS6,107);(MoS5,1);(MoOS6,1);(MoS5,1);(MoOS6,25);(MoS5,1);(MoOS6,142);(MoS5,1);(MoOS6,61);(MoS5,1);(MoOS6,61);(MoS5,1);(MoOS6,403);(MoS5,1);(MoOS6,48);(MoS5,1);(MoOS6,23);(MoS5,1);(MoOS6,14);(MoS5,1);(MoOS6,269);(MoS5,1);(MoOS6,1);(MoS5,1);(MoOS6,119);(MoS5,1);(MoOS6,565);(MoS5,1);(MoOS6,13);(MoS5,1);(MoOS6,277);(MoS5,1);(MoOS6,2);(MoS5,1);(MoOS6,453);(MoS5,1);(MoOS6,8541);(MoS5,4689);(Mo2S10,132)'],
#        ['(Mo3O9,542);(Mo3O9S2,2);(Mo3O9,1);(Mo3O9S2,9);(Mo3O9,3);(Mo3O9S2,23);(MoO,1);(MoO2S,17);(MoO,1);(MoO2S,16);(MoO,1);(MoO2S,6);(MoO,1);(MoO2S,18);(MoO2S3,2);(MoS2,1);(MoOS2,7);(MoS,2);(MoOS2,30);(MoS,1);(MoOS2,2);(MoS,2);(MoOS2,12);(MoS,1);(MoOS2,14);(MoS,1);(MoOS2,8);(MoS,1);(MoOS2,25);(MoS,1);(MoOS2,19);(MoS,1);(MoOS2,6);(MoS,1);(MoOS2,14);(MoS,1);(MoOS2,3);(MoOS4,6);(MoS3,1);(MoOS4,4);(MoOS2,1);(MoOS4,4);(MoS3,1);(MoOS4,2);(MoS3,233);(MoOS4,32);(MoS3,1);(MoOS4,51);(MoO2S5,1);(MoOS4,16);(MoS3,1);(MoOS4,122);(MoS4,50);(MoOS6,16);(MoOS5,4);(MoOS4,16);(MoS3,1);(MoOS4,19);(MoO2S5,2);(MoOS4,43);(MoOS5,8);(MoS4,1);(MoOS5,3);(MoS4,1);(MoOS5,1);(MoOS3,1);(MoOS5,4);(MoS4,1);(MoOS5,4);(MoS4,549);(MoOS6,41);(MoS5,1);(MoOS6,13);(MoS5,2);(MoOS6,11);(MoS5,1);(MoOS6,112);(Mo2S10,3);(MoOS5,13);(Mo2S10,932);(MoOS5,39);(MoO2S7,6);(MoO2S6,92);(MoS5,1);(MoO2S6,2);(MoS5,1);(MoO2S6,3);(MoS5,2);(MoO2S6,21);(MoS5,1);(MoO2S6,4);(MoS5,1);(MoO2S6,22);(MoS5,1);(MoO2S6,15);(MoS5,1);(MoO2S6,8);(MoS5,1);(MoO2S6,4);(MoS5,1);(MoO2S6,16);(MoS5,1);(MoO2S6,12);(MoS5,1);(MoO2S6,7);(MoS5,1);(MoO2S6,4);(MoS5,1);(MoO2S6,11);(MoS5,1);(MoO2S6,11);(MoS5,1);(MoO2S6,11);(MoS5,2);(MoO2S6,16);(MoS5,1);(MoO2S6,3);(MoS5,1);(MoO2S6,10);(MoS5,2);(MoO2S6,7);(MoS5,1);(MoO2S6,5);(MoS5,1);(MoO2S6,9);(MoS5,2);(MoO2S6,5);(MoS5,1);(MoO2S6,2);(MoS5,1);(MoO2S6,3);(MoS5,1);(MoO2S6,28);(MoS5,1);(MoO2S6,2);(MoS5,2);(MoO2S6,4);(MoS5,1);(MoO2S6,24);(MoS5,1);(MoO2S6,7);(MoS5,1);(MoO2S6,6);(MoS5,1);(MoO2S6,38);(MoS5,1);(MoO2S6,4);(MoS5,1);(MoO2S6,16);(MoS5,1);(MoO2S6,2);(MoS5,1);(MoO2S6,5);(MoS5,1);(MoO2S6,2);(MoS5,1);(MoO2S6,39);(MoS5,1);(MoO2S6,6);(MoS5,1);(MoO2S6,13);(MoS5,1);(MoO2S6,25);(MoS5,1);(MoO2S6,18);(MoS5,1);(MoO2S6,7);(MoS5,1);(MoO2S6,23);(MoS5,1);(MoO2S6,4);(MoS5,1);(MoO2S6,6);(MoS5,2);(MoO2S6,74);(MoS5,1);(MoO2S6,26);(MoS5,1);(MoO2S6,18);(MoS5,1);(MoO2S6,6);(MoS5,1);(MoO2S6,3);(MoS5,1);(MoO2S6,11);(MoS5,1);(MoO2S6,22);(MoS5,1);(MoO2S6,4);(MoS5,1);(MoO2S6,16);(MoS5,1);(MoO2S6,6);(MoS5,1);(MoO2S6,2);(MoS5,1);(MoO2S6,7);(MoS5,1);(MoO2S6,14);(MoS5,1);(MoO2S6,6);(MoS5,1);(MoO2S6,29);(MoS5,1);(MoO2S6,9);(MoS5,1);(MoO2S6,14);(MoS5,1);(MoO2S6,3);(MoS5,1);(MoO2S6,4);(MoS5,1);(MoO2S6,3);(MoS5,1);(MoO2S6,5);(MoS5,1);(MoO2S6,7);(MoS5,1);(MoO2S6,2);(MoS5,1);(MoO2S6,12);(MoS5,1);(MoO2S6,47);(MoS5,1);(MoO2S6,10);(MoS5,1);(MoO2S6,7);(MoS5,1);(MoO2S6,32);(MoS5,1);(MoO2S6,5);(MoS5,1);(MoO2S6,14);(MoS5,2);(MoO2S6,75);(MoS5,1);(MoO2S6,4);(MoS5,1);(MoO2S6,3);(MoS5,1);(MoO2S6,35);(MoO3S7,8);(MoO2S6,2);(MoO3S7,14);(MoS5,1);(MoO3S7,8);(MoO2S6,1);(MoO3S7,4);(MoO2S6,119);(MoS5,1);(MoO2S6,37);(MoS5,1);(MoO2S6,64);(MoS5,3);(MoO2S6,6);(MoS5,1);(MoO2S6,8);(MoS5,1);(MoO2S6,1);(MoS5,1);(MoO2S6,51);(MoS5,1);(MoO2S6,1);(MoS5,1);(MoO2S6,16);(MoS5,1);(MoO2S6,11);(MoS5,1);(MoO2S6,3);(MoS5,1);(MoO2S6,6);(MoS5,1);(MoO2S6,26);(MoS5,1);(MoO2S6,8);(MoS5,1);(MoO2S6,71);(MoS5,2);(MoO2S6,88);(MoS5,1);(MoO2S6,5);(MoS5,1);(MoO2S6,2);(MoS5,1);(MoO2S6,45);(MoS5,3);(MoO2S6,7);(MoS5,1);(MoO2S6,1);(MoS5,1);(MoO2S6,8);(MoS5,1);(MoO2S6,6);(MoS5,1);(MoO2S6,30);(MoS5,1);(MoO2S6,21);(MoS5,1);(MoO2S6,18);(MoS5,1);(MoO2S6,18);(MoS5,1);(MoO2S6,9);(MoS5,1);(MoO2S6,2);(MoS5,1);(MoO2S6,40);(MoS5,1);(MoO2S6,4);(MoS5,2);(MoO2S6,31);(MoS5,1);(MoO2S6,14);(MoS5,1);(MoO2S6,5);(MoS5,1);(MoO2S6,7);(MoS5,1);(MoO2S6,6);(MoS5,1);(MoO2S6,6);(MoS5,2);(MoO2S6,43);(MoS5,1);(MoO2S6,29);(MoS5,1);(MoO2S6,10);(MoS5,1);(MoO2S6,57);(MoS5,1);(MoO2S6,12);(MoS5,2);(MoO2S6,15);(MoS5,1);(MoO2S6,9);(MoS5,1);(MoO2S6,66);(MoS5,1);(MoO2S6,3);(MoO2S8,13);(MoS7,1);(MoO2S8,2);(MoS7,1);(MoO2S8,64);(MoS7,2);(MoO2S8,15);(MoS7,1);(MoO2S8,19);(MoS7,1);(MoO2S8,13);(MoS7,1);(MoO2S8,507);(MoS7,103);(MoS6,2065);(MoS9,1);(MoS6,763);(MoS9,1);(MoS6,1206);(MoS8,165);(MoOS9,2);(MoS8,2861);(MoS6,3439);(MoOS7,3);(MoS6,3487);(MoOS7,8);(MoS6,1);(MoOS7,1);(MoS6,1);(MoOS7,4);(MoS6,1);(MoOS7,5);(MoS6,1);(MoOS7,7);(MoS6,1);(MoOS7,2);(MoS6,4);(MoOS7,4);(MoS6,1);(MoOS7,1);(MoS6,1);(MoOS7,13);(MoS6,1);(MoOS7,2);(MoS6,1);(MoOS7,2);(MoS6,1);(MoOS7,1);(MoS6,4);(MoOS7,3);(MoS6,3);(MoOS7,2);( ...
#        ['(Mo3O9,542);(Mo3O9S2,2);(Mo3O9,1);(Mo3O9S2,9);(Mo3O9,3);(Mo3O9S2,17);(MoO2S,6);(MoO2,16);(MoO,1);(MoO2,16);(MoO,1);(MoO2,9);(MoO,1);(MoO2,2);(MoO,1);(MoO2,1);(MoO,215);(MoS2,2);(MoOS,252);(MoOS4,2);(MoS3,1);(MoOS4,6);(MoS3,134);(MoOS4,3);(MoS3,2);(MoOS4,4);(MoOS5,7);(MoS4,1);(MoOS5,8);(MoS4,1);(MoOS5,1);(MoS4,1);(MoOS5,13);(MoS4,2);(MoOS5,9);(MoS4,1);(MoOS5,10);(MoS4,1);(MoOS5,2);(MoS4,1);(MoOS5,5);(MoS4,1);(MoOS5,9);(MoS4,1);(MoOS5,4);(MoS4,1);(MoOS5,1);(MoS4,1);(MoOS5,1);(MoS4,1);(MoOS5,10);(MoS4,2);(MoOS5,22);(MoS4,1);(MoOS5,7);(MoS4,1);(MoOS5,23);(MoS4,1);(MoOS5,13);(MoO2S6,2);(MoOS5,4);(MoS4,1);(MoOS5,45);(MoS4,1);(MoOS5,7);(MoS4,6);(MoOS5,7);(MoS4,1);(MoOS5,1);(MoS4,1);(MoOS5,27);(MoS4,1);(MoOS5,1);(MoS4,1);(MoOS5,5);(MoS4,2);(MoOS5,17);(MoS4,1);(MoOS5,19);(MoS4,1);(MoOS5,14);(MoS4,1);(MoOS5,3);(MoS4,1);(MoOS5,9);(MoS4,1);(MoOS5,8);(MoS4,2);(MoOS5,15);(MoS4,2);(MoOS5,24);(MoS4,1);(MoOS5,12);(MoS4,1);(MoOS5,6);(MoS4,1);(MoOS5,14);(MoS4,1);(MoOS5,18);(MoS4,1);(MoOS5,20);(MoS4,1);(MoOS5,5);(MoS4,1);(MoOS5,8);(MoS4,3);(MoOS5,5);(MoS4,1);(MoOS5,1);(MoS4,1);(MoOS5,14);(MoS4,1);(MoOS5,12);(MoS4,1);(MoOS5,1);(MoS4,1);(MoOS5,6);(MoS4,1);(MoOS5,2);(MoS4,1);(MoOS5,8);(MoS4,1);(MoOS5,15);(MoS4,1);(MoOS5,8);(MoS4,1);(MoOS5,6);(MoS4,1);(MoOS5,2);(MoOS7,1);(MoOS5,12);(MoS4,1);(MoOS5,9);(MoS4,1);(MoOS5,22);(MoOS7,11);(MoS6,711);(MoOS7,1);(MoS6,2943);(MoOS7,1);(MoS6,1);(MoOS7,4);(MoS6,2);(MoOS7,3);(MoS6,1249);(MoOS7,1);(MoS6,1);(MoOS7,14);(MoS6,1);(MoOS7,1);(MoS6,1441);(MoOS7,5);(MoS6,139);(MoOS7,178);(MoS6,1);(MoOS7,4);(MoS6,4);(MoOS7,8);(MoS6,1);(MoOS7,1);(MoS6,1);(MoOS7,7);(MoS6,2);(MoOS7,2);(MoS6,1);(MoOS7,1);(MoS6,1);(MoOS7,16);(MoS6,1);(MoOS7,4);(MoS6,1);(MoOS7,1);(MoS6,1);(MoOS7,627);(MoS6,1);(MoOS7,22);(MoS6,1);(MoOS7,101);(MoS6,1);(MoOS7,2);(MoS6,1);(MoOS7,106);(MoS6,1);(MoOS7,3);(MoS6,1);(MoOS7,298);(MoS6,2);(MoOS7,1);(MoS6,1);(MoOS7,3);(MoS6,1);(MoOS7,1);(MoS6,1);(MoOS7,3);(MoS6,6);(MoOS7,33);(MoS6,1);(MoOS7,3);(MoS6,1);(MoOS7,52);(MoS6,1);(MoOS7,35);(MoS6,1);(MoOS7,190);(MoS6,1);(MoOS7,53);(MoS6,1);(MoOS7,100);(MoS6,1);(MoOS7,1);(MoS6,1);(MoOS7,7);(MoS6,1);(MoOS7,32);(MoS6,1);(MoOS7,112);(MoS6,1);(MoOS7,2);(MoS6,2);(MoOS7,3);(MoS6,1);(MoOS7,2);(MoS6,2);(MoOS7,3);(MoS6,1778);(MoS7,1337);(MoS9,571);(MoS10,77);(MoS8,94);(MoS6,4157);(MoOS7,1);(MoS6,1);(MoOS7,4);(MoS6,2683);(MoOS7,50);(MoS6,1);(MoOS7,1);(MoS6,1);(MoOS7,18);(MoS6,1);(MoOS7,5);(MoS6,1);(MoOS7,45);(MoS6,1);(MoOS7,12);(MoS6,8695)'],
#        ['(Mo3O9,542);(Mo3O9S2,2);(Mo3O9,1);(Mo3O9S2,9);(Mo3O9,3);(Mo3O9S2,20);(MoO,15);(MoO2S,2);(MoO,1);(MoO2S,1);(MoO,422);(MoOS,1);(MoO,136);(MoO2S,22);(MoO,122);(MoO2S3,2);(MoOS2,3);(MoOS5,2);(MoOS3,65);(Mo2OS9,2);(MoOS3,333);(MoOS5,5);(MoS4,1);(MoOS5,1);(MoS4,1);(MoOS5,3);(MoS4,1);(MoOS5,4);(MoS4,1);(MoOS5,3);(MoS4,1);(MoOS5,3);(MoS4,1);(MoOS5,1);(MoS4,3);(MoOS5,23);(MoS4,1);(MoOS5,3);(MoS4,1);(MoOS5,1);(MoS4,2);(MoOS5,9);(MoS4,2);(MoOS5,3);(MoOS3,1);(MoOS5,2);(MoS4,264);(Mo2S5,85);(Mo2S7,14);(MoS6,86);(MoS5,33);(Mo2S8,18);(MoS4,1);(Mo2S8,20);(Mo2S10,41);(MoS6,1);(Mo2S10,3);(Mo2S8,1);(Mo2S10,77);(MoS6,1);(Mo2S10,11);(MoS4,1);(Mo2S10,126);(Mo2S8,179);(MoS4,1);(Mo2S8,45);(Mo2S10,1);(Mo2S8,270);(Mo2OS9,6);(Mo2S8,2);(Mo2OS9,4);(Mo2S8,2);(Mo2OS9,9);(Mo2S8,1);(Mo2OS9,1);(Mo2S8,1);(Mo2OS9,14);(MoS4,1);(Mo2OS9,13);(Mo2S8,1);(Mo2OS9,24);(Mo2S8,1);(Mo2OS9,9);(Mo2S8,1);(Mo2OS9,6);(Mo2S8,1);(Mo2OS9,2);(Mo2S8,1);(Mo2OS9,11);(Mo2S8,1);(Mo2OS9,31);(Mo2S8,1);(Mo2OS9,15);(Mo2S8,1);(Mo2OS9,22);(Mo2S8,1);(Mo2OS9,14);(Mo2S8,1);(Mo2OS9,6);(Mo2S8,1);(Mo2OS9,17);(Mo2S8,1);(Mo2OS9,9);(Mo2S8,1);(Mo2OS9,2);(Mo2S8,1);(Mo2OS9,96);(Mo2OS7,41);(Mo2OS8,4);(Mo2S10,580);(MoS4,1);(Mo2S10,125);(MoOS5,6);(MoS4,1);(MoOS5,2);(MoS4,1);(MoOS5,6);(MoS4,1);(MoOS5,46);(MoS4,1);(MoOS5,68);(MoS4,1);(MoOS5,21);(MoS4,1);(MoOS5,3);(MoS4,1);(MoOS5,13);(MoS4,1);(MoOS5,11);(MoS4,1);(MoOS5,2);(MoS4,1);(MoOS5,34);(MoS4,1);(MoOS5,29);(MoS4,1);(MoOS5,18);(MoS4,1);(MoOS5,5);(MoS4,1);(MoOS5,20);(MoS4,1);(MoOS5,4);(MoS4,1);(MoOS5,28);(MoOS7,18);(MoS4,1);(MoOS5,41);(MoS4,1);(MoOS5,13);(MoS4,1);(MoOS5,13);(MoS4,1);(MoOS5,35);(MoS4,1);(MoOS5,55);(MoS4,1);(MoOS5,64);(MoS4,1);(MoOS5,8);(MoS4,1);(MoOS5,17);(MoS4,1);(MoOS5,102);(MoS4,1);(MoOS5,25);(MoOS6,107);(MoS5,1);(MoOS6,7);(MoS5,1);(MoOS6,35);(MoS5,1);(MoOS6,189);(MoS5,1);(MoOS6,116);(MoS5,1);(MoOS6,127);(MoS5,1);(MoOS6,13);(MoS5,1);(MoOS6,115);(MoS5,1);(MoOS6,406);(MoS5,1);(MoOS6,29);(MoS5,1);(MoOS6,164);(MoS5,1);(MoOS6,5);(MoS5,1);(MoOS6,15);(MoS5,1);(MoOS6,23);(MoS5,1);(MoOS6,92);(MoS5,1);(MoOS6,130);(MoS5,1);(MoOS6,11);(MoS5,1);(MoOS6,108);(MoS5,1);(MoOS6,71);(MoS5,1);(MoOS6,78);(MoS5,1);(MoOS6,7);(MoS5,1);(MoOS6,4);(MoS5,1);(MoOS6,24);(MoS5,1);(MoOS6,69);(MoS5,1);(MoOS6,11);(MoS5,1);(MoOS6,3);(MoS5,1);(MoOS6,9);(MoS5,1);(MoOS6,52);(MoS5,1);(MoOS6,4);(MoS5,1);(MoOS6,10);(MoS5,1);(MoOS6,3);(MoS5,1);(MoOS6,18);(MoS5,1);(MoOS6,4);(MoS5,1);(MoOS6,19);(MoS5,1);(MoOS6,45);(MoS5,1);(MoOS6,22);(MoS5,1);(MoOS6,8);(MoS5,1);(MoOS6,17);(MoS5,2);(MoOS6,8);(MoS5,1);(MoOS6,6);(MoO2S7,1);(MoOS6,88);(MoS5,1);(MoOS6,22);(MoS5,1);(MoOS6,8);(MoS5,2);(MoOS6,3);(MoS5,1);(MoOS6,134);(MoS5,1);(MoOS6,26);(MoS5,1);(MoOS6,12);(MoS5,1);(MoOS6,137);(MoS5,1);(MoOS6,2);(MoS5,1);(MoOS6,89);(MoS5,1);(MoOS6,1562);(MoO2S7,1);(MoOS6,695);(MoS5,1);(MoOS6,7);(MoS5,1);(MoOS6,16);(MoS5,1);(MoOS6,112);(MoS5,1);(MoOS6,284);(MoS5,1);(MoOS6,11);(MoS5,1);(MoOS6,106);(MoS5,1);(MoOS6,4);(MoS5,1);(MoOS6,20);(MoS5,1);(MoOS6,4);(MoS5,1);(MoOS6,13);(MoS5,1);(MoOS6,126);(MoS5,1);(MoOS6,2);(MoS5,1);(MoOS6,4);(MoS5,1);(MoOS6,61);(MoS5,1);(MoOS6,43);(MoS5,1);(MoOS6,22);(MoS5,1);(MoOS6,10);(MoS5,1);(MoOS6,50);(MoS5,1);(MoOS6,3);(MoS5,1);(MoOS6,15);(MoS5,1);(MoOS6,53);(MoS5,1);(MoOS6,32);(MoS5,1);(MoOS6,5);(MoS5,1);(MoOS6,23);(MoS5,1);(MoOS6,186);(MoS5,1);(MoOS6,3);(MoS5,1);(MoOS6,39);(MoS5,1);(MoOS6,9);(MoS5,1);(MoOS6,40);(MoS5,1);(MoOS6,58);(MoS5,1);(MoOS6,1);(MoS5,1);(MoOS6,90);(MoS5,1);(MoOS6,442);(MoS5,1);(MoOS6,3);(MoS5,1);(MoOS6,17);(MoS5,1);(MoOS6,6);(MoS5,1);(MoOS6,698);(MoS5,1);(MoOS6,1);(MoS5,1);(MoOS6,559);(MoS5,1);(MoOS6,683);(MoS5,3);(MoOS6,2);(MoS5,1);(MoOS6,203);(MoO2S7,9);(MoS5,1);(MoOS6,143);(MoS5,2);(MoOS6,37);(MoS5,1);(MoOS6,1);(MoS5,1);(MoOS6,44);(MoS5,1);(MoOS6,61);(MoS5,1);(MoOS6,13);(MoS5,1);(MoOS6,8);(MoS5,1);(MoOS6,43);(MoO2S7,27);(MoOS6,1);(MoO2S7,1);(MoOS6,1);(MoO2S7,48);(MoS6,1);(MoOS6,1);(MoO2S7,3);(MoOS6,1);(MoO2S7,1);(MoOS6,963);(MoO2S7,1);(MoOS6,182);(MoS5,1);(MoOS6,447);(MoS5,1);(MoOS6,2);(MoS5,1);(MoOS6,9);(MoS5,1);(MoOS6,250);(MoS5,1);(MoOS6,86);( ...
#       dtype=object)

# %%
# 处理数据的函数
def process_data(data):
    pro_data = []
    for record in data:
        # 每条记录是一个字符串，将其按分号分割
        elements = record[0].split(';')
        processed_data = []
        for element in elements:
            # print(element)
            # 去除括号并按逗号分割成元素和数字
            mol, count = element.strip('()').split(',')
            processed_data.append((mol, int(count)))
        pro_data.append(np.array(processed_data))
    return pro_data

# 调用函数处理数据
processed = process_data(all_data)
processed = np.array(processed)
print(processed.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 17
#      14     return pro_data
#      16 # 调用函数处理数据
# ---> 17 processed = process_data(all_data)
#      18 processed = np.array(processed)
#      19 print(processed.shape)
#
# NameError: name 'all_data' is not defined

# %%
processed[1]
# Out:
# array([['Mo3O9', '91'],
#        ['Mo3O9S2', '13'],
#        ['Mo2O4', '5'],
#        ...,
#        ['MoS5', '1'],
#        ['MoOS6', '32'],
#        ['MoS5', '1']], dtype='<U11')

# %%
# 加载 .npy 文件
new_processed = np.load('../data/new_processed20.npy', allow_pickle=True)
print(new_processed.shape)
# Out:
# (2652,)

# %%
new_processed[0].shape
# Out:
# (41, 2)

# %% [markdown]
# ### Embedding

# %%
# incode 编码，转换成向量
import numpy as np
def incode(molecule):
    vec = np.zeros(3)
    length = len(molecule)
    Mo = molecule.find('Mo')
    O = molecule.find('O')
    S = molecule.find('S')
    # print(Mo, O, S)
    moi = oi = si = 0
    moi = 1
    if O==-1 and S==-1 and length>2:
        moi = molecule[Mo+2:]
    elif O != -1:
        if O > Mo + 2:
            moi = int(molecule[Mo+2:O])
        else:
            moi = 1
        if S == O + 1 or O+1==length:
            oi = 1
        elif S==-1:
            oi = int(molecule[O+1:])
        else:
            oi = int(molecule[O+1:S])
    elif S != -1:
        if S > Mo + 2:
            moi = int(molecule[Mo+2:S])
        else:
            moi = 1
        if S+1==length:
            si = 1
        else:
            si = int(molecule[S+1:])
    if S!=-1:
        if S+1==length:
            si = 1
        else:
            si = int(molecule[S+1:])
    vec = np.array([moi, oi, si])
    return vec
incode('MoOS13')
# Out:
# array([ 1,  1, 13])

# %%
# 使用列表推导式遍历二维数组并调用函数进行编码，将返回值存储在新的二维数组中
# all_data = [[incode(value) for value in row] for row in cy_data]
# all_data = np.array(all_data)
# all_data.shape
cy_data = new_processed#.iloc[:, :2500]#.iloc[:, ::10]  # 对数据进行每隔10列重新采样
cy_data = np.array(cy_data)
# cy_data = [[incode(value[0]) for value in row] for row in cy_data]
cy_data = [[np.append(incode(value[0]), int(value[1])) for value in row] for row in cy_data]
# cy_data = np.concatenate(cy_data)
cy_data = np.array(cy_data)
cy_data.shape #(1726, 3000, 3)
# Out:
# C:\Users\dfgje\AppData\Local\Temp\ipykernel_26988\2105827966.py:10: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   cy_data = np.array(cy_data)
# (2652,)

# %%
# 找到cy——data中的最大值
max_num = 0
for row in cy_data:
    for value in row:
        if value[3] > max_num:
            max_num = value[3]
max_num
# Out:
# 19395

# %%
import numpy as np
from tqdm import tqdm

# 构建数据集
def create_dataset(data, sequence_length):
    """
    将输入数据分割为长度为 sequence_length 的序列。
    """
    sequences = []
    for i in range(len(data) - sequence_length):
        # 构建序列
        sequences.append(data[i:i + sequence_length])
    return sequences

# 参数
sequence_length = 10

# 假设 cy_data 是 list，转换为合适的格式
# 如果 cy_data 是嵌套 list，则可以直接用它；否则，先检查数据格式
sequences = []
X = []
y = []
for row in cy_data:
    sequence = create_dataset(row, sequence_length)
    sequence = np.array(sequence)
    sequences.append(sequence)
    # print(sequence.shape)
    X.append(sequence[:-1])  # 除去最后一个序列
    y.append(sequence[1:, -1])  # 每个序列的最后一个时间步作为输出

sequences = np.array(sequences)
X = np.array(X)
y = np.array(y)
# 检查生成的序列形状
print('sequences.shape', sequences.shape)

# 构建输入 X 和输出 y

print('X.shape', X.shape)  # 输入的形状
print('y.shape', y.shape)  # 输出的形状
# Out:
# sequences.shape (2652,)
# X.shape (2652,)
# y.shape (2652,)
# C:\Users\dfgje\AppData\Local\Temp\ipykernel_26988\952688469.py:31: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   sequences = np.array(sequences)
# C:\Users\dfgje\AppData\Local\Temp\ipykernel_26988\952688469.py:32: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.array(X)
# C:\Users\dfgje\AppData\Local\Temp\ipykernel_26988\952688469.py:33: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   y = np.array(y)

# %%
print('X.shape', X.shape)  # 输入的形状
print('y.shape', y.shape)  # 输出的形状
print('X[0].shape', X[0].shape)  # 输入的形状
print('y[0].shape', y[0].shape)  # 输出的形状
# Out:
# X.shape (2652,)
# y.shape (2652,)
# X[0].shape (30, 10, 4)
# y[0].shape (30, 4)

# %%
# find the maximun of y[:][:,3]
max_num = 0
for value in y:
    for row in value:
        if row[3] > max_num:
            max_num = row[3]
max_num
# Out:
# 17989

# %%
X_concat = np.concatenate(X)
X_concat = X_concat.reshape(-1, 10, 4)
y_concat = np.concatenate(y)

print('X.shape', X_concat.shape)# X_train.shape (1035, 2899, 100, 3)
print('y.shape', y_concat.shape)# X_test.shape (691, 2899, 100, 3)
# Out:
# X.shape (91670, 10, 4)
# y.shape (91670, 4)

# %%
# 找到 y 中第四个特征大于 10000 的索引
filter_condition = y_concat[:, 3] <= 8000

# 根据索引筛选 X 和 y
X_filtered = X_concat[filter_condition]
y_filtered = y_concat[filter_condition]

# 查看结果
print(X_filtered.shape)
print(y_filtered.shape)
# Out:
# (91439, 10, 4)
# (91439, 4)

# %% [markdown]
# ### 重采样

# %%
import numpy as np
import pandas as pd
from sklearn.utils import resample

# 获取第四个特征
y_feature4 = y_filtered[:, 3]

# 设定分桶数（可以调整）
num_bins = 10
bins = np.linspace(y_feature4.min(), y_feature4.max(), num_bins + 1)
bin_labels = np.digitize(y_feature4, bins)  # 将数据分配到不同的桶

# 创建DataFrame便于处理
df = pd.DataFrame({'bin': bin_labels})
df['index'] = np.arange(len(y_filtered))

# 计算每个桶的样本数
bin_counts = df['bin'].value_counts()

# 选择目标样本数（取最大桶的样本数量）
target_samples = bin_counts.max()

resampled_indices = []

for bin_label, count in bin_counts.items():
    bin_indices = df[df['bin'] == bin_label]['index'].values
    
    # 过采样到目标样本数
    sampled = np.random.choice(bin_indices, target_samples, replace=True)
    
    resampled_indices.extend(sampled)

# 获取新的数据集
X_resampled = X_filtered[resampled_indices]
y_resampled = y_filtered[resampled_indices]

print(f"重采样后的X.shape: {X_resampled.shape}")
print(f"重采样后的y.shape: {y_resampled.shape}")
# Out:
# 重采样后的X.shape: (733359, 10, 4)
# 重采样后的y.shape: (733359, 4)

# %%
import numpy as np
import pandas as pd
from sklearn.utils import resample

# 获取第四个特征
y_feature4 = y_filtered[:, 3]

# 设定分桶数（可以调整）
num_bins = 10
bins = np.linspace(y_feature4.min(), y_feature4.max(), num_bins + 1)
bin_labels = np.digitize(y_feature4, bins)  # 将数据分配到不同的桶

# 创建DataFrame便于处理
df = pd.DataFrame({'bin': bin_labels})
df['index'] = np.arange(len(y_filtered))

# 计算每个桶的样本数
bin_counts = df['bin'].value_counts()

# 选择目标样本数（可以选择均衡化）
# target_samples = bin_counts.median()  # 目标数量取中位数
# 选择目标样本数（取最大桶的样本数量）
target_samples = bin_counts.max()

resampled_indices = []

for bin_label, count in bin_counts.items():
    bin_indices = df[df['bin'] == bin_label]['index'].values
    
    if count > target_samples:
        # 欠采样
        sampled = np.random.choice(bin_indices, int(target_samples), replace=False)
    else:
        # 过采样
        sampled = np.random.choice(bin_indices, int(target_samples), replace=True)
    
    resampled_indices.extend(sampled)

# 获取新的数据集
X_resampled = X_filtered[resampled_indices]
y_resampled = y_filtered[resampled_indices]

print(f"重采样后的X.shape: {X_resampled.shape}")
print(f"重采样后的y.shape: {y_resampled.shape}")
# Out:
# 重采样后的X.shape: (733359, 10, 4)
# 重采样后的y.shape: (733359, 4)

# %%
import numpy as np
import pandas as pd
from sklearn.utils import resample

# 获取第四个特征
y_feature4 = y_concat[:, 3]

# 设定分桶数（可以调整）
num_bins = 10
bins = np.linspace(y_feature4.min(), y_feature4.max(), num_bins + 1)
bin_labels = np.digitize(y_feature4, bins)  # 将数据分配到不同的桶

# 创建DataFrame便于处理
df = pd.DataFrame({'bin': bin_labels})
df['index'] = np.arange(len(y_concat))

# 计算每个桶的样本数
bin_counts = df['bin'].value_counts()

# 选择目标样本数（取最大桶的样本数量）
target_samples = bin_counts.max()

resampled_indices = []

for bin_label, count in bin_counts.items():
    bin_indices = df[df['bin'] == bin_label]['index'].values
    
    # 过采样到目标样本数
    sampled = np.random.choice(bin_indices, target_samples, replace=True)
    
    resampled_indices.extend(sampled)

# 获取新的数据集
X_resampled = X_concat[resampled_indices]
y_resampled = y_concat[resampled_indices]

print(f"重采样后的X.shape: {X_resampled.shape}")
print(f"重采样后的y.shape: {y_resampled.shape}")
# Out:
# 重采样后的X.shape: (876942, 10, 4)
# 重采样后的y.shape: (876942, 4)

# %%
import matplotlib.pyplot as plt

# plt.hist(y_concat[:, 3], bins=20, alpha=0.5, label="Original")
plt.hist(y_train_resampled[:, 3], bins=20, alpha=0.5, label="Resampled")
plt.legend()
plt.show()

# %%
# 将数据划分为训练集和测试集，可以指定测试集的大小和随机种子
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.3, random_state=42)
print('X_train.shape', X_train.shape)# X_train.shape (1035, 2899, 100, 3)
print('X_test.shape', X_test.shape)# X_test.shape (691, 2899, 100, 3)
print('y_train.shape', y_train.shape)# y_train.shape (1035, 2899, 3)
print('y_test.shape', y_test.shape)# y_test.shape (691, 2899, 3)
# Out:
# X_train.shape (513351, 10, 4)
# X_test.shape (220008, 10, 4)
# y_train.shape (513351, 4)
# y_test.shape (220008, 4)

# %% [markdown]
# #### 先分训练集和测试集

# %%
# 将数据划分为训练集和测试集，可以指定测试集的大小和随机种子
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
print('X_train.shape', X_train.shape)# X_train.shape (1035, 2899, 100, 3)
print('X_test.shape', X_test.shape)# X_test.shape (691, 2899, 100, 3)
print('y_train.shape', y_train.shape)# y_train.shape (1035, 2899, 3)
print('y_test.shape', y_test.shape)# y_test.shape (691, 2899, 3)
# Out:
# X_train.shape (1856,)
# X_test.shape (796,)
# y_train.shape (1856,)
# y_test.shape (796,)

# %% [markdown]
# max(y_train)

# %%
X_train.shape
# Out:
# (1856,)

# %%
X_train = np.concatenate(X_train)
X_train = X_train.reshape(-1, 10, 4)
y_train = np.concatenate(y_train)
X_test = np.concatenate(X_test)
X_test = X_test.reshape(-1, 10, 4)
y_test = np.concatenate(y_test)
print('X_train.shape', X_train.shape)# X_train.shape (1035, 2899, 100, 3)
print('X_test.shape', X_test.shape)# X_test.shape (691, 2899, 100, 3)
print('y_train.shape', y_train.shape)# y_train.shape (1035, 2899, 3)
print('y_test.shape', y_test.shape)# y_test.shape (691, 2899, 3)
# Out:
# X_train.shape (63858, 10, 4)
# X_test.shape (27812, 10, 4)
# y_train.shape (63858, 4)
# y_test.shape (27812, 4)

# %%
# 创建掩码，筛选第四个特征 <= num 的样本
num = 8000
mask_train = y_train[:, 3] <= num

# 应用掩码到X_train和y_train
X_train = X_train[mask_train]
y_train = y_train[mask_train]

# 创建掩码，筛选第四个特征 <= num 的样本
mask_test = y_test[:, 3] <= num

# 应用掩码到X_test和y_test
X_test = X_test[mask_test]
y_test = y_test[mask_test]

print("处理后的形状:")
print("X_train.shape", X_train.shape)
print("y_train.shape", y_train.shape)
print("X_test.shape", X_test.shape)
print("y_test.shape", y_test.shape)
# Out:
# 处理后的形状:
# X_train.shape (63691, 10, 4)
# y_train.shape (63691, 4)
# X_test.shape (27748, 10, 4)
# y_test.shape (27748, 4)

# %%
int(np.median(bin_counts))
# Out:
# 779

# %%
import numpy as np
import pandas as pd
from sklearn.utils import resample

# 获取第四个特征
y_feature4 = y_train[:, 3]

# 设定分桶数（可以调整）
num_bins = 20
bins = np.linspace(y_feature4.min(), y_feature4.max(), num_bins + 1)
bin_labels = np.digitize(y_feature4, bins)  # 将数据分配到不同的桶

# 创建DataFrame便于处理
df = pd.DataFrame({'bin': bin_labels})
df['index'] = np.arange(len(y_train))

# 计算每个桶的样本数
bin_counts = df['bin'].value_counts()

# 选择目标样本数（目标样本数取每个桶的中位数）
target_samples = 2000 # int(np.median(bin_counts))

resampled_indices = []

for bin_label, count in bin_counts.items():
    bin_indices = df[df['bin'] == bin_label]['index'].values
    
    if count > target_samples:
        # 如果该桶的样本数量大于目标样本数，进行欠采样
        sampled = np.random.choice(bin_indices, target_samples, replace=False)
    else:
        # 如果该桶的样本数量小于或等于目标样本数，保持不变
        sampled = bin_indices
    
    resampled_indices.extend(sampled)

# 获取新的数据集
X_train_resampled = X_train[resampled_indices]
y_train_resampled = y_train[resampled_indices]

print(f"重采样后的X.shape: {X_train_resampled.shape}")
print(f"重采样后的y.shape: {y_train_resampled.shape}")


# 获取第四个特征
y_feature4 = y_test[:, 3]

# 设定分桶数（可以调整）
num_bins = 20
bins = np.linspace(y_feature4.min(), y_feature4.max(), num_bins + 1)
bin_labels = np.digitize(y_feature4, bins)  # 将数据分配到不同的桶

# 创建DataFrame便于处理
df = pd.DataFrame({'bin': bin_labels})
df['index'] = np.arange(len(y_test))

# 计算每个桶的样本数
bin_counts = df['bin'].value_counts()

# 选择目标样本数（目标样本数取每个桶的中位数）
target_samples =  800 # int(np.median(bin_counts))

resampled_indices = []

for bin_label, count in bin_counts.items():
    bin_indices = df[df['bin'] == bin_label]['index'].values
    
    if count > target_samples:
        # 如果该桶的样本数量大于目标样本数，进行欠采样
        sampled = np.random.choice(bin_indices, target_samples, replace=False)
    else:
        # 如果该桶的样本数量小于或等于目标样本数，保持不变
        sampled = bin_indices
    
    resampled_indices.extend(sampled)

# 获取新的数据集
X_test_resampled = X_test[resampled_indices]
y_test_resampled = y_test[resampled_indices]

print(f"重采样后的X.shape: {X_test_resampled.shape}")
print(f"重采样后的y.shape: {y_test_resampled.shape}")
# Out:
# 重采样后的X.shape: (17101, 10, 4)
# 重采样后的y.shape: (17101, 4)
# 重采样后的X.shape: (7102, 10, 4)
# 重采样后的y.shape: (7102, 4)

# %%
import numpy as np
import pandas as pd
from sklearn.utils import resample

# 获取第四个特征
y_feature4 = y_test[:, 3]

# 设定分桶数（可以调整）
num_bins = 10
bins = np.linspace(y_feature4.min(), y_feature4.max(), num_bins + 1)
bin_labels = np.digitize(y_feature4, bins)  # 将数据分配到不同的桶

# 创建DataFrame便于处理
df = pd.DataFrame({'bin': bin_labels})
df['index'] = np.arange(len(y_test))

# 计算每个桶的样本数
bin_counts = df['bin'].value_counts()

# 选择目标样本数（取最大桶的样本数量）
target_samples = bin_counts.max()

resampled_indices = []

for bin_label, count in bin_counts.items():
    bin_indices = df[df['bin'] == bin_label]['index'].values
    
    # 过采样到目标样本数
    sampled = np.random.choice(bin_indices, target_samples, replace=True)
    
    resampled_indices.extend(sampled)

# 获取新的数据集
X_test_resampled = X_test[resampled_indices]
y_test_resampled = y_test[resampled_indices]

print(f"重采样后的X.shape: {X_test_resampled.shape}")
print(f"重采样后的y.shape: {y_test_resampled.shape}")
# Out:
# 重采样后的X.shape: (223135, 10, 4)
# 重采样后的y.shape: (223135, 4)

# %%
import numpy as np
import pandas as pd
from sklearn.utils import resample

# 获取第四个特征
y_feature4 = y_train[:, 3]

# 设定分桶数（可以调整）
num_bins = 10
bins = np.linspace(y_feature4.min(), y_feature4.max(), num_bins + 1)
bin_labels = np.digitize(y_feature4, bins)  # 将数据分配到不同的桶

# 创建DataFrame便于处理
df = pd.DataFrame({'bin': bin_labels})
df['index'] = np.arange(len(y_train))

# 计算每个桶的样本数
bin_counts = df['bin'].value_counts()

# 选择目标样本数（可以选择均衡化）
# target_samples = bin_counts.median()  # 目标数量取中位数
# 选择目标样本数（取最大桶的样本数量）
target_samples = bin_counts.max()

resampled_indices = []

for bin_label, count in bin_counts.items():
    bin_indices = df[df['bin'] == bin_label]['index'].values
    
    if count > target_samples:
        # 欠采样
        sampled = np.random.choice(bin_indices, int(target_samples), replace=False)
    else:
        # 过采样
        sampled = np.random.choice(bin_indices, int(target_samples), replace=True)
    
    resampled_indices.extend(sampled)

# 获取新的数据集
X_train_resampled = X_train[resampled_indices]
y_train_resampled = y_train[resampled_indices]

print(f"重采样后的X.shape: {X_train_resampled.shape}")
print(f"重采样后的y.shape: {y_train_resampled.shape}")
# Out:
# 重采样后的X.shape: (510224, 10, 4)
# 重采样后的y.shape: (510224, 4)

# %%
import numpy as np
import pandas as pd
from sklearn.utils import resample

# 获取第四个特征
y_feature4 = y_test[:, 3]

# 设定分桶数（可以调整）
num_bins = 10
bins = np.linspace(y_feature4.min(), y_feature4.max(), num_bins + 1)
bin_labels = np.digitize(y_feature4, bins)  # 将数据分配到不同的桶

# 创建DataFrame便于处理
df = pd.DataFrame({'bin': bin_labels})
df['index'] = np.arange(len(y_test))

# 计算每个桶的样本数
bin_counts = df['bin'].value_counts()

# 选择目标样本数（可以选择均衡化）
# target_samples = bin_counts.median()  # 目标数量取中位数
# 选择目标样本数（取最大桶的样本数量）
target_samples = bin_counts.max()

resampled_indices = []

for bin_label, count in bin_counts.items():
    bin_indices = df[df['bin'] == bin_label]['index'].values
    
    if count > target_samples:
        # 欠采样
        sampled = np.random.choice(bin_indices, int(target_samples), replace=False)
    else:
        # 过采样
        sampled = np.random.choice(bin_indices, int(target_samples), replace=True)
    
    resampled_indices.extend(sampled)

# 获取新的数据集
X_test_resampled = X_test[resampled_indices]
y_test_resampled = y_test[resampled_indices]

print(f"重采样后的X.shape: {X_test_resampled.shape}")
print(f"重采样后的y.shape: {y_test_resampled.shape}")
# Out:
# 重采样后的X.shape: (223135, 10, 4)
# 重采样后的y.shape: (223135, 4)

# %%
import numpy as np
import pandas as pd

def resample_by_target(X, y, n_bins=10, strategy="undersample"):
    """
    对数据集 (X, y) 进行基于 y[:, 3] 的均匀重采样
    参数：
        X: (N, 10, 4) 训练或测试数据
        y: (N, 4)  目标标签
        n_bins: 分桶的数量，默认 10
        strategy: 采样策略，"undersample" 进行下采样，"oversample" 进行上采样
    返回：
        X_resampled, y_resampled: 重新采样后的数据
    """
    # 获取 y[:, 3] 作为分桶依据
    y_feature = y[:, 3]
    
    # 使用 pd.qcut 进行等频分桶
    bins, bin_edges = pd.qcut(y_feature, q=n_bins, retbins=True, labels=False, duplicates="drop")
    
    # 统计每个桶的样本数
    bin_counts = np.bincount(bins)
    
    # 选择采样的目标数量
    if strategy == "undersample":
        target_size = bin_counts.min()  # 选择最小桶数量进行下采样
    elif strategy == "oversample":
        target_size = bin_counts.max()  # 选择最大桶数量进行上采样
    else:
        raise ValueError("strategy 只能是 'undersample' 或 'oversample'")
    
    # 存储采样后的索引
    sampled_indices = []
    
    # 遍历每个桶并进行采样
    for bin_id in range(len(bin_counts)):
        indices = np.where(bins == bin_id)[0]  # 获取该桶的索引
        
        if len(indices) > target_size:
            sampled_bin = np.random.choice(indices, target_size, replace=True)  # 下采样
        else:
            sampled_bin = np.random.choice(indices, target_size, replace=True)  # 上采样
            
        sampled_indices.extend(sampled_bin)
    
    # 打乱索引
    np.random.shuffle(sampled_indices)
    
    # 生成重采样后的数据
    X_resampled = X[sampled_indices]
    y_resampled = y[sampled_indices]
    
    return X_resampled, y_resampled

# 对训练集和测试集分别进行重采样
X_train_resampled, y_train_resampled = resample_by_target(X_train, y_train, n_bins=10, strategy="undersample")
X_test_resampled, y_test_resampled = resample_by_target(X_test, y_test, n_bins=10, strategy="undersample")

# 保存结果
np.save("X_train_resampled.npy", X_train_resampled)
np.save("y_train_resampled.npy", y_train_resampled)
np.save("X_test_resampled.npy", X_test_resampled)
np.save("y_test_resampled.npy", y_test_resampled)

# 打印数据变化情况
print("Resampled X_train shape:", X_train_resampled.shape)
print("Resampled y_train shape:", y_train_resampled.shape)
print("Resampled X_test shape:", X_test_resampled.shape)
print("Resampled y_test shape:", y_test_resampled.shape)
# Out:
# Resampled X_train shape: (61560, 10, 4)
# Resampled y_train shape: (61560, 4)
# Resampled X_test shape: (27190, 10, 4)
# Resampled y_test shape: (27190, 4)

# %%
import numpy as np
import pandas as pd
from sklearn.utils import resample

# 获取第四个特征
y_feature4 = y_train[:, 3]

# 设定分桶数（可以调整）
num_bins = 10
bins = np.linspace(y_feature4.min(), y_feature4.max(), num_bins + 1)
bin_labels = np.digitize(y_feature4, bins)  # 将数据分配到不同的桶

# 创建DataFrame便于处理
df = pd.DataFrame({'bin': bin_labels})
df['index'] = np.arange(len(y_train))

# 计算每个桶的样本数
bin_counts = df['bin'].value_counts()

# 选择目标样本数（取最小桶的样本数量）
# target_samples = bin_counts.min()
target_samples = bin_counts.median()  # 目标数量取中位数


resampled_indices = []

for bin_label, count in bin_counts.items():
    bin_indices = df[df['bin'] == bin_label]['index'].values
    
    # 欠采样到目标样本数（如果样本多于目标数量）
    if count > target_samples:
        sampled = np.random.choice(bin_indices, target_samples, replace=False)
    else:
        sampled = bin_indices
    
    resampled_indices.extend(sampled)

# 获取新的数据集
X_train_resampled = X_train[resampled_indices]
y_train_resampled = y_train[resampled_indices]

print(f"重采样后的X.shape: {X_train_resampled.shape}")
print(f"重采样后的y.shape: {y_train_resampled.shape}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[52], line 32
#      30 # 欠采样到目标样本数（如果样本多于目标数量）
#      31 if count > target_samples:
# ---> 32     sampled = np.random.choice(bin_indices, target_samples, replace=False)
#      33 else:
#      34     sampled = bin_indices
#
# File mtrand.pyx:992, in numpy.random.mtrand.RandomState.choice()
#
# TypeError: 'numpy.float64' object cannot be interpreted as an integer

# %%
import matplotlib.pyplot as plt

plt.hist(y_train[:, 3], bins=20, alpha=0.5, label="Original")
plt.hist(y_train_resampled[:, 3], bins=20, alpha=0.5, label="Resampled")
plt.legend()
plt.show()

plt.hist(y_test[:, 3], bins=20, alpha=0.5, label="Original")
plt.hist(y_test_resampled[:, 3], bins=20, alpha=0.5, label="Resampled")
plt.legend()
plt.show()

# %%
import numpy as np
import pandas as pd
from sklearn.utils import resample

# 假设 y_train[:, 3] 是第四个特征
y_train_fourth = y_train[:, 3]

# 分箱（假设我们分为10个区间，可以根据需要调整）
bins = np.linspace(np.min(y_train_fourth), np.max(y_train_fourth), num=11)  # 10个区间
bin_indices = np.digitize(y_train_fourth, bins)

# 创建一个 DataFrame 来存储每个区间的样本
df = pd.DataFrame({'X': list(X_train), 'y': list(y_train), 'bin': bin_indices})

# 计算每个区间的样本数
bin_counts = df['bin'].value_counts()
 
# 找到最大样本数
max_count = bin_counts.max()

# 创建一个新的列表来存储重采样后的数据
resampled_X, resampled_y = [], []

for bin_value in bin_counts.index:
    # 获取当前区间的所有样本
    bin_samples = df[df['bin'] == bin_value]
    
    # 如果该区间的样本少于最大样本数，进行过采样
    if len(bin_samples) < max_count:
        bin_samples = resample(bin_samples, replace=True, n_samples=max_count, random_state=42)
    # 如果该区间的样本多于最大样本数，进行欠采样
    elif len(bin_samples) > max_count:
        bin_samples = resample(bin_samples, replace=False, n_samples=max_count, random_state=42)
    
    # 添加到重采样后的数据中
    resampled_X.append(bin_samples['X'].to_list())
    resampled_y.append(bin_samples['y'].to_list())

# 将重采样后的数据合并
resampled_X = np.concatenate(resampled_X, axis=0)
resampled_y = np.concatenate(resampled_y, axis=0)

# 检查重采样后的结果
print("Resampled X_train shape:", resampled_X.shape)
print("Resampled y_train shape:", resampled_y.shape)
# Out:
# Resampled X_train shape: (610731, 10, 4)
# Resampled y_train shape: (610731, 4)

# %%
# 将数据划分为训练集和测试集，可以指定测试集的大小和随机种子
X_train, X_test, y_train, y_test = train_test_split(resampled_X, resampled_y, test_size=0.3, random_state=42)
print('X_train.shape', X_train.shape)# X_train.shape (1035, 2899, 100, 3)
print('X_test.shape', X_test.shape)# X_test.shape (691, 2899, 100, 3)
print('y_train.shape', y_train.shape)# y_train.shape (1035, 2899, 3)
print('y_test.shape', y_test.shape)# y_test.shape (691, 2899, 3)
# Out:
# X_train.shape (427511, 10, 4)
# X_test.shape (183220, 10, 4)
# y_train.shape (427511, 4)
# y_test.shape (183220, 4)

# %%
import numpy as np
import pandas as pd
from sklearn.utils import resample

# 假设 y_train[:, 3] 是第四个特征
y_train_fourth = y_train[:, 3]

# 步骤 1: 去掉 y 的第四个特征大于 2500 的样本
mask = y_train_fourth <= 2500
X_train_filtered = X_train[mask]
y_train_filtered = y_train[mask]

# 步骤 2: 分箱
bins = np.linspace(np.min(y_train_filtered[:, 3]), np.max(y_train_filtered[:, 3]), num=11)  # 10个区间
bin_indices = np.digitize(y_train_filtered[:, 3], bins)

# 步骤 3: 创建一个 DataFrame 来存储每个区间的样本
df = pd.DataFrame({'X': list(X_train_filtered), 'y': list(y_train_filtered), 'bin': bin_indices})

# 计算每个区间的样本数
bin_counts = df['bin'].value_counts()

# 找到最小的样本数（最小样本数用于欠采样）
min_count = bin_counts.min()

# 创建一个新的列表来存储重采样后的数据
resampled_X, resampled_y = [], []

for bin_value in bin_counts.index:
    # 获取当前区间的所有样本
    bin_samples = df[df['bin'] == bin_value]
    
    # 进行欠采样：随机选择 min_count 个样本
    bin_samples = resample(bin_samples, replace=False, n_samples=min_count, random_state=42)
    
    # 添加到重采样后的数据中
    resampled_X.append(bin_samples['X'].to_list())
    resampled_y.append(bin_samples['y'].to_list())

# 将重采样后的数据合并
resampled_X = np.concatenate(resampled_X, axis=0)
resampled_y = np.concatenate(resampled_y, axis=0)

# 检查重采样后的结果
print("Resampled X_train shape:", resampled_X.shape)
print("Resampled y_train shape:", resampled_y.shape)
# Out:
# Resampled X_train shape: (55, 10, 4)
# Resampled y_train shape: (55, 4)

# %% [markdown]
# ### 数据形状处理

# %%
X_train[:, -1, -1] = 0
X_test[:, -1, -1] = 0

# %%
X_train = X_train_resampled
y_train = y_train_resampled

X_test = X_test_resampled
y_test = y_test_resampled

# %%
# 将x_train和y_train接起来
y_train_expanded = np.expand_dims(y_train, axis=1)  # 将 y_train 从 (n, 4) 转换为 (n, 1, 4)
train_data = np.concatenate((X_train, y_train_expanded), axis=1)

# 将x_test和y_test接起来
y_test_expanded = np.expand_dims(y_test, axis=1)  # 将 y_test 从 (n, 4) 转换为 (n, 1, 4)
test_data = np.concatenate((X_test, y_test_expanded), axis=1)


train_data.shape, test_data.shape
# Out:
# ((17101, 11, 4), (7102, 11, 4))

# %%
train_data[:, -1, -1] = 0
test_data[:, -1, -1] = 0

X_train = train_data
X_test = test_data

y_train = y_train[:, 3]
y_test = y_test[:, 3]
y_train = y_train.reshape(-1, 1)
y_test = y_test.reshape(-1, 1)
y_train.shape, y_test.shape
# Out:
# ((17101, 1), (7102, 1))

# %% [markdown]
# ### 特征处理

# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# 假设你的训练集和测试集是 X_train 和 X_test
# X_train 和 X_test 形状为 (n_samples, 10, 4)

# 提取前三个特征（前3列）
X_train_features_3 = X_train[:, :, :3]
X_test_features_3 = X_test[:, :, :3]

# 提取第四个特征（第4列）
X_train_feature_4 = X_train[:, :, 3]
X_test_feature_4 = X_test[:, :, 3]

# 归一化前三个特征
scaler_3 = MinMaxScaler()
X_train_features_3 = scaler_3.fit_transform(X_train_features_3.reshape(-1, 3)).reshape(X_train_features_3.shape)
X_test_features_3 = scaler_3.transform(X_test_features_3.reshape(-1, 3)).reshape(X_test_features_3.shape)

# # 标准化前三个特征
# scaler = StandardScaler()
# X_train_features_3 = scaler.fit_transform(X_train_features_3.reshape(-1, 3)).reshape(X_train_features_3.shape)
# X_test_features_3 = scaler.transform(X_test_features_3.reshape(-1, 3)).reshape(X_test_features_3.shape)

# 对第四个特征取对数（确保数值大于0）
X_train_feature_4 = np.log(X_train_feature_4 + 1e-6)  # 加上一个小常数避免log(0)
X_test_feature_4 = np.log(X_test_feature_4 + 1e-6)

# 线性变化第四个特征 
# scaler = 1000
# X_train_feature_4 = X_train_feature_4/scaler
# X_test_feature_4 = X_test_feature_4/scaler


# 标准化第四个特征
# scaler_4 = StandardScaler()
# X_train_feature_4 = scaler_4.fit_transform(X_train_feature_4.reshape(-1, 1)).reshape(X_train_feature_4.shape)
# X_test_feature_4 = scaler_4.transform(X_test_feature_4.reshape(-1, 1)).reshape(X_test_feature_4.shape)


# 合并处理后的特征
X_train_processed = np.concatenate([X_train_features_3, X_train_feature_4[..., np.newaxis]], axis=-1)
X_test_processed = np.concatenate([X_test_features_3, X_test_feature_4[..., np.newaxis]], axis=-1)

# 检查结果
print(X_train_processed.shape)  # 应该是 (n_samples, 10, 4)
print(X_test_processed.shape)   # 应该是 (n_samples, 10, 4)

# 对第四个特征取对数（确保数值大于0）
y_train_processed = np.log(y_train + 1e-6)  # 加上一个小常数避免log(0)
y_test_processed = np.log(y_test + 1e-6)

# 线性变化第四个特征 
# y_train_processed = y_train/scaler
# y_test_processed = y_test/scaler

# 对目标变量进行标准化
# scaler_y = StandardScaler()
# y_train_processed = scaler_y.fit_transform(y_train)  # 直接对y进行标准化
# y_test_processed = scaler_y.transform(y_test)  # 使用训练集的标准化参数处理测试集


# 检查结果
print(y_train_processed.shape)  # 应该是 (n_samples, 4)
print(y_test_processed.shape)   # 应该是 (n_samples, 4)
# Out:
# (17101, 11, 4)
# (7102, 11, 4)
# (17101, 1)
# (7102, 1)

# %%
# Box-Cox 变换
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from scipy import stats

# 假设你的训练集和测试集是 X_train 和 X_test，y_train 和 y_test
# X_train 和 X_test 形状为 (n_samples, 10, 4)

# 提取前三个特征（前3列）
X_train_features_3 = X_train[:, :, :3]
X_test_features_3 = X_test[:, :, :3]

# 提取第四个特征（第4列）
X_train_feature_4 = X_train[:, :, 3]
X_test_feature_4 = X_test[:, :, 3]

# 归一化前三个特征
scaler = MinMaxScaler()
X_train_features_3 = scaler.fit_transform(X_train_features_3.reshape(-1, 3)).reshape(X_train_features_3.shape)
X_test_features_3 = scaler.transform(X_test_features_3.reshape(-1, 3)).reshape(X_test_features_3.shape)

# 对第四个特征进行 Box-Cox 变换
# 由于 Box-Cox 变换要求数据为正数，确保没有零或负数
X_train_feature_4_transformed, lambda_train = stats.boxcox(X_train_feature_4.flatten()+1e-6)
X_test_feature_4_transformed = (X_test_feature_4.flatten()+1e-6 ** lambda_train - 1) / lambda_train if lambda_train != 0 else np.log(X_test_feature_4.flatten()+1e-6)

# 重新调整为原始的形状
X_train_feature_4_transformed = X_train_feature_4_transformed.reshape(X_train_feature_4.shape)
X_test_feature_4_transformed = X_test_feature_4_transformed.reshape(X_test_feature_4.shape)

# 合并处理后的特征
X_train_processed = np.concatenate([X_train_features_3, X_train_feature_4_transformed[..., np.newaxis]], axis=-1)
X_test_processed = np.concatenate([X_test_features_3, X_test_feature_4_transformed[..., np.newaxis]], axis=-1)

# 检查结果
print(X_train_processed.shape)  # 应该是 (n_samples, 10, 4)
print(X_test_processed.shape)   # 应该是 (n_samples, 10, 4)

# 对目标值 y_train 和 y_test 进行 Box-Cox 变换
y_train_transformed, lambda_y = stats.boxcox(y_train.flatten())  # 假设 y_train 是形状 (n_samples, 1)
y_test_transformed = (y_test.flatten() ** lambda_y - 1) / lambda_y if lambda_y != 0 else np.log(y_test.flatten())

# 重新调整为原始的形状
y_train_processed = y_train_transformed.reshape(y_train.shape)
y_test_processed = y_test_transformed.reshape(y_test.shape)

# # # 对目标值（y_train 和 y_test）进行标准化
# scaler_y = MinMaxScaler()
# y_train_processed = scaler_y.fit_transform(y_train_transformed)
# y_test_processed = scaler_y.transform(y_test_transformed)

# 检查结果
print(y_train_processed.shape)  # 应该是 (n_samples, 4)
print(y_test_processed.shape)   # 应该是 (n_samples, 4)
# Out:
# (613859, 10, 4)
# (263083, 10, 4)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[64], line 40
#      37 print(X_test_processed.shape)   # 应该是 (n_samples, 10, 4)
#      39 # 对目标值 y_train 和 y_test 进行 Box-Cox 变换
# ---> 40 y_train_transformed, lambda_y = stats.boxcox(y_train.flatten())  # 假设 y_train 是形状 (n_samples, 1)
#      41 y_test_transformed = (y_test.flatten() ** lambda_y - 1) / lambda_y if lambda_y != 0 else np.log(y_test.flatten())
#      43 # 重新调整为原始的形状
#
# File d:\Software\anaconda3\envs\pytorch\lib\site-packages\scipy\stats\morestats.py:1064, in boxcox(x, lmbda, alpha, optimizer)
#    1061     raise ValueError("Data must not be constant.")
#    1063 if np.any(x <= 0):
# -> 1064     raise ValueError("Data must be positive.")
#    1066 if lmbda is not None:  # single transformation
#    1067     return special.boxcox(x, lmbda)
#
# ValueError: Data must be positive.

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((1215179, 11, 4), (524954, 11, 4), (1215179, 1), (524954, 1))

# %%
X_test_processed[0], y_test_processed[0], X_train_processed[0], y_train_processed[0]
# Out:
# (array([[ 1.00000000e+00,  1.00000000e+00,  0.00000000e+00,
#           1.09861262e+00],
#         [ 1.00000000e+00,  1.00000000e+00,  2.00000000e-01,
#           2.89037181e+00],
#         [ 0.00000000e+00,  1.11111111e-01,  0.00000000e+00,
#           4.15888310e+00],
#         [ 0.00000000e+00,  1.11111111e-01,  2.00000000e-01,
#           9.99999500e-07],
#         [ 0.00000000e+00,  0.00000000e+00,  1.00000000e-01,
#           2.83321340e+00],
#         [ 0.00000000e+00,  0.00000000e+00,  3.00000000e-01,
#           2.07944167e+00],
#         [ 0.00000000e+00,  0.00000000e+00,  1.00000000e-01,
#           9.99999500e-07],
#         [ 0.00000000e+00,  0.00000000e+00,  3.00000000e-01,
#           3.46573593e+00],
#         [ 0.00000000e+00,  0.00000000e+00,  1.00000000e-01,
#           9.99999500e-07],
#         [ 0.00000000e+00,  0.00000000e+00,  3.00000000e-01,
#           6.93147681e-01],
#         [ 0.00000000e+00,  0.00000000e+00,  5.00000000e-01,
#          -1.38155106e+01]]),
#  array([1.60943811]),
#  array([[  1.        ,   1.        ,   0.        ,   2.99573232],
#         [  1.        ,   1.        ,   0.2       ,   1.60943811],
#         [  0.        ,   0.33333333,   0.        ,   1.09861262],
#         [  0.        ,   0.22222222,   0.        ,   3.76120014],
#         [  0.        ,   0.11111111,   0.        ,   2.07944167],
#         [  0.        ,   0.22222222,   0.        ,   3.21887586],
#         [  0.        ,   0.11111111,   0.        ,   2.94443903],
#         [  0.        ,   0.11111111,   0.2       ,   3.0910425 ],
#         [  0.        ,   0.        ,   0.1       ,   0.69314768],
#         [  0.        ,   0.11111111,   0.2       ,   1.60943811],
#         [  0.        ,   0.        ,   0.1       , -13.81551056]]),
#  array([9.999995e-07]))

# %%
# train_data = TensorDataset(X_train, y_train)
# test_data = TensorDataset(X_test, y_test)
# train_data = TensorDataset(torch.tensor(X_train_normalized), torch.tensor(y_train))
# train_data = TensorDataset(torch.tensor(X_train_normalized), torch.tensor(y_train_normalized))
train_data = TensorDataset(torch.tensor(X_train_processed), torch.tensor(y_train_processed))

# train_data = TensorDataset(torch.tensor(X_train_new), torch.tensor(y_train_new))
# test_data = TensorDataset(torch.tensor(X_test_normalized), torch.tensor(y_test_normalized))
test_data = TensorDataset(torch.tensor(X_test_processed), torch.tensor(y_test_processed))
# test_data = TensorDataset(torch.tensor(X_test_normalized), torch.tensor(y_test))

# %%
X_train_processed[100], y_train_processed[0], X_test_processed[0], y_test_processed[0]
# Out:
# (array([[  0.5       ,   0.        ,   0.6       ,   4.70953021],
#         [  0.5       ,   0.        ,   0.8       ,   3.36729586],
#         [  0.5       ,   0.        ,   0.6       ,   1.79175964],
#         [  0.5       ,   0.        ,   0.8       ,   3.68887948],
#         [  0.        ,   0.        ,   0.3       ,   3.63758619],
#         [  0.5       ,   0.        ,   0.9       ,   4.83628191],
#         [  0.        ,   0.        ,   0.5       ,   5.50533154],
#         [  0.5       ,   0.        ,   0.9       ,   0.69314768],
#         [  0.        ,   0.        ,   0.7       ,   0.69314768],
#         [  0.5       ,   0.        ,   0.9       ,   1.94591029],
#         [  0.        ,   0.        ,   0.4       , -13.81551056]]),
#  array([ 9.99999500e-07,  9.99999500e-07, -1.38155106e+01,  9.99999500e-07]),
#  array([[  1.        ,   1.        ,   0.        ,   4.46590813],
#         [  1.        ,   1.        ,   0.2       ,   2.19722469],
#         [  0.        ,   0.22222222,   0.        ,   1.09861262],
#         [  0.        ,   0.33333333,   0.        ,   0.69314768],
#         [  0.        ,   0.22222222,   0.        ,   3.78418966],
#         [  0.        ,   0.11111111,   0.        ,   1.94591029],
#         [  0.        ,   0.22222222,   0.        ,   1.38629461],
#         [  0.        ,   0.33333333,   0.        ,   0.69314768],
#         [  0.        ,   0.22222222,   0.        ,   3.87120103],
#         [  0.        ,   0.11111111,   0.        ,   1.09861262],
#         [  0.        ,   0.22222222,   0.        , -13.81551056]]),
#  array([ 9.99999500e-07,  6.93147681e-01, -1.38155106e+01,  6.93147681e-01]))

# %%
X_train_processed.shape, y_train_processed.shape, X_test_processed.shape, y_test_processed.shape
# Out:
# ((510224, 11, 4), (510224, 1), (223135, 11, 4), (223135, 1))

# %% [markdown]
# ### 数据分布图

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 使用Matplotlib绘制直方图
plt.hist(y_train_processed.flatten(), bins=50)
plt.title('Histogram of y_train')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()
# 使用Matplotlib绘制直方图
plt.hist(y_test_processed.flatten(), bins=50)
plt.title('Histogram of y_test')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# 使用Matplotlib绘制直方图
plt.hist(X_train_processed[:, :, -1].flatten(), bins=50)
plt.title('Histogram of X_train')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()
# 使用Matplotlib绘制直方图
plt.hist(X_test_processed[:, :, -1].flatten(), bins=50)
plt.title('Histogram of X_test')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
# 使用Matplotlib绘制直方图
plt.hist(resampled_y[:, 3].flatten(), bins=50)
plt.title('Histogram of y_test')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 使用Matplotlib绘制直方图
plt.hist(y_train.flatten(), bins=50)
plt.title('Histogram of y_train')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()
# 使用Matplotlib绘制直方图
plt.hist(y_test.flatten(), bins=50)
plt.title('Histogram of y_test')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# 使用Matplotlib绘制直方图
plt.hist(X_train[:, :, -1].flatten(), bins=50)
plt.title('Histogram of X_train')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()
# 使用Matplotlib绘制直方图
plt.hist(X_test[:, :, -1].flatten(), bins=50)
plt.title('Histogram of X_test')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### 训练

# %%
import torch
import torch.nn as nn

class FocalLoss(nn.Module):
    def __init__(self, alpha=1, gamma=2, epsilon=1e-6):
        super(FocalLoss, self).__init__()
        self.alpha = alpha
        self.gamma = gamma
        self.epsilon = epsilon

    def forward(self, y_pred, y_true):
        # 计算绝对误差
        loss = torch.abs(y_pred - y_true)
        
        # 计算焦点损失
        focal_loss = self.alpha * (1 - loss / (torch.abs(y_true) + self.epsilon))**self.gamma * loss
        return focal_loss.mean()

# %%
class PositionalEncoding(nn.Module):
    
    def __init__(self, d_model, max_len=5000):
        super(PositionalEncoding, self).__init__()       
        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0).transpose(0, 1)
        self.register_buffer('pe', pe)

    def forward(self, x):
        return x + self.pe[:x.size(0), :] # [input_window, batch size, embed dim]

class TransAm(nn.Module):
    def __init__(self, series_dim, feature_size = 80, num_layers=3, dropout=0.5):
        super(TransAm, self).__init__()
        self.model_type = 'Transformer'
        self.src_mask = None
        self.input_embedding = nn.Linear(series_dim, feature_size)
        self.pos_encoder = PositionalEncoding(feature_size)
        self.encoder_layer = nn.TransformerEncoderLayer(d_model=feature_size, nhead=10, dropout=dropout)
        self.transformer_encoder = nn.TransformerEncoder(self.encoder_layer, num_layers=num_layers)        
        self.decoder = nn.Linear(feature_size, feature_size//2)
        self.out = nn.Linear(feature_size//2, series_dim)
        self.init_weights()

    def init_weights(self):
        initrange = 0.1    
        self.decoder.bias.data.zero_()
        # 将解码器的权重初始化为均匀分布的随机值，范围在 [−0.1,0.1] 之间
        self.decoder.weight.data.uniform_(-initrange, initrange)

    def forward(self,src):
        if self.src_mask is None or self.src_mask.size(0) != len(src):
            device = src.device
            mask = self._generate_square_subsequent_mask(len(src)).to(device)
            self.src_mask = mask
        src = self.input_embedding(src)
        src = self.pos_encoder(src) # [input_window, batch_size, feature_size]
        en_output = self.transformer_encoder(src, self.src_mask) 
        de_output = self.decoder(en_output) # [input_window, batch_size, feature_size//2]
        out_put = self.out(de_output[-output_window:,:,:])
        return out_put # [output_window, batch_size, series_dim]

    def _generate_square_subsequent_mask(self, sz):
        '''
        生成一个上三角掩码矩阵，防止模型在预测时看到未来时间步的数据。若 sz = 4 则生成：
        [[0.0,   -inf,  -inf,  -inf],
        [0.0,    0.0,  -inf,  -inf],
        [0.0,    0.0,   0.0,  -inf],
        [0.0,    0.0,   0.0,   0.0]]
        '''
        mask = (torch.triu(torch.ones(sz, sz)) == 1).transpose(0, 1)
        mask = mask.float().masked_fill(mask == 0, float('-inf')).masked_fill(mask == 1, float(0.0))
        return mask

# %%
# 模型
# LSTM model
class LSTM(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, num_classes, dropout_prob=0.5):
        super(LSTM, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True, dropout=dropout_prob if num_layers > 1 else 0)
        self.fc = nn.Linear(hidden_size, num_classes)
        self.dropout = nn.Dropout(dropout_prob)

    def forward(self, x):
        # Initialize hidden state with zeros
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
        # Initialize cell state
        c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
        # Forward propagate LSTM
        out, _ = self.lstm(x, (h0, c0))
        # Decode the hidden state of the last time step
        out = self.dropout(out[:, -1, :])  # Apply dropout before the fully connected layer
        out = self.fc(out)
        return out
        
# BiLSTM-MAIN model
class MultiHeadSelfAttention(nn.Module):
    def __init__(self, hidden_size, num_heads):
        super(MultiHeadSelfAttention, self).__init__()
        self.num_heads = num_heads
        self.head_dim = hidden_size // num_heads
        assert hidden_size % num_heads == 0, "hidden_size must be divisible by num_heads"
        
        self.attention_heads = nn.Parameter(torch.Tensor(num_heads, self.head_dim, 1))
        nn.init.xavier_uniform_(self.attention_heads)
        
        self.fc = nn.Linear(hidden_size, hidden_size)

    def forward(self, lstm_output):
        batch_size, seq_len, hidden_size = lstm_output.size(0), lstm_output.size(1), lstm_output.size(2)
        # Reshape lstm_output to (batch_size, seq_len, num_heads, head_dim)
        lstm_output = lstm_output.view(batch_size, seq_len, self.num_heads, self.head_dim)
        # Transpose for matrix multiplication: (batch_size, num_heads, seq_len, head_dim)
        lstm_output = lstm_output.transpose(1, 2)
        # Compute attention scores
        attention_scores = torch.matmul(lstm_output, self.attention_heads)
        # Apply softmax to get the weights on the values
        attention_scores = F.softmax(attention_scores, dim=-2)
        # Apply attention weights to lstm_output
        weighted_output = attention_scores * lstm_output
        # Sum weighted output over seq_len dimension
        weighted_output = weighted_output.sum(dim=-2)
        # Reshape weighted_output to (batch_size, hidden_size)
        weighted_output = weighted_output.reshape(batch_size, -1)
        # Pass through the fully connected layer
        output = self.fc(weighted_output)
        return output

# BiLSTM-MAIN model
class LSTMWithMulAttention(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, num_classes, dropout_rate, num_heads):
        super(LSTMWithMulAttention, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True, bidirectional=True)
        self.attention = MultiHeadSelfAttention(hidden_size*2, num_heads)  # 注意hidden_size*2因为BiLSTM
        self.layer_norm = nn.LayerNorm(hidden_size*2)
        self.dropout = nn.Dropout(dropout_rate)
        self.fc = nn.Linear(hidden_size*2, num_classes)
        # 添加残差连接的线性层
        self.residual_fc = nn.Linear(hidden_size*2, hidden_size*2)

    def forward(self, x):
        h0 = torch.zeros(self.num_layers*2, x.size(0), self.hidden_size).to(x.device)  # 乘以2因为BiLSTM
        c0 = torch.zeros(self.num_layers*2, x.size(0), self.hidden_size).to(x.device)
        lstm_out, _ = self.lstm(x, (h0, c0))
        # 添加残差连接
        residual_output = lstm_out + self.residual_fc(lstm_out)
        lstm_out = self.layer_norm(residual_output)
        attn_out = self.attention(lstm_out)
        drop_out = self.dropout(attn_out)
        out = self.fc(drop_out)
        return out

# %%
# %%time
from torch.nn.parallel import DataParallel
import torch.nn.functional as F

hidden_size = 512
num_layers = 14
batch_size = 256
sequence_length = 11

train_loader = DataLoader(train_data, shuffle=False, batch_size=batch_size)
test_loader = DataLoader(test_data, shuffle=False, batch_size=batch_size)


# print('X_train.shape[-1]:',X_train.shape[-1])

input_size = 4
num_classes= 1
# model = LSTM(input_size, hidden_size, num_layers, num_classes, dropout_prob=0.5)
#model = LSTMWithAttention(input_size, hidden_size, num_layers, num_classes, dropout_rate = 0.2)
model = LSTMWithMulAttention(input_size, hidden_size, num_layers, num_classes, dropout_rate=0.4, num_heads=8)
# print('num_classes:', num_classes)

model = model.to(device)
model = nn.DataParallel(model)
criterion = nn.MSELoss() # FocalLoss(alpha=0.25, gamma=2) #nn.CrossEntropyLoss() #nn.MSELoss() #custom_loss 
optimizer = optim.Adam(model.parameters(), lr=1e-5)
scheduler = ReduceLROnPlateau(optimizer, 'min',factor=0.4, patience=10, min_lr=1e-6, verbose=True)

# 训练模型
num_epochs = 500
best_loss = np.inf
early_stopping_patience = 30
early_stopping_counter = 0
loss_values = []

for epoch in range(num_epochs):
    model.train()
    train_losses = []
    for i, (x_batch, y_batch) in enumerate(tqdm(train_loader, desc=f"train epoch {epoch}" ,unit="batch")): #tqdm(train_loader, desc=f"train epoch {epoch}" ,unit="batch"))
        # one_batch_bar.set_description(f'[ epoch: {ep+1} ]')
        x_batch = x_batch.to(device).float()
        y_batch = y_batch.to(device).float()
#         print('x_batch:', x_batch.shape)
#         print('y_batch:', y_batch.shape)
        
        optimizer.zero_grad()
        # print('x_batch shape:',x_batch.shape[0])
        # print(x_batch.shape)
        x_batch = x_batch.view(-1, sequence_length, input_size)
        y_batch = y_batch.view(-1, num_classes)
        
        outputs = model(x_batch)
        # print('outputs:', outputs.shape)
        loss = criterion(outputs, y_batch) #, x_batch
        loss.backward()
        optimizer.step()
        # break
        train_losses.append(loss.item())
        # 更新进度条后缀信息，显示当前损失值
        # tqdm.set_postfix({'loss': loss / (100 * (epoch+1))}, refresh=True)
    
    val_losses = []
    model.eval()
    with torch.no_grad():
        # for i, (x_batch, y_batch) in enumerate(test_loader):
        for i, (x_batch, y_batch) in enumerate(test_loader):
            x_batch = x_batch.to(device).float()
            y_batch = y_batch.to(device).float()
            
            x_batch = x_batch.view(-1, sequence_length, input_size)
            y_batch = y_batch.view(-1, num_classes)
            # y_batch = y_batch.squeeze().long()
            
            outputs = model(x_batch)
            loss = criterion(outputs, y_batch) #, x_batch
            val_losses.append(loss.item())

    train_loss = np.mean(train_losses)
    val_loss = np.mean(val_losses)
    scheduler.step(train_loss)
    loss_values.append([train_loss, val_loss])

    # if epoch%10==0 :
    print(f'Epoch {epoch+1}/{num_epochs}, Train Loss: {train_loss}, Validation Loss: {val_loss}', "Current learning rate:", scheduler.get_last_lr()[0])
    # 在每个 epoch 结束时获取最后设置的学习率并打印

    if val_loss - best_loss < -0.000001:
        # early_stopping_counter = 0
        if best_loss - val_loss > 0.01:
            early_stopping_counter = 0
        best_loss = val_loss
        best_model = deepcopy(model.state_dict())
    else:
        early_stopping_counter += 1
        print(f'EarlyStopping counter: {early_stopping_counter} out of {early_stopping_patience}')
        if early_stopping_counter >= early_stopping_patience:
            model.load_state_dict(best_model)
            print('Early stopping')
            break

    # 保存最好的模型
    torch.save(best_model, '../model/mul512_l14_T1500c20rsntMax_sst11_log.pth')#########################################################

# 画出loss变化曲线
loss_values = np.array(loss_values)
plt.plot(loss_values[:, 0], label='Train Loss')
plt.plot(loss_values[:, 1], label='Validation Loss')
plt.legend()
plt.show()

# 评估预测结果
model.eval()
predictions = []
targets = []
with torch.no_grad():
    for i, (x_batch, y_batch) in enumerate(test_loader):
        x_batch = x_batch.to(device).float()
        y_batch = y_batch.to(device).float()
        x_batch = x_batch.view(-1, sequence_length, input_size)
        y_batch = y_batch.view(-1, num_classes)
        outputs = model(x_batch)
        predictions.append(outputs.cpu().numpy())
        targets.append(y_batch.cpu().numpy()) 

predictions = np.concatenate(predictions)
targets = np.concatenate(targets) 
print(f'Epoch {epoch+1}/{num_epochs}, Train Loss: {train_loss}, Validation Loss: {val_loss}')
print('Test RMSE:', np.sqrt(mean_squared_error(targets, predictions)))
# Out:
# train epoch 0: 100%|██████████| 67/67 [00:03<00:00, 21.27batch/s]
# Epoch 1/500, Train Loss: 3.7178031506378257, Validation Loss: 2.473186659659924 Current learning rate: 1e-05
# train epoch 1: 100%|██████████| 67/67 [00:03<00:00, 21.63batch/s]
# Epoch 2/500, Train Loss: 2.0077530421427827, Validation Loss: 2.818008196581754 Current learning rate: 1e-05
# EarlyStopping counter: 1 out of 30
# train epoch 2: 100%|██████████| 67/67 [00:03<00:00, 21.67batch/s]
# Epoch 3/500, Train Loss: 2.1598805712897384, Validation Loss: 2.803470956070149 Current learning rate: 1e-05
# EarlyStopping counter: 2 out of 30
# train epoch 3: 100%|██████████| 67/67 [00:03<00:00, 21.64batch/s]
# Epoch 4/500, Train Loss: 2.153449162618438, Validation Loss: 2.7689926157472655 Current learning rate: 1e-05
# EarlyStopping counter: 3 out of 30
# train epoch 4: 100%|██████████| 67/67 [00:03<00:00, 21.62batch/s]
# Epoch 5/500, Train Loss: 2.1579491867503124, Validation Loss: 2.7747993903301125 Current learning rate: 1e-05
# EarlyStopping counter: 4 out of 30
# train epoch 5: 100%|██████████| 67/67 [00:03<00:00, 21.68batch/s]
# Epoch 6/500, Train Loss: 2.15629785696962, Validation Loss: 2.7914595701565434 Current learning rate: 1e-05
# EarlyStopping counter: 5 out of 30
# train epoch 6: 100%|██████████| 67/67 [00:03<00:00, 21.63batch/s]
# Epoch 7/500, Train Loss: 2.168599226359111, Validation Loss: 2.8307064233397665 Current learning rate: 1e-05
# EarlyStopping counter: 6 out of 30
# train epoch 7: 100%|██████████| 67/67 [00:03<00:00, 21.65batch/s]
# Epoch 8/500, Train Loss: 2.1793794247196683, Validation Loss: 2.7804597355591665 Current learning rate: 4.000000000000001e-06
# EarlyStopping counter: 7 out of 30
# train epoch 8: 100%|██████████| 67/67 [00:03<00:00, 21.63batch/s]
# Epoch 9/500, Train Loss: 2.4450679263517037, Validation Loss: 1.7403890909710233 Current learning rate: 4.000000000000001e-06
# train epoch 9: 100%|██████████| 67/67 [00:03<00:00, 21.63batch/s]
# Epoch 10/500, Train Loss: 1.9073175446533446, Validation Loss: 1.7604865797163387 Current learning rate: 4.000000000000001e-06
# EarlyStopping counter: 1 out of 30
# train epoch 10: 100%|██████████| 67/67 [00:03<00:00, 21.52batch/s]
# Epoch 11/500, Train Loss: 1.9059491190892548, Validation Loss: 1.77361671302268 Current learning rate: 4.000000000000001e-06
# EarlyStopping counter: 2 out of 30
# train epoch 11: 100%|██████████| 67/67 [00:03<00:00, 21.65batch/s]
# Epoch 12/500, Train Loss: 1.921916200598674, Validation Loss: 1.772440328296008 Current learning rate: 4.000000000000001e-06
# EarlyStopping counter: 3 out of 30
# train epoch 12: 100%|██████████| 67/67 [00:03<00:00, 21.69batch/s]
# Epoch 13/500, Train Loss: 1.9300935493031544, Validation Loss: 1.7791757549026184 Current learning rate: 4.000000000000001e-06
# EarlyStopping counter: 4 out of 30
# train epoch 13: 100%|██████████| 67/67 [00:03<00:00, 21.63batch/s]
# Epoch 14/500, Train Loss: 1.940213994637354, Validation Loss: 1.7759690568449773 Current learning rate: 4.000000000000001e-06
# EarlyStopping counter: 5 out of 30
# train epoch 14: 100%|██████████| 67/67 [00:03<00:00, 21.65batch/s]
# Epoch 15/500, Train Loss: 1.9382377809553004, Validation Loss: 1.7775117690408868 Current learning rate: 4.000000000000001e-06
# EarlyStopping counter: 6 out of 30
# train epoch 15: 100%|██████████| 67/67 [00:03<00:00, 21.61batch/s]
# Epoch 16/500, Train Loss: 1.9427105687669854, Validation Loss: 1.7833116300836471 Current learning rate: 4.000000000000001e-06
# EarlyStopping counter: 7 out of 30
# train epoch 16: 100%|██████████| 67/67 [00:03<00:00, 21.65batch/s]
# Epoch 17/500, Train Loss: 1.923911607865967, Validation Loss: 1.7780361161733578 Current learning rate: 1.6000000000000004e-06
# EarlyStopping counter: 8 out of 30
# train epoch 17: 100%|██████████| 67/67 [00:03<00:00, 21.66batch/s]
# Epoch 18/500, Train Loss: 1.9410871543101411, Validation Loss: 1.5438032276994949 Current learning rate: 1.6000000000000004e-06
# train epoch 18: 100%|██████████| 67/67 [00:03<00:00, 21.55batch/s]
# Epoch 19/500, Train Loss: 1.7407038850125982, Validation Loss: 1.510727851784655 Current learning rate: 1.6000000000000004e-06
# train epoch 19: 100%|██████████| 67/67 [00:03<00:00, 21.68batch/s]
# Epoch 20/500, Train Loss: 1.6846198736509281, Validation Loss: 1.506053893693856 Current learning rate: 1.6000000000000004e-06
# train epoch 20: 100%|██████████| 67/67 [00:03<00:00, 21.65batch/s]
# Epoch 21/500, Train Loss: 1.6904663857239395, Validation Loss: 1.50463807862252 Current learning rate: 1.6000000000000004e-06
# train epoch 21: 100%|██████████| 67/67 [00:03<00:00, 21.70batch/s]
# Epoch 22/500, Train Loss: 1.6892433692492657, Validation Loss: 1.5053503114197935 Current learning rate: 1.6000000000000004e-06
# EarlyStopping counter: 1 out of 30
# train epoch 22: 100%|██████████| 67/67 [00:03<00:00, 21.50batch/s]
# Epoch 23/500, Train Loss: 1.6942762869285113, Validation Loss: 1.5054993304823125 Current learning rate: 1.6000000000000004e-06
# EarlyStopping counter: 2 out of 30
# train epoch 23: 100%|██████████| 67/67 [00:03<00:00, 21.66batch/s]
# Epoch 24/500, Train Loss: 1.7035588159489987, Validation Loss: 1.507364655578775 Current learning rate: 1.6000000000000004e-06
# EarlyStopping counter: 3 out of 30
# train epoch 24: 100%|██████████| 67/67 [00:03<00:00, 21.60batch/s]
# Epoch 25/500, Train Loss: 1.706891950609079, Validation Loss: 1.5063404005153902 Current learning rate: 1.6000000000000004e-06
# EarlyStopping counter: 4 out of 30
# train epoch 25: 100%|██████████| 67/67 [00:03<00:00, 21.05batch/s]
# Epoch 26/500, Train Loss: 1.6947392219705368, Validation Loss: 1.507569586325969 Current learning rate: 1e-06
# EarlyStopping counter: 5 out of 30
# train epoch 26: 100%|██████████| 67/67 [00:03<00:00, 21.61batch/s]
# Epoch 27/500, Train Loss: 1.6745412741134416, Validation Loss: 1.4904665108770132 Current learning rate: 1e-06
# train epoch 27: 100%|██████████| 67/67 [00:03<00:00, 21.56batch/s]
# Epoch 28/500, Train Loss: 1.6494195259996314, Validation Loss: 1.4856430658006243 Current learning rate: 1e-06
# train epoch 28: 100%|██████████| 67/67 [00:03<00:00, 21.62batch/s]
# Epoch 29/500, Train Loss: 1.6324803242042882, Validation Loss: 1.4839998313026237 Current learning rate: 1e-06
# train epoch 29: 100%|██████████| 67/67 [00:03<00:00, 21.66batch/s]
# Epoch 30/500, Train Loss: 1.640651776719449, Validation Loss: 1.482914240066228 Current learning rate: 1e-06
# train epoch 30: 100%|██████████| 67/67 [00:03<00:00, 21.58batch/s]
# Epoch 31/500, Train Loss: 1.6281431143853202, Validation Loss: 1.4826579215337656 Current learning rate: 1e-06
# train epoch 31: 100%|██████████| 67/67 [00:03<00:00, 21.63batch/s]
# Epoch 32/500, Train Loss: 1.637749319979504, Validation Loss: 1.4829163394003575 Current learning rate: 1e-06
# EarlyStopping counter: 1 out of 30
# train epoch 32: 100%|██████████| 67/67 [00:03<00:00, 21.63batch/s]
# Epoch 33/500, Train Loss: 1.6317334699986585, Validation Loss: 1.4831055911324387 Current learning rate: 1e-06
# EarlyStopping counter: 2 out of 30
# train epoch 33: 100%|██████████| 67/67 [00:03<00:00, 21.48batch/s]
# Epoch 34/500, Train Loss: 1.6300736623468683, Validation Loss: 1.4832897904395526 Current learning rate: 1e-06
# EarlyStopping counter: 3 out of 30
# train epoch 34: 100%|██████████| 67/67 [00:03<00:00, 21.25batch/s]
# Epoch 35/500, Train Loss: 1.6401644042178767, Validation Loss: 1.4835336591516222 Current learning rate: 1e-06
# EarlyStopping counter: 4 out of 30
# train epoch 35: 100%|██████████| 67/67 [00:03<00:00, 21.04batch/s]
# Epoch 36/500, Train Loss: 1.636307143008531, Validation Loss: 1.4835360465970422 Current learning rate: 1e-06
# EarlyStopping counter: 5 out of 30
# train epoch 36: 100%|██████████| 67/67 [00:03<00:00, 21.01batch/s]
# Epoch 37/500, Train Loss: 1.6264699847618145, Validation Loss: 1.4840629000017154 Current learning rate: 1e-06
# EarlyStopping counter: 6 out of 30
# train epoch 37: 100%|██████████| 67/67 [00:03<00:00, 20.94batch/s]
# Epoch 38/500, Train Loss: 1.6375298358833612, Validation Loss: 1.4838735962153546 Current learning rate: 1e-06
# EarlyStopping counter: 7 out of 30
# train epoch 38: 100%|██████████| 67/67 [00:03<00:00, 20.98batch/s]
# Epoch 39/500, Train Loss: 1.6362539013819908, Validation Loss: 1.484112436084875 Current learning rate: 1e-06
# EarlyStopping counter: 8 out of 30
# train epoch 39: 100%|██████████| 67/67 [00:03<00:00, 20.95batch/s]
# Epoch 40/500, Train Loss: 1.6263678187309807, Validation Loss: 1.4843460581531482 Current learning rate: 1e-06
# EarlyStopping counter: 9 out of 30
# train epoch 40: 100%|██████████| 67/67 [00:03<00:00, 20.95batch/s]
# Epoch 41/500, Train Loss: 1.6365556139776956, Validation Loss: 1.4844785100514335 Current learning rate: 1e-06
# EarlyStopping counter: 10 out of 30
# train epoch 41: 100%|██████████| 67/67 [00:03<00:00, 20.99batch/s]
# Epoch 42/500, Train Loss: 1.641081367633236, Validation Loss: 1.4845150470999735 Current learning rate: 1e-06
# EarlyStopping counter: 11 out of 30
# train epoch 42: 100%|██████████| 67/67 [00:03<00:00, 20.88batch/s]
# Epoch 43/500, Train Loss: 1.6418862407332036, Validation Loss: 1.4840957902238838 Current learning rate: 1e-06
# EarlyStopping counter: 12 out of 30
# train epoch 43: 100%|██████████| 67/67 [00:03<00:00, 20.84batch/s]
# Epoch 44/500, Train Loss: 1.6378045896096016, Validation Loss: 1.4851087098275977 Current learning rate: 1e-06
# EarlyStopping counter: 13 out of 30
# train epoch 44: 100%|██████████| 67/67 [00:03<00:00, 21.52batch/s]
# Epoch 45/500, Train Loss: 1.633577117056989, Validation Loss: 1.4849754514704858 Current learning rate: 1e-06
# EarlyStopping counter: 14 out of 30
# train epoch 45: 100%|██████████| 67/67 [00:03<00:00, 20.65batch/s]
# Epoch 46/500, Train Loss: 1.6413023456263898, Validation Loss: 1.4847386206300663 Current learning rate: 1e-06
# EarlyStopping counter: 15 out of 30
# train epoch 46: 100%|██████████| 67/67 [00:03<00:00, 21.36batch/s]
# Epoch 47/500, Train Loss: 1.635100762568303, Validation Loss: 1.484831742410149 Current learning rate: 1e-06
# EarlyStopping counter: 16 out of 30
# train epoch 47: 100%|██████████| 67/67 [00:03<00:00, 18.73batch/s]
# Epoch 48/500, Train Loss: 1.6416229711317305, Validation Loss: 1.484525527672044 Current learning rate: 1e-06
# EarlyStopping counter: 17 out of 30
# train epoch 48: 100%|██████████| 67/67 [00:03<00:00, 19.69batch/s]
# Epoch 49/500, Train Loss: 1.6399086272316192, Validation Loss: 1.484403181189139 Current learning rate: 1e-06
# EarlyStopping counter: 18 out of 30
# train epoch 49: 100%|██████████| 67/67 [00:03<00:00, 19.12batch/s]
# Epoch 50/500, Train Loss: 1.637484952585021, Validation Loss: 1.4842033000729447 Current learning rate: 1e-06
# EarlyStopping counter: 19 out of 30
# train epoch 50: 100%|██████████| 67/67 [00:03<00:00, 18.51batch/s]
# Epoch 51/500, Train Loss: 1.63096768420134, Validation Loss: 1.4851586500049703 Current learning rate: 1e-06
# EarlyStopping counter: 20 out of 30
# train epoch 51: 100%|██████████| 67/67 [00:03<00:00, 18.84batch/s]
# Epoch 52/500, Train Loss: 1.644164598255015, Validation Loss: 1.4846526795133417 Current learning rate: 1e-06
# EarlyStopping counter: 21 out of 30
# train epoch 52: 100%|██████████| 67/67 [00:03<00:00, 19.01batch/s]
# Epoch 53/500, Train Loss: 1.6412803154827944, Validation Loss: 1.4850233352876134 Current learning rate: 1e-06
# EarlyStopping counter: 22 out of 30
# train epoch 53: 100%|██████████| 67/67 [00:03<00:00, 18.86batch/s]
# Epoch 54/500, Train Loss: 1.6367143834037567, Validation Loss: 1.4850950730033219 Current learning rate: 1e-06
# EarlyStopping counter: 23 out of 30
# train epoch 54: 100%|██████████| 67/67 [00:03<00:00, 18.60batch/s]
# Epoch 55/500, Train Loss: 1.6432653469825858, Validation Loss: 1.4852379796627377 Current learning rate: 1e-06
# EarlyStopping counter: 24 out of 30
# train epoch 55: 100%|██████████| 67/67 [00:03<00:00, 19.15batch/s]
# Epoch 56/500, Train Loss: 1.6327489008432003, Validation Loss: 1.485076942115224 Current learning rate: 1e-06
# EarlyStopping counter: 25 out of 30
# train epoch 56: 100%|██████████| 67/67 [00:03<00:00, 20.94batch/s]
# Epoch 57/500, Train Loss: 1.6370314002704265, Validation Loss: 1.484732347141419 Current learning rate: 1e-06
# EarlyStopping counter: 26 out of 30
# train epoch 57: 100%|██████████| 67/67 [00:03<00:00, 20.71batch/s]
# Epoch 58/500, Train Loss: 1.6416187358658705, Validation Loss: 1.4848987929789084 Current learning rate: 1e-06
# EarlyStopping counter: 27 out of 30
# train epoch 58: 100%|██████████| 67/67 [00:03<00:00, 21.01batch/s]
# Epoch 59/500, Train Loss: 1.6282207205224393, Validation Loss: 1.4852786277021681 Current learning rate: 1e-06
# EarlyStopping counter: 28 out of 30
# train epoch 59: 100%|██████████| 67/67 [00:03<00:00, 21.19batch/s]
# Epoch 60/500, Train Loss: 1.6361840795447578, Validation Loss: 1.4852542224606233 Current learning rate: 1e-06
# EarlyStopping counter: 29 out of 30
# train epoch 60: 100%|██████████| 67/67 [00:03<00:00, 21.22batch/s]
# Epoch 61/500, Train Loss: 1.6409790649342892, Validation Loss: 1.4852439669360007 Current learning rate: 1e-06
# EarlyStopping counter: 30 out of 30
# Early stopping
# Epoch 61/500, Train Loss: 1.6409790649342892, Validation Loss: 1.4852439669360007
# Test RMSE: 1.2145493
# CPU times: total: 56.3 s
# Wall time: 4min 5s

# %%
# 评估预测结果
model.eval()
train_targets = []
train_targets = []
with torch.no_grad():
    for i, (x_batch, y_batch) in enumerate(train_loader):
        x_batch = x_batch.to(device).float()
        y_batch = y_batch.to(device).float()
        x_batch = x_batch.view(-1, sequence_length, input_size)
        y_batch = y_batch.view(-1, num_classes)
        outputs = model(x_batch)
        predictions.append(outputs.cpu().numpy())
        targets.append(y_batch.cpu().numpy()) 

train_predictions = np.concatenate(predictions)
train_targets = np.concatenate(targets) 
# print(f'Epoch {epoch+1}/{num_epochs}, Train Loss: {train_loss}, Validation Loss: {val_loss}')
print('Test RMSE:', np.sqrt(mean_squared_error(train_targets, train_predictions)))
# Out:
# Test RMSE: 1.245349

# %%
predictions = []
targets = []
with torch.no_grad():
    for i, (x_batch, y_batch) in enumerate(test_loader):
        x_batch = x_batch.to(device).float()
        y_batch = y_batch.to(device).float()
        x_batch = x_batch.view(-1, sequence_length, input_size)
        y_batch = y_batch.view(-1, num_classes)
        outputs = model(x_batch)
        predictions.append(outputs.cpu().numpy())
        targets.append(y_batch.cpu().numpy()) 

predictions = np.concatenate(predictions)
targets = np.concatenate(targets)

# %%
# 画出loss变化曲线
loss_values = np.array(loss_values)
plt.plot(loss_values[:, 0], label='Train Loss')
plt.plot(loss_values[:, 1], label='Validation Loss')
plt.legend()
plt.show()

# %%
# 画出loss变化曲线
loss_values = np.array(loss_values)
plt.plot(loss_values[:, 0], label='Train Loss')
plt.plot(loss_values[:, 1], label='Validation Loss')
plt.legend()
plt.show()

# %% [markdown]
# ### Evaluation

# %%
# 评估预测结果
test_loader = DataLoader(test_data, shuffle=False, batch_size=batch_size)
model.eval()
predictions = []
targets = []
with torch.no_grad():
    for i, (x_batch, y_batch) in enumerate(tqdm(test_loader, desc="test", unit="batch")):
        x_batch = x_batch.to(device).float()
        y_batch = y_batch.to(device).float()
        x_batch = x_batch.view(-1, sequence_length+1, input_size)
        y_batch = y_batch.view(-1, num_classes)
        outputs = model(x_batch)
        predictions.append(outputs.cpu().numpy())
        targets.append(y_batch.cpu().numpy()) 

predictions = np.concatenate(predictions)
targets = np.concatenate(targets)
# Out:
# test: 100%|██████████| 435/435 [00:00<00:00, 703.23batch/s]

# %%
# 数据转回原始尺度
predictions = scaler_y.inverse_transform(predictions)
targets = scaler_y.inverse_transform(targets)

# %%
# 数据转回非log
predictions = np.exp(predictions)
targets = np.exp(targets)

# %%
predictions[1], targets[1]
# Out:
# (array([2.61678], dtype=float32), array([1.7917596], dtype=float32))

# %%
predictions.shape, targets.shape
# Out:
# ((264803, 3), (264803, 3))

# %%
predictions_s = predictions
targets_s = targets
predictions = predictions[:, :-1]
targets = targets[:, :-1]

predictions.shape, targets.shape
# Out:
# ((264803, 3), (264803, 3))

# %% [markdown]
# #### 指标

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
# 四舍五入的
# pre_round = np.round(new_pred)
print('Test RMSE:', np.sqrt(mean_squared_error(targets, predictions)))
# 计算均方误差（MSE）
mse = mean_squared_error(targets, predictions)
print("Mean Squared Error (MSE):", mse)

# 计算平均绝对误差（MAE）
mae = mean_absolute_error(targets, predictions)
print("Mean Absolute Error (MAE):", mae)

# 计算R平方
r2 = r2_score(targets, predictions)
print("R^2 Score:", r2)
# Out:
# Test RMSE: 1.2089516
# Mean Squared Error (MSE): 1.461564
# Mean Absolute Error (MAE): 0.87642175
# R^2 Score: -2.333012805544321e-05

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
# 四舍五入的
# pre_round = np.round(new_pred)
print('Test RMSE:', np.sqrt(mean_squared_error(targets, predictions)))
# 计算均方误差（MSE）
mse = mean_squared_error(targets, predictions)
print("Mean Squared Error (MSE):", mse)

# 计算平均绝对误差（MAE）
mae = mean_absolute_error(targets, predictions)
print("Mean Absolute Error (MAE):", mae)

# 计算R平方
r2 = r2_score(targets, predictions)
print("R^2 Score:", r2)
# Out:
# Test RMSE: 0.56842613
# Mean Squared Error (MSE): 0.3231083
# Mean Absolute Error (MAE): 0.34290752
# R^2 Score: 0.9488135268164927

# %%
#保存预测结果
np.savez('../results/mul_T1500c20sa_sst11_log_test.npz', arr1=targets, arr2=predictions)

# %%
# 反向对数变换：将对数变换的值恢复到原始值
predictions = np.exp(predictions) - 1e-6  # 减去加的常数（避免log(0)）
targets = np.exp(targets) - 1e-6

# 反向标准化：将标准化的数据恢复到原始尺度
# predictions = scaler_y.inverse_transform(prediction_exp)
# targets = scaler_y.inverse_transform(target_exp)

# 检查结果
print(predictions.shape)  # 应该是 (n_samples, 4)
print(targets.shape)      # 应该是 (n_samples, 4)
# Out:
# (27812, 1)
# (27812, 1)

# %%
# 反向标准化：将标准化的数据恢复到原始尺度
predictions = scaler_y.inverse_transform(predictions)
targets = scaler_y.inverse_transform(targets)

# # 反向对数变换：将对数变换的值恢复到原始值
# predictions = np.exp(predictions) - 1e-6  # 减去加的常数（避免log(0)）
# targets = np.exp(targets) - 1e-6

# 检查结果
print(predictions.shape)  # 应该是 (n_samples, 4)
print(targets.shape)      # 应该是 (n_samples, 4)
# Out:
# (116060, 1)
# (116060, 1)

# %%
# 反向标准化：将标准化的数据恢复到原始尺度
predictions = scaler_y.inverse_transform(predictions)
targets = scaler_y.inverse_transform(targets)

# # 反向对数变换：将对数变换的值恢复到原始值
# predictions = np.exp(predictions) - 1e-6  # 减去加的常数（避免log(0)）
# targets = np.exp(targets) - 1e-6

# 检查结果
print(predictions.shape)  # 应该是 (n_samples, 4)
print(targets.shape)      # 应该是 (n_samples, 4)

# %%
predictions[100], targets[100], predictions.shape, targets.shape
# Out:
# (array([1.0047483e+00, 4.1949246e-03, 5.0357013e+00, 2.4206024e+01],
#        dtype=float32),
#  array([1.        , 0.        , 5.        , 0.99999994], dtype=float32),
#  (102104, 4),
#  (102104, 4))

# %% [markdown]
# #### 画图

# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats

# 假设 y_test 是真实值，predictions 是预测值
residuals = targets - predictions
residuals = residuals.flatten()  # 将 residuals 转换为一维数组
residuals_train = train_targets - train_predictions
residuals_train = residuals_train.flatten()  # 将 residuals 转换为一维数组

# 创建 2x2 的子图（一个 2 行 2 列的布局）
fig, axes = plt.subplots(2, 2, figsize=(12, 12))

# 绘制散点图
axes[0, 0].scatter(targets, predictions, alpha=0.1)
axes[0, 0].plot([min(targets), max(targets)], [min(targets), max(targets)], color='red', linestyle='--')
axes[0, 0].set_xlabel('True Values')
axes[0, 0].set_ylabel('Predicted Values')
axes[0, 0].set_title('Scatter Plot of True vs Predicted')

# 绘制残差图
axes[0, 1].scatter(predictions, residuals, alpha=0.1)
axes[0, 1].axhline(y=0, color='red', linestyle='--')
axes[0, 1].set_xlabel('Predicted Values')
axes[0, 1].set_ylabel('Residuals')
axes[0, 1].set_title('Residual Plot')

# # 绘制误差分布图
# axes[1, 0].hist(residuals, bins=30, density=True, alpha=0.6, color='g')
# axes[1, 0].set_xlabel('Residuals')
# axes[1, 0].set_ylabel('Frequency')
# axes[1, 0].set_title('Error Distribution')

# # 绘制 Q-Q 图
# stats.probplot(residuals, dist="norm", plot=axes[1, 1])
# axes[1, 1].set_title('Q-Q Plot')

# 绘制散点图
axes[1, 0].scatter(train_targets, train_predictions, alpha=0.1)
axes[1, 0].plot([min(train_targets), max(train_targets)], [min(train_targets), max(train_targets)], color='red', linestyle='--')
axes[1, 0].set_xlabel('True Values')
axes[1, 0].set_ylabel('Predicted Values')
axes[1, 0].set_title('train Scatter Plot of True vs Predicted')

# 绘制残差图
axes[1, 1].scatter(train_predictions, residuals_train, alpha=0.1)
axes[1, 1].axhline(y=0, color='red', linestyle='--')
axes[1, 1].set_xlabel('Predicted Values')
axes[1, 1].set_ylabel('Residuals')
axes[1, 1].set_title('train Residual Plot')

# 调整布局
plt.tight_layout()
plt.show()

# %%
max(y_test)
# Out:
# array([16515])

# %%
import matplotlib.pyplot as plt
import numpy as np

# 生成示例数据
# x = np.linspace(0, 10, 100)
# y1 = np.sin(x)
# y2 = np.cos(x)
# y3 = np.tan(x)
num = 8000
start = 0
end = 100
p_round = predictions.round()
t_round = y_test #targets.round()
p1 = p_round[start:end]
t1 = t_round[start:end]
# 创建一个包含三个子图的画布
fig, axs = plt.subplots(4, 1, figsize=(15, 9))

# 在第一个子图中绘制 y1
axs[0].plot(t1[:], label='Mo')
axs[0].plot(p1[:], label='predict Mo')
#
axs[0].set_title('Mo')
axs[0].legend(loc='upper right')

# 在第二个子图中绘制 y2
axs[1].plot(t1[:, 1], label='O')
axs[1].plot(p1[:, 1], label='predict O')
# axs[1].plot(p1[:, 1], color='blue', label='predict O')
# axs[1].plot(t1[:, 1], color='red', label='O')
axs[1].set_title('O')
axs[1].legend(loc='upper right')
# 在第三个子图中绘制 y3
axs[2].plot(t1[:, 2], label='S')
axs[2].plot(p1[:, 2], label='predict S')
axs[2].set_title('S')
axs[2].legend(loc='upper right')
# 在第三个子图中绘制 y3
# axs[3].plot(t1[:, 3], label='target')
# axs[3].plot(p1[:, 3], label='predict')
# axs[3].set_title('time')
# axs[3].legend(loc='upper right')
# 设置统一的横坐标标签
for ax in axs:
    # plt.xlim(1100, 1200)
    ax.set_xlabel('state transition')
# axs[0].set_xlim(1100, 1200)
# 调整子图之间的间距
plt.tight_layout()

# 显示图形
plt.show()
# plt.savefig('result.png')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[117], line 27
#      24 axs[0].legend(loc='upper right')
#      26 # 在第二个子图中绘制 y2
# ---> 27 axs[1].plot(t1[:, 1], label='O')
#      28 axs[1].plot(p1[:, 1], label='predict O')
#      29 # axs[1].plot(p1[:, 1], color='blue', label='predict O')
#      30 # axs[1].plot(t1[:, 1], color='red', label='O')
#
# IndexError: index 1 is out of bounds for axis 1 with size 1

# %%
t_round.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[140], line 1
# ----> 1 t_round.shape
#
# NameError: name 't_round' is not defined

# %%
dd = np.array(cy_data[0])
dd.shape
# Out:
# (464, 4)

# %%
# 可视化cy_data
import matplotlib.pyplot as plt
import numpy as np

# 生成示例数据
# x = np.linspace(0, 10, 100)
# y1 = np.sin(x)
# y2 = np.cos(x)
# y3 = np.tan(x)
num = 8000
start = 0
end = 100
# p_round = predictions.round()
t_round = dd #targets.round()
# p1 = p_round[start:end, :]
t1 = t_round[start:end, :]
# 创建一个包含三个子图的画布
fig, axs = plt.subplots(4, 1, figsize=(15, 9))

# 在第一个子图中绘制 y1
axs[0].plot(t1[:, 0], label='Mo')
# axs[0].plot(p1[:, 0], label='predict Mo')
#
axs[0].set_title('Mo')
axs[0].legend(loc='upper right')

# 在第二个子图中绘制 y2
axs[1].plot(t1[:, 1], label='O')
# axs[1].plot(p1[:, 1], label='predict O')
# axs[1].plot(p1[:, 1], color='blue', label='predict O')
# axs[1].plot(t1[:, 1], color='red', label='O')
axs[1].set_title('O')
axs[1].legend(loc='upper right')
# 在第三个子图中绘制 y3
axs[2].plot(t1[:, 2], label='S')
# axs[2].plot(p1[:, 2], label='predict S')
axs[2].set_title('S')
axs[2].legend(loc='upper right')
# 在第三个子图中绘制 y3
axs[3].plot(t1[:, 3], label='target')
# axs[3].plot(p1[:, 3], label='predict')
axs[3].set_title('time')
axs[3].legend(loc='upper right')
# 设置统一的横坐标标签
for ax in axs:
    # plt.xlim(1100, 1200)
    ax.set_xlabel('time')
# axs[0].set_xlim(1100, 1200)
# 调整子图之间的间距
plt.tight_layout()

# 显示图形
plt.show()
# plt.savefig('result.png')

# %%
import numpy as np
ss = np.load('../results/mul_T900_ss.npz')
ss_targets = ss['arr1']
ss_predictions = ss['arr2']

sts = np.load('../results/mul_T900_sts.npz')
sts_targets = sts['arr1']
sts_predictions = sts['arr2']

stst = np.load('../results/mul_T900_stst.npz')
stst_targets = stst['arr1']
stst_predictions = stst['arr2']

# %%
# 可视化cy_data
import matplotlib.pyplot as plt
import numpy as np

# 生成示例数据
# x = np.linspace(0, 10, 100)
# y1 = np.sin(x)
# y2 = np.cos(x)
# y3 = np.tan(x)
num = 8000
start = 0
end = 100
# p_round = predictions.round()
t_round = targets.round()  # stst_targets
# p1 = p_round[start:end, :]
t1 = t_round[start:end, :]
# 创建一个包含三个子图的画布
fig, axs = plt.subplots(4, 1, figsize=(15, 9))

# 在第一个子图中绘制 y1
axs[0].plot(t1[:, 0], label='Mo')
axs[0].plot(ss_predictions[start:end, 0], label='ss_predictions')
axs[0].plot(sts_predictions[start:end, 0], label='sts_predictions')
axs[0].plot(stst_predictions[start:end, 0], label='stst_predictions')
#
axs[0].set_title('Mo')
axs[0].legend(loc='upper right')

# 在第二个子图中绘制 y2
axs[1].plot(t1[:, 1], label='O')
axs[1].plot(ss_predictions[start:end, 1], label='ss_predictions')
axs[1].plot(sts_predictions[start:end, 1], label='sts_predictions')
axs[1].plot(stst_predictions[start:end, 1], label='stst_predictions')
# axs[1].plot(p1[:, 1], label='predict O')
# axs[1].plot(p1[:, 1], color='blue', label='predict O')
# axs[1].plot(t1[:, 1], color='red', label='O')
axs[1].set_title('O')
axs[1].legend(loc='upper right')
# 在第三个子图中绘制 y3
axs[2].plot(t1[:, 2], label='S')
axs[2].plot(ss_predictions[start:end, 2], label='ss_predictions')
axs[2].plot(sts_predictions[start:end, 2], label='sts_predictions')
axs[2].plot(stst_predictions[start:end, 2], label='stst_predictions')
# axs[2].plot(p1[:, 2], label='predict S')
axs[2].set_title('S')
axs[2].legend(loc='upper right')
# 在第三个子图中绘制 y3
# axs[3].plot(t1[:, 3], label='target')
# # axs[3].plot(p1[:, 3], label='predict')
# axs[3].set_title('time')
# axs[3].legend(loc='upper right')
# 设置统一的横坐标标签
for ax in axs:
    # plt.xlim(1100, 1200)
    ax.set_xlabel('time')
# axs[0].set_xlim(1100, 1200)
# 调整子图之间的间距
plt.tight_layout()

# 显示图形
plt.show()
# plt.savefig('result.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[116], line 22
#      20 # 在第一个子图中绘制 y1
#      21 axs[0].plot(t1[:, 0], label='Mo')
# ---> 22 axs[0].plot(ss_predictions[start:end, 0], label='ss_predictions')
#      23 axs[0].plot(sts_predictions[start:end, 0], label='sts_predictions')
#      24 axs[0].plot(stst_predictions[start:end, 0], label='stst_predictions')
#
# NameError: name 'ss_predictions' is not defined
